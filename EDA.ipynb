# %% [markdown]
# # DS 5110 EDA — DIME + FEC Party Classification
#
# This notebook is an initial EDA I did; I tried using a year's transaction data from itemized contribution records, but even a year's worth was so large that it took a long time to process and exceeded 50GB. So this version avoids the huge DIME itemized transaction files and removes the DIME Donors/PACs aggregate table, since that table cannot be reliably linked back to recipients/candidates without itemized contribution links.
#
# What I used for a POC(proof of concept):
#
# 1. Stanford DIME **Recipients/Candidates** aggregate data
# 2. Federal Election Commission **Candidate Summary**
# 3. FEC **Candidate Master**
# 4. FEC **Candidate-Committee Linkage**
# 5. FEC **Committee Master / Committee Summary**
#
# The FEC features are joined directly when a compatible FEC candidate ID exists in DIME. If no compatible ID exists, the notebook adds valid **year + state** FEC context features without using the target party as a join key.
#
# This notebook includes:
#
# - Data import and preprocessing
# - DIME + FEC feature engineering
# - Missing-value handling and compact Parquet caching
# - Automatic constant/all-zero column removal
# - Train/test split
# - EDA with many tables and graphs
# - Three Spark ML models
# - K-fold cross-validation and hyperparameter tuning
# - Model evaluation with accuracy, precision, recall, F1, confusion matrices, and one-vs-rest AUROC
# - Random Forest feature importance and Logistic Regression coefficient importance
# - Champion model selection and hyperparameter sensitivity analysis

# %%
import os
import re
import gzip
import zipfile
import shutil
import urllib.request
from pathlib import Path
from typing import Optional, Sequence, List, Dict

import pandas as pd
import matplotlib.pyplot as plt

from pyspark.sql import SparkSession, DataFrame
from pyspark.sql import functions as F
from pyspark.sql import Window
from pyspark.storagelevel import StorageLevel

from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler, StandardScaler
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator, BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.functions import vector_to_array

DATA_DIR = Path("./data/dime_fec_final_project")
DATA_DIR.mkdir(parents=True, exist_ok=True)

PROCESSED_DIR = DATA_DIR / "processed"
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

# Multiple years, not just 2024.
START_YEAR = 2018
END_YEAR = 2024
YEAR_LABEL = f"{START_YEAR}_{END_YEAR}"

# Hard limit requested by you.
MAX_FINAL_TABLE_GB = 40.0

# Download missing files from Stanford if needed.
DOWNLOAD_DATA_IF_MISSING = True

# If .csv.gz exists but .csv does not, decompress once.
# Uncompressed CSV generally lets Spark split the input better than one large .gz file.
DECOMPRESS_GZ_TO_CSV = True

# Main modeling controls
ADD_DONOR_PAC_CONTEXT = False

# Add FEC candidate/committee context instead of DIME contribDB and donor/PAC aggregate context.
ADD_FEC_CONTEXT = True
FEC_CYCLES = [2018, 2020, 2022, 2024]
DOWNLOAD_FEC_IF_MISSING = True
READ_FEC_FEATURES_IF_EXISTS = True
WRITE_FEC_FEATURES_PARQUET = True


# Reuse compact model parquet once built.
READ_FINAL_MODEL_IF_EXISTS = True
WRITE_FINAL_MODEL_PARQUET = True
# Set True after changing donor/PAC context settings so you do not read an old Parquet cache.
FORCE_REBUILD_FINAL_MODEL = False

# Keep expensive debug actions controlled.
SHOW_DEBUG = True
RUN_EXPENSIVE_COUNTS = True
MAKE_GRAPHS = True

# Modeling controls
USE_RECIPIENT_CFSCORE_FEATURE = True

# Remove useless numeric columns that are constant/all-zero, such as vote pct fields when unavailable.
DROP_CONSTANT_ZERO_COLUMNS = True
TEST_FRACTION = 0.2
RANDOM_SEED = 42

# Cross-validation/hyperparameter tuning controls.
FAST_CV = True
NUM_FOLDS = 3
MAX_TRAIN_ROWS_FOR_TUNING = None 

# Spark partition controls
NUM_CORES = int(os.environ.get("SLURM_CPUS_PER_TASK", os.cpu_count() or 8))
SHUFFLE_PARTITIONS = max(32, NUM_CORES * 4)
MODEL_PARTITIONS = max(16, NUM_CORES * 2)

print("Years:", START_YEAR, "to", END_YEAR)
print("NUM_CORES:", NUM_CORES)
print("SHUFFLE_PARTITIONS:", SHUFFLE_PARTITIONS)
print("MODEL_PARTITIONS:", MODEL_PARTITIONS)
from pyspark.sql.types import DoubleType, IntegerType, StringType, StructType, StructField, LongType
# Out:
# Years: 2018 to 2024
# NUM_CORES: 10
# SHUFFLE_PARTITIONS: 40
# MODEL_PARTITIONS: 20

# %%
spark = (
    SparkSession.builder
    .appName("DIME_Aggregate_PLUS_Fast_Party_Modeling")
    .master(f"local[{NUM_CORES}]")
    .config("spark.sql.shuffle.partitions", str(SHUFFLE_PARTITIONS))
    .config("spark.default.parallelism", str(SHUFFLE_PARTITIONS))
    .config("spark.sql.adaptive.enabled", "true")
    .config("spark.sql.adaptive.coalescePartitions.enabled", "true")
    .config("spark.sql.adaptive.skewJoin.enabled", "true")
    .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer")
    .getOrCreate()
)

spark.sparkContext.setLogLevel("WARN")

print("Spark master:", spark.sparkContext.master)
print("Default parallelism:", spark.sparkContext.defaultParallelism)
print("Shuffle partitions:", spark.conf.get("spark.sql.shuffle.partitions"))
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/01 11:50:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Spark master: local[10]
# Default parallelism: 40
# Shuffle partitions: 40

# %% [markdown]
# # File paths and download helpers

# %%
# Stanford DIME aggregate links
RECIPIENTS_URL = "https://www.dropbox.com/scl/fi/bcpmxvxwc7iwmqvchm2sp/dime_recipients_1979_2024.csv.gz?dl=1&rlkey=4ii8765xw8y2svlzcbxzfvnbh"

RECIPIENTS_GZ = DATA_DIR / "dime_recipients_1979_2024.csv.gz"
RECIPIENTS_CSV = DATA_DIR / "dime_recipients_1979_2024.csv"


# FEC data folder
FEC_DIR = DATA_DIR / "fec"
FEC_DIR.mkdir(parents=True, exist_ok=True)

FEC_FEATURES_PARQUET = PROCESSED_DIR / f"fec_candidate_committee_features_{min(FEC_CYCLES)}_{max(FEC_CYCLES)}_parquet"

FINAL_MODEL_PARQUET = PROCESSED_DIR / f"dime_no_dimeplus_party_model_{YEAR_LABEL}_parquet"

def path_size_gb(path: Path) -> float:
    if not path.exists():
        return 0.0
    if path.is_file():
        return path.stat().st_size / 1024**3
    total = 0
    for p in path.rglob("*"):
        if p.is_file():
            total += p.stat().st_size
    return total / 1024**3

def download_if_missing(url: str, out_path: Path, enabled: bool = True) -> None:
    if out_path.exists() and out_path.stat().st_size > 0:
        print("Already exists:", out_path, "GB:", round(path_size_gb(out_path), 3))
        return
    if not enabled:
        print("Download disabled; missing:", out_path)
        return

    print("Downloading:", out_path)
    print("From:", url)
    urllib.request.urlretrieve(url, out_path)
    print("Downloaded:", out_path, "GB:", round(path_size_gb(out_path), 3))

def decompress_gz_if_needed(gz_path: Path, csv_path: Path) -> Path:
    if csv_path.exists() and csv_path.stat().st_size > 0:
        print("Using existing CSV:", csv_path, "GB:", round(path_size_gb(csv_path), 3))
        return csv_path

    if not gz_path.exists():
        raise FileNotFoundError(f"Missing both CSV and GZ: {csv_path} / {gz_path}")

    if not DECOMPRESS_GZ_TO_CSV:
        print("Using GZ directly:", gz_path)
        return gz_path

    free_gb = shutil.disk_usage(str(DATA_DIR)).free / 1024**3
    print("Free disk GB:", round(free_gb, 2))
    print("Decompressing:", gz_path, "->", csv_path)
    with gzip.open(gz_path, "rb") as f_in:
        with open(csv_path, "wb") as f_out:
            shutil.copyfileobj(f_in, f_out)
    print("Created:", csv_path, "GB:", round(path_size_gb(csv_path), 3))
    return csv_path


def unzip_if_needed(zip_path: Path, output_dir: Path) -> Optional[Path]:
    if not zip_path.exists():
        print("ZIP missing:", zip_path)
        return None

    output_dir.mkdir(parents=True, exist_ok=True)

    existing = list(output_dir.glob("*.txt")) + list(output_dir.glob("*.csv"))
    if existing:
        print("Using existing extracted file:", existing[0])
        return existing[0]

    print("Unzipping:", zip_path)
    with zipfile.ZipFile(zip_path, "r") as z:
        names = [n for n in z.namelist() if n.lower().endswith((".txt", ".csv"))]
        if not names:
            print("No txt/csv found in:", zip_path)
            return None
        z.extract(names[0], output_dir)
        return output_dir / names[0]

def fec_cycle_suffix(cycle: int) -> str:
    return str(cycle)[-2:]

def fec_candidate_summary_url(cycle: int) -> str:
    return f"https://www.fec.gov/files/bulk-downloads/{cycle}/candidate_summary_{cycle}.csv"

def fec_committee_summary_url(cycle: int) -> str:
    return f"https://www.fec.gov/files/bulk-downloads/{cycle}/committee_summary_{cycle}.csv"

def fec_candidate_master_url(cycle: int) -> str:
    return f"https://www.fec.gov/files/bulk-downloads/{cycle}/cn{fec_cycle_suffix(cycle)}.zip"

def fec_committee_master_url(cycle: int) -> str:
    return f"https://www.fec.gov/files/bulk-downloads/{cycle}/cm{fec_cycle_suffix(cycle)}.zip"

def fec_candidate_committee_linkage_url(cycle: int) -> str:
    return f"https://www.fec.gov/files/bulk-downloads/{cycle}/ccl{fec_cycle_suffix(cycle)}.zip"

def get_fec_file_paths(cycle: int) -> dict:
    cycle_dir = FEC_DIR / str(cycle)
    cycle_dir.mkdir(parents=True, exist_ok=True)

    paths = {
        "candidate_summary": cycle_dir / f"candidate_summary_{cycle}.csv",
        "committee_summary": cycle_dir / f"committee_summary_{cycle}.csv",
        "candidate_master_zip": cycle_dir / f"cn{fec_cycle_suffix(cycle)}.zip",
        "committee_master_zip": cycle_dir / f"cm{fec_cycle_suffix(cycle)}.zip",
        "candidate_committee_linkage_zip": cycle_dir / f"ccl{fec_cycle_suffix(cycle)}.zip",
        "candidate_master_dir": cycle_dir / "candidate_master",
        "committee_master_dir": cycle_dir / "committee_master",
        "candidate_committee_linkage_dir": cycle_dir / "candidate_committee_linkage",
    }
    return paths

def download_fec_cycle_if_missing(cycle: int):
    paths = get_fec_file_paths(cycle)

    download_if_missing(fec_candidate_summary_url(cycle), paths["candidate_summary"], DOWNLOAD_FEC_IF_MISSING)
    download_if_missing(fec_committee_summary_url(cycle), paths["committee_summary"], DOWNLOAD_FEC_IF_MISSING)
    download_if_missing(fec_candidate_master_url(cycle), paths["candidate_master_zip"], DOWNLOAD_FEC_IF_MISSING)
    download_if_missing(fec_committee_master_url(cycle), paths["committee_master_zip"], DOWNLOAD_FEC_IF_MISSING)
    download_if_missing(fec_candidate_committee_linkage_url(cycle), paths["candidate_committee_linkage_zip"], DOWNLOAD_FEC_IF_MISSING)

    paths["candidate_master"] = unzip_if_needed(paths["candidate_master_zip"], paths["candidate_master_dir"])
    paths["committee_master"] = unzip_if_needed(paths["committee_master_zip"], paths["committee_master_dir"])
    paths["candidate_committee_linkage"] = unzip_if_needed(paths["candidate_committee_linkage_zip"], paths["candidate_committee_linkage_dir"])

    return paths

if not RECIPIENTS_CSV.exists() and not RECIPIENTS_GZ.exists():
    download_if_missing(RECIPIENTS_URL, RECIPIENTS_GZ, DOWNLOAD_DATA_IF_MISSING)


RECIPIENTS_INPUT = decompress_gz_if_needed(RECIPIENTS_GZ, RECIPIENTS_CSV)

CONTRIBUTORS_INPUT = None

FEC_INPUTS = {}
if ADD_FEC_CONTEXT:
    for cyc in FEC_CYCLES:
        FEC_INPUTS[int(cyc)] = download_fec_cycle_if_missing(int(cyc))

print("Recipients input:", RECIPIENTS_INPUT)
print("Contributors/Donor-PAC input: disabled")
print("FEC inputs:", FEC_INPUTS)
print("DIME+ contribDB and donor/PAC aggregate data are disabled in this notebook.")
# Out:
# Using existing CSV: data/dime_fec_final_project/dime_recipients_1979_2024.csv GB: 0.14
# Already exists: data/dime_fec_final_project/fec/2018/candidate_summary_2018.csv GB: 0.001
# Already exists: data/dime_fec_final_project/fec/2018/committee_summary_2018.csv GB: 0.006
# Already exists: data/dime_fec_final_project/fec/2018/cn18.zip GB: 0.0
# Already exists: data/dime_fec_final_project/fec/2018/cm18.zip GB: 0.001
# Already exists: data/dime_fec_final_project/fec/2018/ccl18.zip GB: 0.0
# Using existing extracted file: data/dime_fec_final_project/fec/2018/candidate_master/cn.txt
# Using existing extracted file: data/dime_fec_final_project/fec/2018/committee_master/cm.txt
# Using existing extracted file: data/dime_fec_final_project/fec/2018/candidate_committee_linkage/ccl.txt
# Already exists: data/dime_fec_final_project/fec/2020/candidate_summary_2020.csv GB: 0.002
# Already exists: data/dime_fec_final_project/fec/2020/committee_summary_2020.csv GB: 0.007
# Already exists: data/dime_fec_final_project/fec/2020/cn20.zip GB: 0.0
# Already exists: data/dime_fec_final_project/fec/2020/cm20.zip GB: 0.001
# Already exists: data/dime_fec_final_project/fec/2020/ccl20.zip GB: 0.0
# Using existing extracted file: data/dime_fec_final_project/fec/2020/candidate_master/cn.txt
# Using existing extracted file: data/dime_fec_final_project/fec/2020/committee_master/cm.txt
# Using existing extracted file: data/dime_fec_final_project/fec/2020/candidate_committee_linkage/ccl.txt
# Already exists: data/dime_fec_final_project/fec/2022/candidate_summary_2022.csv GB: 0.002
# Already exists: data/dime_fec_final_project/fec/2022/committee_summary_2022.csv GB: 0.007
# Already exists: data/dime_fec_final_project/fec/2022/cn22.zip GB: 0.0
# Already exists: data/dime_fec_final_project/fec/2022/cm22.zip GB: 0.001
# Already exists: data/dime_fec_final_project/fec/2022/ccl22.zip GB: 0.0
# Using existing extracted file: data/dime_fec_final_project/fec/2022/candidate_master/cn.txt
# Using existing extracted file: data/dime_fec_final_project/fec/2022/committee_master/cm.txt
# Using existing extracted file: data/dime_fec_final_project/fec/2022/candidate_committee_linkage/ccl.txt
# Already exists: data/dime_fec_final_project/fec/2024/candidate_summary_2024.csv GB: 0.002
# Already exists: data/dime_fec_final_project/fec/2024/committee_summary_2024.csv GB: 0.007
# Already exists: data/dime_fec_final_project/fec/2024/cn24.zip GB: 0.0
# Already exists: data/dime_fec_final_project/fec/2024/cm24.zip GB: 0.001
# Already exists: data/dime_fec_final_project/fec/2024/ccl24.zip GB: 0.0
# Using existing extracted file: data/dime_fec_final_project/fec/2024/candidate_master/cn.txt
# Using existing extracted file: data/dime_fec_final_project/fec/2024/committee_master/cm.txt
# Using existing extracted file: data/dime_fec_final_project/fec/2024/candidate_committee_linkage/ccl.txt
# Recipients input: data/dime_fec_final_project/dime_recipients_1979_2024.csv
# Contributors/Donor-PAC input: disabled
# FEC inputs: {2018: {'candidate_summary': PosixPath('data/dime_fec_final_project/fec/2018/candidate_summary_2018.csv'), 'committee_summary': PosixPath('data/dime_fec_final_project/fec/2018/committee_summary_2018.csv'), 'candidate_master_zip': PosixPath('data/dime_fec_final_project/fec/2018/cn18.zip'), 'committee_master_zip': PosixPath('data/dime_fec_final_project/fec/2018/cm18.zip'), 'candidate_committee_linkage_zip': PosixPath('data/dime_fec_final_project/fec/2018/ccl18.zip'), 'candidate_master_dir': PosixPath('data/dime_fec_final_project/fec/2018/candidate_master'), 'committee_master_dir': PosixPath('data/dime_fec_final_project/fec/2018/committee_master'), 'candidate_committee_linkage_dir': PosixPath('data/dime_fec_final_project/fec/2018/candidate_committee_linkage'), 'candidate_master': PosixPath('data/dime_fec_final_project/fec/2018/candidate_master/cn.txt'), 'committee_master': PosixPath('data/dime_fec_final_project/fec/2018/committee_master/cm.txt'), 'candidate_committee_linkage': PosixPath('data/dime_fec_final_project/fec/2018/candidate_committee_linkage/ccl.txt')}, 2020: {'candidate_summary': PosixPath('data/dime_fec_final_project/fec/2020/candidate_summary_2020.csv'), 'committee_summary': PosixPath('data/dime_fec_final_project/fec/2020/committee_summary_2020.csv'), 'candidate_master_zip': PosixPath('data/dime_fec_final_project/fec/2020/cn20.zip'), 'committee_master_zip': PosixPath('data/dime_fec_final_project/fec/2020/cm20.zip'), 'candidate_committee_linkage_zip': PosixPath('data/dime_fec_final_project/fec/2020/ccl20.zip'), 'candidate_master_dir': PosixPath('data/dime_fec_final_project/fec/2020/candidate_master'), 'committee_master_dir': PosixPath('data/dime_fec_final_project/fec/2020/committee_master'), 'candidate_committee_linkage_dir': PosixPath('data/dime_fec_final_project/fec/2020/candidate_committee_linkage'), 'candidate_master': PosixPath('data/dime_fec_final_project/fec/2020/candidate_master/cn.txt'), 'committee_master': PosixPath('data/dime_fec_final_project/fec/2020/committee_master/cm.txt'), 'candidate_committee_linkage': PosixPath('data/dime_fec_final_project/fec/2020/candidate_committee_linkage/ccl.txt')}, 2022: {'candidate_summary': PosixPath('data/dime_fec_final_project/fec/2022/candidate_summary_2022.csv'), 'committee_summary': PosixPath('data/dime_fec_final_project/fec/2022/committee_summary_2022.csv'), 'candidate_master_zip': PosixPath('data/dime_fec_final_project/fec/2022/cn22.zip'), 'committee_master_zip': PosixPath('data/dime_fec_final_project/fec/2022/cm22.zip'), 'candidate_committee_linkage_zip': PosixPath('data/dime_fec_final_project/fec/2022/ccl22.zip'), 'candidate_master_dir': PosixPath('data/dime_fec_final_project/fec/2022/candidate_master'), 'committee_master_dir': PosixPath('data/dime_fec_final_project/fec/2022/committee_master'), 'candidate_committee_linkage_dir': PosixPath('data/dime_fec_final_project/fec/2022/candidate_committee_linkage'), 'candidate_master': PosixPath('data/dime_fec_final_project/fec/2022/candidate_master/cn.txt'), 'committee_master': PosixPath('data/dime_fec_final_project/fec/2022/committee_master/cm.txt'), 'candidate_committee_linkage': PosixPath('data/dime_fec_final_project/fec/2022/candidate_committee_linkage/ccl.txt')}, 2024: {'candidate_summary': PosixPath('data/dime_fec_final_project/fec/2024/candidate_summary_2024.csv'), 'committee_summary': PosixPath('data/dime_fec_final_project/fec/2024/committee_summary_2024.csv'), 'candidate_master_zip': PosixPath('data/dime_fec_final_project/fec/2024/cn24.zip'), 'committee_master_zip': PosixPath('data/dime_fec_final_project/fec/2024/cm24.zip'), 'candidate_committee_linkage_zip': PosixPath('data/dime_fec_final_project/fec/2024/ccl24.zip'), 'candidate_master_dir': PosixPath('data/dime_fec_final_project/fec/2024/candidate_master'), 'committee_master_dir': PosixPath('data/dime_fec_final_project/fec/2024/committee_master'), 'candidate_committee_linkage_dir': PosixPath('data/dime_fec_final_project/fec/2024/candidate_committee_lin ...
# DIME+ contribDB and donor/PAC aggregate data are disabled in this notebook.

# %% [markdown]
# # Robust utility functions

# %%
def safe_name(name: str) -> str:
    name = str(name).strip().lower()
    name = re.sub(r"[^0-9a-zA-Z]+", "_", name)
    name = re.sub(r"_+", "_", name).strip("_")
    if not name:
        name = "col"
    if re.match(r"^\d", name):
        name = "c_" + name
    return name


def dedupe_names(names: Sequence[str]) -> List[str]:
    seen = {}
    out = []
    for n in names:
        base = safe_name(n)
        if base not in seen:
            seen[base] = 0
            out.append(base)
        else:
            seen[base] += 1
            out.append(f"{base}_{seen[base]}")
    return out


def qcol(name: str) -> str:
    return "`" + str(name).replace("`", "``") + "`"


def try_int_col(col_name: str):
    return F.expr(f"try_cast(nullif(trim(cast({qcol(col_name)} as string)), '') as int)")


def try_double_expr(expr_sql: str):
    return F.expr(f"try_cast({expr_sql} as double)")


def clean_double_col(col_name: str):
    return F.expr(
        f"try_cast(nullif(trim(regexp_replace(cast({qcol(col_name)} as string), '[$,]', '')), '') as double)"
    )


def read_csv_strings(path: Path) -> DataFrame:
    df = (
        spark.read
        .option("header", True)
        .option("inferSchema", False)
        .option("multiLine", False)
        .option("mode", "PERMISSIVE")
        .option("quote", '"')
        .option("escape", '"')
        .option("columnNameOfCorruptRecord", "_corrupt_record")
        .csv(str(path))
    )
    df = df.toDF(*dedupe_names(df.columns))
    return df


def first_present(df: DataFrame, candidates: Sequence[str]) -> Optional[str]:
    cols = set(df.columns)
    for c in candidates:
        c_safe = safe_name(c)
        if c_safe in cols:
            return c_safe
    return None


def first_present_contains(df: DataFrame, required_terms: Sequence[str], forbidden_terms: Sequence[str] = ()) -> Optional[str]:
    required_terms = [safe_name(t) for t in required_terms]
    forbidden_terms = [safe_name(t) for t in forbidden_terms]
    for c in df.columns:
        if all(t in c for t in required_terms) and not any(t in c for t in forbidden_terms):
            return c
    return None


def party_group_expr(c):
    x = F.upper(F.trim(c.cast("string")))
    return (
        F.when(x.isin("100", "D", "DEM", "DEMOCRAT", "DEMOCRATIC", "DEMOCRATIC_FARMER_LABOR", "DFL"), "DEMOCRAT")
         .when(x.isin("200", "R", "REP", "REPUBLICAN", "GOP"), "REPUBLICAN")
         .when(x.isNull() | (x == ""), None)
         .otherwise("OTHER")
    )


def ideology_group_expr(c):
    # c should usually already be numeric, but use cast safely after earlier clean_double_col.
    x = c.cast("double")
    return (
        F.when(x <= -0.25, "LEFT_LEANING")
         .when(x >= 0.25, "RIGHT_LEANING")
         .when(x.isNull(), None)
         .otherwise("MODERATE")
    )


def type_group_expr(c):
    x = F.upper(F.trim(c.cast("string")))
    return (
        F.when(x.isin("CAND", "CANDIDATE"), "CANDIDATE")
         .when(x.isin("COMM", "COMMITTEE", "PAC"), "COMMITTEE_OR_PAC")
         .when(x.isin("I", "IND", "INDIVIDUAL"), "INDIVIDUAL")
         .when(x.isNull() | (x == ""), "MISSING")
         .otherwise(x)
    )


def clean_cat(c):
    return F.coalesce(F.upper(F.trim(c.cast("string"))), F.lit("MISSING"))


def show_df(df: DataFrame, n: int = 20, truncate: bool = False) -> None:
    df.show(n, truncate=truncate)


def safe_ratio(num_col, den_col):
    return F.when(F.col(den_col) > 0, F.col(num_col) / F.col(den_col)).otherwise(F.lit(0.0))

# %% [markdown]
# # Raw data size summary

# %%
raw_size_rows = []
raw_size_rows.append(("dime_recipients_candidates", str(RECIPIENTS_INPUT), path_size_gb(Path(RECIPIENTS_INPUT))))


if ADD_FEC_CONTEXT:
    for cyc, paths in FEC_INPUTS.items():
        for key, p in paths.items():
            if isinstance(p, Path) and p.exists() and p.is_file():
                raw_size_rows.append((f"fec_{key}_{cyc}", str(p), path_size_gb(p)))

raw_size_df = spark.createDataFrame(raw_size_rows, ["source", "path", "size_gb"])
show_df(raw_size_df.orderBy(F.desc("size_gb")), 100, truncate=False)

print("Approximate raw input size GB:", round(sum(r[2] for r in raw_size_rows), 3))
# Out:
# [Stage 0:================================>                       (23 + 12) / 40]
# +----------------------------------------+------------------------------------------------------------------------+---------------------+
# |source                                  |path                                                                    |size_gb              |
# +----------------------------------------+------------------------------------------------------------------------+---------------------+
# |dime_recipients_candidates              |data/dime_fec_final_project/dime_recipients_1979_2024.csv               |0.1402341015636921   |
# |fec_committee_summary_2024              |data/dime_fec_final_project/fec/2024/committee_summary_2024.csv         |0.007321745157241821 |
# |fec_committee_summary_2022              |data/dime_fec_final_project/fec/2022/committee_summary_2022.csv         |0.00726318359375     |
# |fec_committee_summary_2020              |data/dime_fec_final_project/fec/2020/committee_summary_2020.csv         |0.0070317592471838   |
# |fec_committee_summary_2018              |data/dime_fec_final_project/fec/2018/committee_summary_2018.csv         |0.006414720788598061 |
# |fec_committee_master_2024               |data/dime_fec_final_project/fec/2024/committee_master/cm.txt            |0.0023290570825338364|
# |fec_committee_master_2022               |data/dime_fec_final_project/fec/2022/committee_master/cm.txt            |0.0022131046280264854|
# |fec_committee_master_2018               |data/dime_fec_final_project/fec/2018/committee_master/cm.txt            |0.0021016495302319527|
# |fec_committee_master_2020               |data/dime_fec_final_project/fec/2020/committee_master/cm.txt            |0.0020553674548864365|
# |fec_candidate_summary_2024              |data/dime_fec_final_project/fec/2024/candidate_summary_2024.csv         |0.001817259006202221 |
# |fec_candidate_summary_2020              |data/dime_fec_final_project/fec/2020/candidate_summary_2020.csv         |0.0017781713977456093|
# |fec_candidate_summary_2022              |data/dime_fec_final_project/fec/2022/candidate_summary_2022.csv         |0.0016116853803396225|
# |fec_candidate_summary_2018              |data/dime_fec_final_project/fec/2018/candidate_summary_2018.csv         |0.0013691643252968788|
# |fec_candidate_master_2024               |data/dime_fec_final_project/fec/2024/candidate_master/cn.txt            |8.872495964169502E-4 |
# |fec_committee_master_zip_2024           |data/dime_fec_final_project/fec/2024/cm24.zip                           |8.227881044149399E-4 |
# |fec_committee_master_zip_2022           |data/dime_fec_final_project/fec/2022/cm22.zip                           |7.806979119777679E-4 |
# |fec_candidate_master_2022               |data/dime_fec_final_project/fec/2022/candidate_master/cn.txt            |7.748566567897797E-4 |
# |fec_committee_master_zip_2018           |data/dime_fec_final_project/fec/2018/cm18.zip                           |7.536839693784714E-4 |
# |fec_committee_master_zip_2020           |data/dime_fec_final_project/fec/2020/cm20.zip                           |7.288390770554543E-4 |
# |fec_candidate_master_2020               |data/dime_fec_final_project/fec/2020/candidate_master/cn.txt            |6.97714276611805E-4  |
# |fec_candidate_master_2018               |data/dime_fec_final_project/fec/2018/candidate_master/cn.txt            |6.651431322097778E-4 |
# |fec_candidate_master_zip_2024           |data/dime_fec_final_project/fec/2024/cn24.zip                           |3.319205716252327E-4 |
# |fec_candidate_committee_linkage_2024    |data/dime_fec_final_project/fec/2024/candidate_committee_linkage/ccl.txt|3.291061148047447E-4 |
# |fec_candidate_committee_linkage_2022    |data/dime_fec_final_project/fec/2022/candidate_committee_linkage/ccl.txt|2.9333028942346573E-4|
# |fec_candidate_master_zip_2022           |data/dime_fec_final_project/fec/2022/cn22.zip                           |2.917414531111717E-4 |
# |fec_candidate_committee_linkage_2018    |data/dime_fec_final_project/fec/2018/candidate_committee_linkage/ccl.txt|2.7416180819272995E-4|
# |fec_candidate_committee_linkage_2020    |data/dime_fec_final_project/fec/2020/candidate_committee_linkage/ccl.txt|2.6938971132040024E-4|
# |fec_candidate_master_zip_2020           |data/dime_fec_final_project/fec/2020/cn20.zip                           |2.6407185941934586E-4|
# |fec_candidate_master_zip_2018           |data/dime_fec_final_project/fec/2018/cn18.zip                           |2.53274105489254E-4  |
# |fec_candidate_committee_linkage_zip_2024|data/dime_fec_final_project/fec/2024/ccl24.zip                          |8.778832852840424E-5 |
# |fec_candidate_committee_linkage_zip_2022|data/dime_fec_final_project/fec/2022/ccl22.zip                          |7.825996726751328E-5 |
# |fec_candidate_committee_linkage_zip_2020|data/dime_fec_final_project/fec/2020/ccl20.zip                          |7.124431431293488E-5 |
# |fec_candidate_committee_linkage_zip_2018|data/dime_fec_final_project/fec/2018/ccl18.zip                          |7.008202373981476E-5 |
# +----------------------------------------+------------------------------------------------------------------------+---------------------+
#
# Approximate raw input size GB: 0.192

# %% [markdown]
# # DataFrame cleanup helpers

# %%
def unique_column_names(cols):
    """Return unique column names by suffixing duplicates."""
    seen = {}
    out = []
    for c in cols:
        if c not in seen:
            seen[c] = 0
            out.append(c)
        else:
            seen[c] += 1
            out.append(f"{c}_dup{seen[c]}")
    return out

def make_columns_unique(df: DataFrame) -> DataFrame:
    """Spark can hold duplicate names after joins; Parquet writes cannot."""
    new_cols = unique_column_names(df.columns)
    if new_cols != df.columns:
        print("Duplicate column names detected and renamed.")
        return df.toDF(*new_cols)
    return df

def drop_uninformative_numeric_columns(
    df: DataFrame,
    protected_cols=None,
    max_cols_per_batch: int = 40,
):
    """
    Drops numeric columns that are all-null, constant, or all-zero.
    Protected columns such as identifiers, target, and categorical columns are never dropped.
    """
    if protected_cols is None:
        protected_cols = set()
    protected_cols = set(protected_cols)

    numeric_type_prefixes = ("double", "float", "int", "bigint", "long", "smallint", "tinyint", "decimal")
    numeric_cols = []
    for name, dtype in df.dtypes:
        if name in protected_cols:
            continue
        dtype_lower = dtype.lower()
        if any(dtype_lower.startswith(prefix) for prefix in numeric_type_prefixes):
            numeric_cols.append(name)

    audit_schema = StructType([
        StructField("column", StringType(), True),
        StructField("min", DoubleType(), True),
        StructField("max", DoubleType(), True),
        StructField("non_null_count", LongType(), True),
        StructField("approx_distinct", LongType(), True),
        StructField("drop_reason", StringType(), True),
    ])

    if not numeric_cols:
        empty = spark.createDataFrame([], audit_schema)
        return df, empty

    rows = []
    for start in range(0, len(numeric_cols), max_cols_per_batch):
        batch_cols = numeric_cols[start:start + max_cols_per_batch]
        exprs = []
        for c in batch_cols:
            exprs.extend([
                F.min(F.col(c)).alias(f"{c}__min"),
                F.max(F.col(c)).alias(f"{c}__max"),
                F.count(F.col(c)).alias(f"{c}__non_null"),
                F.approx_count_distinct(F.col(c)).alias(f"{c}__distinct"),
            ])

        stats = df.agg(*exprs).collect()[0].asDict()

        for c in batch_cols:
            min_v = stats.get(f"{c}__min")
            max_v = stats.get(f"{c}__max")
            non_null = stats.get(f"{c}__non_null") or 0
            approx_distinct = stats.get(f"{c}__distinct") or 0

            drop_reason = None
            if non_null == 0:
                drop_reason = "all_null"
            elif approx_distinct <= 1 and min_v == 0 and max_v == 0:
                drop_reason = "constant_all_zero"
            elif approx_distinct <= 1:
                drop_reason = "constant"

            rows.append((
                c,
                float(min_v) if min_v is not None else None,
                float(max_v) if max_v is not None else None,
                int(non_null),
                int(approx_distinct),
                drop_reason,
            ))

    audit_df = spark.createDataFrame(rows, audit_schema)

    drop_cols = [r["column"] for r in audit_df.filter(F.col("drop_reason").isNotNull()).collect()]
    if drop_cols:
        print("Dropping uninformative numeric columns:")
        for c in drop_cols:
            print("  -", c)
        df = df.drop(*drop_cols)
    else:
        print("No uninformative numeric columns detected.")

    return df, audit_df

# %% [markdown]
# # Sanity check

# %%
_test_df = spark.createDataFrame([(1.0, 2.0)], ["test_nonconstant_a", "test_nonconstant_b"])
_test_clean_df, _test_audit_df = drop_uninformative_numeric_columns(
    _test_df,
    protected_cols=set()
)
print("Helper sanity check passed.")
show_df(_test_audit_df, 10, truncate=False)
# Out:
# 26/07/01 11:50:17 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Dropping uninformative numeric columns:
#   - test_nonconstant_a
#   - test_nonconstant_b
# Helper sanity check passed.
# +------------------+---+---+--------------+---------------+-----------+
# |column            |min|max|non_null_count|approx_distinct|drop_reason|
# +------------------+---+---+--------------+---------------+-----------+
# |test_nonconstant_a|1.0|1.0|1             |1              |constant   |
# |test_nonconstant_b|2.0|2.0|1             |1              |constant   |
# +------------------+---+---+--------------+---------------+-----------+

# %% [markdown]
# # Build recipients/candidates base modeling table

# %%
rec_raw = read_csv_strings(RECIPIENTS_INPUT)

print("Recipient columns:", len(rec_raw.columns))
if SHOW_DEBUG:
    print(rec_raw.columns[:100])

rec_colmap = {
    "year": first_present(rec_raw, ["cycle", "year", "election_cycle", "recipient_cycle"]),
    "recipient_id": first_present(rec_raw, [
        "recipient.dime.id", "recipient_dime_id", "dime.id", "dime_id",
        "bonica.rid", "bonica_rid", "rid", "recipient_id", "candidate_id", "cand_id"
    ]),
    "party": first_present(rec_raw, [
        "party", "recipient.party", "recipient_party", "candidate_party",
        "cand_party", "cand_pty_affiliation", "party_affiliation"
    ]),
    "type": first_present(rec_raw, ["recipient.type", "recipient_type", "type", "rtype", "recipient_rtype"]),
    "state": first_present(rec_raw, ["state", "recipient.state", "recipient_state", "cand_office_st", "office_state"]),
    "seat": first_present(rec_raw, ["seat", "office", "office.type", "office_type", "cand_office"]),
    "district": first_present(rec_raw, ["district", "recipient.district", "recipient_district", "cand_office_district"]),
    "gender": first_present(rec_raw, ["gender", "candidate.gender", "candidate_gender", "recipient_gender"]),
    "cfscore": first_present(rec_raw, ["cfscore", "recipient.cfscore", "recipient_cfscore", "dime_cfscore"]),
    "name": first_present(rec_raw, ["recipient.name", "recipient_name", "candidate_name", "name"]),
}

numeric_candidates = {
    "total_receipts": ["total_receipts", "total_receipt", "total_received", "total_recpts", "receipts"],
    "total_indiv_contribs": ["total_indiv_contribs", "total_individual_contributions", "individual_contributions", "indiv_contribs"],
    "total_pac_contribs": ["total_pac_contribs", "pac_contributions", "committee_contributions", "other_committee_contribution"],
    "num_givers": ["num_givers", "number_givers", "n_givers", "contributors", "num_contributors"],
    "primary_vote_pct": ["primary_vote_pct", "primary_vote_percent", "primary_pct"],
    "general_vote_pct": ["general_vote_pct", "general_vote_percent", "general_pct"],
    "recipient_cfscore": ["cfscore", "recipient_cfscore", "dime_cfscore"],
}

resolved_numeric = {}
for out_name, candidates in numeric_candidates.items():
    col = first_present(rec_raw, candidates)
    if col is None:
        col = first_present_contains(rec_raw, out_name.split("_"))
    resolved_numeric[out_name] = col

print("Resolved recipient columns:")
for k, v in rec_colmap.items():
    print(f"  {k:22s} -> {v}")

print("Resolved numeric features:")
for k, v in resolved_numeric.items():
    print(f"  {k:22s} -> {v}")

if rec_colmap["year"] is None:
    raise ValueError("No year/cycle column found in recipients file.")
if rec_colmap["party"] is None:
    raise ValueError("No party column found in recipients file.")

select_exprs = [
    try_int_col(rec_colmap["year"]).alias("year"),
]

if rec_colmap["recipient_id"] is not None:
    select_exprs.append(F.trim(F.col(rec_colmap["recipient_id"]).cast("string")).alias("recipient_id"))
else:
    select_exprs.append(F.monotonically_increasing_id().cast("string").alias("recipient_id"))

select_exprs.append(F.col(rec_colmap["party"]).cast("string").alias("party_raw"))

for out_name, key in [
    ("recipient_type_group", "type"),
    ("state_group", "state"),
    ("seat_group", "seat"),
    ("district_group", "district"),
    ("gender_group", "gender"),
    ("recipient_name", "name"),
]:
    c = rec_colmap.get(key)
    if c is not None:
        select_exprs.append(F.col(c).cast("string").alias(out_name))
    else:
        select_exprs.append(F.lit(None).cast("string").alias(out_name))

for out_name, source_col in resolved_numeric.items():
    if out_name == "recipient_cfscore" and not USE_RECIPIENT_CFSCORE_FEATURE:
        select_exprs.append(F.lit(None).cast("double").alias(out_name))
    elif source_col is not None:
        select_exprs.append(clean_double_col(source_col).alias(out_name))
    else:
        select_exprs.append(F.lit(None).cast("double").alias(out_name))

rec_model = (
    rec_raw
    .select(*select_exprs)
    .filter(F.col("year").between(START_YEAR, END_YEAR))
    .withColumn("party_group", party_group_expr(F.col("party_raw")))
    .filter(F.col("party_group").isin("DEMOCRAT", "REPUBLICAN", "OTHER"))
    .filter(F.col("recipient_id").isNotNull())
    .filter(F.length(F.col("recipient_id")) > 0)
    .withColumn("recipient_type_group", type_group_expr(F.col("recipient_type_group")))
    .withColumn("state_group", clean_cat(F.col("state_group")))
    .withColumn("seat_group", clean_cat(F.col("seat_group")))
    .withColumn("district_group", clean_cat(F.col("district_group")))
    .withColumn("gender_group", clean_cat(F.col("gender_group")))
)

base_numeric_cols = list(resolved_numeric.keys())
rec_model = rec_model.fillna({c: 0.0 for c in base_numeric_cols})

# Helpful log transforms for skewed financial variables.
for c in ["total_receipts", "total_indiv_contribs", "total_pac_contribs", "num_givers"]:
    if c in rec_model.columns:
        rec_model = rec_model.withColumn(f"log_{c}", F.log1p(F.greatest(F.col(c), F.lit(0.0))))

print("Built recipient/candidate base table.")
if RUN_EXPENSIVE_COUNTS:
    print("Recipient/candidate rows:", rec_model.count())
# Out:
# Recipient columns: 64
# ['election', 'cycle', 'fecyear', 'bonica_rid', 'bonica_cid', 'name', 'lname', 'ffname', 'fname', 'mname', 'title', 'suffix', 'party', 'state', 'seat', 'district', 'distcyc', 'ico_status', 'cand_gender', 'recipient_cfscore', 'recipient_cfscore_dyn', 'contributor_cfscore', 'dwdime', 'dwnom1', 'dwnom2', 'ps_dwnom1', 'ps_dwnom2', 'irt_cfscore', 'composite_score', 'num_givers', 'num_givers_total', 'total_receipts', 'total_disbursements', 'total_indiv_contribs', 'total_unitemized', 'total_pac_contribs', 'total_party_contribs', 'total_contribs_from_candidate', 'ind_exp_support', 'ind_exp_oppose', 'prim_vote_pct', 'pwinner', 'gen_vote_pct', 'gwinner', 's_elec_stat', 'r_elec_stat', 'district_pres_vs', 'fec_cand_status', 'recipient_type', 'igcat', 'comtype', 'icpsr', 'icpsr2', 'cand_id', 'fec_id', 'nid', 'before_switch_icpsr', 'after_switch_icpsr', 'party_orig', 'nimsp_party', 'nimsp_candidate_ico_code', 'nimsp_district', 'nimsp_office', 'nimsp_candidate_status']
# Resolved recipient columns:
#   year                   -> cycle
#   recipient_id           -> bonica_rid
#   party                  -> party
#   type                   -> recipient_type
#   state                  -> state
#   seat                   -> seat
#   district               -> district
#   gender                 -> None
#   cfscore                -> recipient_cfscore
#   name                   -> name
# Resolved numeric features:
#   total_receipts         -> total_receipts
#   total_indiv_contribs   -> total_indiv_contribs
#   total_pac_contribs     -> total_pac_contribs
#   num_givers             -> num_givers
#   primary_vote_pct       -> None
#   general_vote_pct       -> None
#   recipient_cfscore      -> recipient_cfscore
# Built recipient/candidate base table.
# [Stage 10:==============>                                         (9 + 13) / 36]
# Recipient/candidate rows: 86861

# %%
model_with_context = rec_model

print("Current modeling table columns:", len(model_with_context.columns))
# Out:
# Current modeling table columns: 21

# %% [markdown]
# # Add FEC Candidate and Committee Features
#
# This section adds FEC data instead of the huge DIME `contribDB` file.
#
# - **Candidate Summary** for federal candidate financial totals
# - **Candidate Master** for federal candidate metadata
# - **Candidate-Committee Linkage** to connect candidates to committees
# - **Committee Master / Committee Summary** for committee structure and receipts/disbursements

# %%
def parquet_has_data(path: Path) -> bool:
    if not path.exists():
        return False
    if (path / "_SUCCESS").exists():
        return True
    return any(path.rglob("*.parquet"))

def read_fec_csv_header(path: Path) -> DataFrame:
    df = (
        spark.read
        .option("header", True)
        .option("inferSchema", False)
        .option("multiLine", False)
        .option("mode", "PERMISSIVE")
        .csv(str(path))
    )
    return df.toDF(*dedupe_names(df.columns))

def read_fec_pipe_no_header(path: Path, columns: list) -> DataFrame:
    df = (
        spark.read
        .option("header", False)
        .option("inferSchema", False)
        .option("sep", "|")
        .option("mode", "PERMISSIVE")
        .csv(str(path))
    )
    # Keep only expected number of columns.
    if len(df.columns) >= len(columns):
        df = df.select(*[F.col(df.columns[i]).alias(columns[i]) for i in range(len(columns))])
    else:
        # If file is short for any reason, still rename available columns.
        renamed = [columns[i] if i < len(columns) else f"extra_{i}" for i in range(len(df.columns))]
        df = df.toDF(*renamed)
    return df

FEC_CANDIDATE_MASTER_COLS = [
    "cand_id", "cand_name", "cand_pty_affiliation", "cand_election_yr", "cand_office_st",
    "cand_office", "cand_office_district", "cand_ici", "cand_status", "cand_pcc",
    "cand_st1", "cand_st2", "cand_city", "cand_st", "cand_zip"
]

FEC_COMMITTEE_MASTER_COLS = [
    "cmte_id", "cmte_nm", "tres_nm", "cmte_st1", "cmte_st2", "cmte_city", "cmte_st",
    "cmte_zip", "cmte_dsgn", "cmte_tp", "cmte_pty_affiliation", "cmte_filing_freq",
    "org_tp", "connected_org_nm", "cand_id"
]

FEC_CANDIDATE_COMMITTEE_LINKAGE_COLS = [
    "cand_id", "cand_election_yr", "fec_election_yr", "cmte_id", "cmte_tp", "cmte_dsgn", "linkage_id"
]

def party_group_from_fec(c):
    x = F.upper(F.trim(c.cast("string")))
    return (
        F.when(x.isin("DEM", "D", "100"), "DEMOCRAT")
         .when(x.isin("REP", "R", "200"), "REPUBLICAN")
         .when(x.isNull() | (x == ""), None)
         .otherwise("OTHER")
    )

def build_fec_features_for_cycle(cycle: int, paths: dict) -> DataFrame:
    print(f"Building FEC features for cycle {cycle}")

    cand_sum = read_fec_csv_header(paths["candidate_summary"])
    cmte_sum = read_fec_csv_header(paths["committee_summary"])
    cand_master = read_fec_pipe_no_header(paths["candidate_master"], FEC_CANDIDATE_MASTER_COLS)
    cmte_master = read_fec_pipe_no_header(paths["committee_master"], FEC_COMMITTEE_MASTER_COLS)
    ccl = read_fec_pipe_no_header(paths["candidate_committee_linkage"], FEC_CANDIDATE_COMMITTEE_LINKAGE_COLS)

    if SHOW_DEBUG:
        print("FEC candidate_summary cols:", cand_sum.columns[:80])
        print("FEC committee_summary cols:", cmte_sum.columns[:80])

    # Candidate summary column names should follow FEC descriptions, but normalize robustly.
    cand_colmap = {
        "cand_id": first_present(cand_sum, ["cand_id"]),
        "cand_name": first_present(cand_sum, ["cand_name"]),
        "cand_ici": first_present(cand_sum, ["cand_ici"]),
        "party": first_present(cand_sum, ["cand_pty_affiliation", "party"]),
        "ttl_receipts": first_present(cand_sum, ["ttl_receipts", "total_receipts"]),
        "trans_from_auth": first_present(cand_sum, ["trans_from_auth"]),
        "ttl_disb": first_present(cand_sum, ["ttl_disb", "total_disbursements"]),
        "trans_to_auth": first_present(cand_sum, ["trans_to_auth"]),
        "coh_bop": first_present(cand_sum, ["coh_bop"]),
        "coh_cop": first_present(cand_sum, ["coh_cop"]),
        "cand_contrib": first_present(cand_sum, ["cand_contrib"]),
        "cand_loans": first_present(cand_sum, ["cand_loans"]),
        "other_loans": first_present(cand_sum, ["other_loans"]),
        "debts_owed_by": first_present(cand_sum, ["debts_owed_by"]),
        "ttl_indiv_contrib": first_present(cand_sum, ["ttl_indiv_contrib"]),
        "cand_office_st": first_present(cand_sum, ["cand_office_st"]),
        "cand_office_district": first_present(cand_sum, ["cand_office_district"]),
        "other_pol_cmte_contrib": first_present(cand_sum, ["other_pol_cmte_contrib"]),
        "pol_pty_contrib": first_present(cand_sum, ["pol_pty_contrib"]),
        "indiv_refunds": first_present(cand_sum, ["indiv_refunds"]),
        "cmte_refunds": first_present(cand_sum, ["cmte_refunds"]),
    }

    if cand_colmap["cand_id"] is None:
        raise ValueError(f"FEC candidate summary for {cycle} is missing cand_id.")

    def cnum(name):
        src = cand_colmap.get(name)
        if src is None:
            return F.lit(0.0).cast("double")
        return clean_double_col(src)

    cand_features = (
        cand_sum
        .select(
            F.lit(int(cycle)).cast("int").alias("year"),
            F.trim(F.col(cand_colmap["cand_id"]).cast("string")).alias("fec_cand_id"),
            F.col(cand_colmap["cand_name"]).cast("string").alias("fec_cand_name") if cand_colmap["cand_name"] else F.lit(None).cast("string").alias("fec_cand_name"),
            party_group_from_fec(F.col(cand_colmap["party"])).alias("fec_party_group") if cand_colmap["party"] else F.lit(None).cast("string").alias("fec_party_group"),
            clean_cat(F.col(cand_colmap["cand_ici"])).alias("fec_incumbent_challenger") if cand_colmap["cand_ici"] else F.lit("MISSING").alias("fec_incumbent_challenger"),
            clean_cat(F.col(cand_colmap["cand_office_st"])).alias("fec_state_group") if cand_colmap["cand_office_st"] else F.lit("MISSING").alias("fec_state_group"),
            clean_cat(F.col(cand_colmap["cand_office_district"])).alias("fec_district_group") if cand_colmap["cand_office_district"] else F.lit("MISSING").alias("fec_district_group"),
            cnum("ttl_receipts").alias("fec_ttl_receipts"),
            cnum("trans_from_auth").alias("fec_trans_from_auth"),
            cnum("ttl_disb").alias("fec_ttl_disb"),
            cnum("trans_to_auth").alias("fec_trans_to_auth"),
            cnum("coh_bop").alias("fec_coh_bop"),
            cnum("coh_cop").alias("fec_coh_cop"),
            cnum("cand_contrib").alias("fec_cand_contrib"),
            cnum("cand_loans").alias("fec_cand_loans"),
            cnum("other_loans").alias("fec_other_loans"),
            cnum("debts_owed_by").alias("fec_debts_owed_by"),
            cnum("ttl_indiv_contrib").alias("fec_ttl_indiv_contrib"),
            cnum("other_pol_cmte_contrib").alias("fec_other_pol_cmte_contrib"),
            cnum("pol_pty_contrib").alias("fec_pol_pty_contrib"),
            cnum("indiv_refunds").alias("fec_indiv_refunds"),
            cnum("cmte_refunds").alias("fec_cmte_refunds"),
        )
        .filter(F.col("fec_cand_id").isNotNull())
        .filter(F.length("fec_cand_id") > 0)
    )

    cand_master_features = (
        cand_master
        .select(
            F.lit(int(cycle)).cast("int").alias("year"),
            F.trim(F.col("cand_id")).alias("fec_cand_id"),
            clean_cat(F.col("cand_office")).alias("fec_office_group"),
            clean_cat(F.col("cand_status")).alias("fec_candidate_status"),
            clean_cat(F.col("cand_pcc")).alias("fec_principal_cmte_id"),
        )
        .filter(F.col("fec_cand_id").isNotNull())
        .filter(F.length("fec_cand_id") > 0)
        .dropDuplicates(["year", "fec_cand_id"])
    )

    # Committee summary robust mapping.
    cmte_colmap = {
        "cmte_id": first_present(cmte_sum, ["cmte_id"]),
        "ttl_receipts": first_present(cmte_sum, ["ttl_receipts", "total_receipts"]),
        "ttl_disb": first_present(cmte_sum, ["ttl_disb", "total_disbursements"]),
        "cash_on_hand": first_present(cmte_sum, ["coh_cop", "cash_on_hand_end", "cash_on_hand"]),
        "indv_contrib": first_present(cmte_sum, ["indv_contrib", "ttl_indiv_contrib", "individual_contributions"]),
        "other_pol_cmte_contrib": first_present(cmte_sum, ["other_pol_cmte_contrib", "other_cmte_contrib"]),
        "pty_cmte_contrib": first_present(cmte_sum, ["pty_cmte_contrib", "pol_pty_contrib", "party_cmte_contrib"]),
        "cand_contrib": first_present(cmte_sum, ["cand_contrib"]),
    }

    if cmte_colmap["cmte_id"] is not None:
        def cmtenum(name):
            src = cmte_colmap.get(name)
            if src is None:
                return F.lit(0.0).cast("double")
            return clean_double_col(src)

        cmte_sum_small = (
            cmte_sum
            .select(
                F.lit(int(cycle)).cast("int").alias("year"),
                F.trim(F.col(cmte_colmap["cmte_id"]).cast("string")).alias("cmte_id"),
                cmtenum("ttl_receipts").alias("fec_cmte_ttl_receipts"),
                cmtenum("ttl_disb").alias("fec_cmte_ttl_disb"),
                cmtenum("cash_on_hand").alias("fec_cmte_cash_on_hand"),
                cmtenum("indv_contrib").alias("fec_cmte_indv_contrib"),
                cmtenum("other_pol_cmte_contrib").alias("fec_cmte_other_pol_cmte_contrib"),
                cmtenum("pty_cmte_contrib").alias("fec_cmte_party_contrib"),
                cmtenum("cand_contrib").alias("fec_cmte_cand_contrib"),
            )
            .filter(F.col("cmte_id").isNotNull())
            .filter(F.length("cmte_id") > 0)
        )
    else:
        cmte_sum_small = None

    cmte_master_small = (
        cmte_master
        .select(
            F.trim(F.col("cmte_id")).alias("cmte_id"),
            clean_cat(F.col("cmte_dsgn")).alias("fec_cmte_designation"),
            clean_cat(F.col("cmte_tp")).alias("fec_cmte_type"),
            party_group_from_fec(F.col("cmte_pty_affiliation")).alias("fec_cmte_party_group"),
            clean_cat(F.col("cmte_filing_freq")).alias("fec_cmte_filing_freq"),
            clean_cat(F.col("org_tp")).alias("fec_cmte_org_type"),
        )
        .filter(F.col("cmte_id").isNotNull())
        .filter(F.length("cmte_id") > 0)
        .dropDuplicates(["cmte_id"])
    )

    ccl_small = (
        ccl
        .select(
            F.lit(int(cycle)).cast("int").alias("year"),
            F.trim(F.col("cand_id")).alias("fec_cand_id"),
            F.trim(F.col("cmte_id")).alias("cmte_id"),
            clean_cat(F.col("cmte_tp")).alias("fec_link_cmte_type"),
            clean_cat(F.col("cmte_dsgn")).alias("fec_link_cmte_designation"),
        )
        .filter(F.col("fec_cand_id").isNotNull())
        .filter(F.length("fec_cand_id") > 0)
        .filter(F.col("cmte_id").isNotNull())
        .filter(F.length("cmte_id") > 0)
    )

    ccl_enriched = ccl_small.join(F.broadcast(cmte_master_small), on="cmte_id", how="left")

    if cmte_sum_small is not None:
        ccl_enriched = ccl_enriched.join(cmte_sum_small, on=["year", "cmte_id"], how="left")

    committee_features = (
        ccl_enriched
        .groupBy("year", "fec_cand_id")
        .agg(
            F.countDistinct("cmte_id").alias("fec_num_linked_committees"),
            F.sum(F.when(F.col("fec_link_cmte_designation") == "P", 1).otherwise(0)).alias("fec_num_principal_committees"),
            F.sum(F.when(F.col("fec_link_cmte_designation") == "A", 1).otherwise(0)).alias("fec_num_authorized_committees"),
            F.sum(F.when(F.col("fec_cmte_type").isin("H", "S", "P"), 1).otherwise(0)).alias("fec_num_candidate_committees"),
            F.sum(F.when(F.col("fec_cmte_type").isin("Q", "O", "N", "U", "V", "W", "X", "Y"), 1).otherwise(0)).alias("fec_num_pac_party_like_committees"),
            F.avg("fec_cmte_ttl_receipts").alias("fec_avg_linked_cmte_receipts"),
            F.sum("fec_cmte_ttl_receipts").alias("fec_sum_linked_cmte_receipts"),
            F.sum("fec_cmte_ttl_disb").alias("fec_sum_linked_cmte_disb"),
            F.sum("fec_cmte_indv_contrib").alias("fec_sum_linked_cmte_indv_contrib"),
            F.sum("fec_cmte_other_pol_cmte_contrib").alias("fec_sum_linked_cmte_other_pol_cmte_contrib"),
            F.sum("fec_cmte_party_contrib").alias("fec_sum_linked_cmte_party_contrib"),
        )
    )

    features = (
        cand_features
        .join(cand_master_features, on=["year", "fec_cand_id"], how="left")
        .join(committee_features, on=["year", "fec_cand_id"], how="left")
    )

    fec_numeric_cols = [c for c, dtype in features.dtypes if c.startswith("fec_") and dtype.lower() in ("double", "bigint", "int", "long")]
    features = features.fillna({c: 0.0 for c in fec_numeric_cols})

    # Adjusted totals to reduce double-counted transfers where possible.
    features = (
        features
        .withColumn("fec_adjusted_receipts", F.greatest(F.col("fec_ttl_receipts") - F.col("fec_trans_from_auth"), F.lit(0.0)))
        .withColumn("fec_adjusted_disb", F.greatest(F.col("fec_ttl_disb") - F.col("fec_trans_to_auth"), F.lit(0.0)))
        .withColumn("fec_spend_to_receipts_ratio", F.when(F.col("fec_adjusted_receipts") > 0, F.col("fec_adjusted_disb") / F.col("fec_adjusted_receipts")).otherwise(0.0))
        .withColumn("fec_indiv_contrib_share", F.when(F.col("fec_adjusted_receipts") > 0, F.col("fec_ttl_indiv_contrib") / F.col("fec_adjusted_receipts")).otherwise(0.0))
        .withColumn("fec_committee_contrib_share", F.when(F.col("fec_adjusted_receipts") > 0, F.col("fec_other_pol_cmte_contrib") / F.col("fec_adjusted_receipts")).otherwise(0.0))
        .withColumn("fec_party_contrib_share", F.when(F.col("fec_adjusted_receipts") > 0, F.col("fec_pol_pty_contrib") / F.col("fec_adjusted_receipts")).otherwise(0.0))
        .withColumn("fec_log_adjusted_receipts", F.log1p(F.col("fec_adjusted_receipts")))
        .withColumn("fec_log_adjusted_disb", F.log1p(F.col("fec_adjusted_disb")))
        .withColumn("fec_log_num_linked_committees", F.log1p(F.greatest(F.col("fec_num_linked_committees"), F.lit(0.0))))
    )

    return features

def build_all_fec_features() -> Optional[DataFrame]:
    if not ADD_FEC_CONTEXT:
        return None

    if READ_FEC_FEATURES_IF_EXISTS and parquet_has_data(FEC_FEATURES_PARQUET):
        print("Reading existing FEC features:", FEC_FEATURES_PARQUET)
        return spark.read.parquet(str(FEC_FEATURES_PARQUET))

    all_fec = []
    for cycle, paths in FEC_INPUTS.items():
        all_fec.append(build_fec_features_for_cycle(int(cycle), paths))

    if not all_fec:
        return None

    fec_features = all_fec[0]
    for df in all_fec[1:]:
        fec_features = fec_features.unionByName(df, allowMissingColumns=True)

    fec_features = make_columns_unique(fec_features).repartition(MODEL_PARTITIONS, "year")

    if WRITE_FEC_FEATURES_PARQUET:
        temp_path = PROCESSED_DIR / f"_tmp_fec_candidate_committee_features_{min(FEC_CYCLES)}_{max(FEC_CYCLES)}_parquet"
        if temp_path.exists():
            shutil.rmtree(temp_path)

        print("Writing FEC features:", FEC_FEATURES_PARQUET)
        fec_features.write.mode("overwrite").option("compression", "snappy").parquet(str(temp_path))

        if FEC_FEATURES_PARQUET.exists():
            shutil.rmtree(FEC_FEATURES_PARQUET)
        shutil.move(str(temp_path), str(FEC_FEATURES_PARQUET))

        fec_features = spark.read.parquet(str(FEC_FEATURES_PARQUET))

    return fec_features

fec_features_df = build_all_fec_features()

if fec_features_df is not None:
    print("FEC feature columns:", len(fec_features_df.columns))
    print(fec_features_df.columns)

    if RUN_EXPENSIVE_COUNTS:
        print("FEC candidate feature rows:", fec_features_df.count())

    # Try direct join if DIME has a FEC candidate ID column.
    # If not, use state-year-party context features.
    dime_possible_fec_id_cols = [
        c for c in model_with_context.columns
        if c.lower() in ["fec_id", "fec_cand_id", "candidate_fec_id", "cand_fec_id", "fec_candidate_id"]
        or ("fec" in c.lower() and "id" in c.lower())
    ]

    if dime_possible_fec_id_cols:
        dime_fec_id_col = dime_possible_fec_id_cols[0]
        print("Using direct DIME-FEC candidate join on:", dime_fec_id_col)

        model_with_context = (
            model_with_context
            .withColumn("fec_cand_id_join", F.trim(F.col(dime_fec_id_col).cast("string")))
            .join(
                fec_features_df,
                (model_with_context["year"] == fec_features_df["year"]) &
                (F.col("fec_cand_id_join") == fec_features_df["fec_cand_id"]),
                "left"
            )
            .drop(fec_features_df["year"])
            .drop("fec_cand_id_join")
        )
    else:
        print("No DIME FEC candidate ID found. Adding FEC year-state context instead.")
        print("Important: the join does NOT use party_group, because that would leak the target label.")

        fec_context = (
            fec_features_df
            .groupBy("year", "fec_state_group")
            .agg(
                F.count("*").alias("fec_ctx_candidate_count"),
                F.avg("fec_adjusted_receipts").alias("fec_ctx_avg_adjusted_receipts"),
                F.avg("fec_adjusted_disb").alias("fec_ctx_avg_adjusted_disb"),
                F.avg("fec_spend_to_receipts_ratio").alias("fec_ctx_avg_spend_to_receipts_ratio"),
                F.avg("fec_indiv_contrib_share").alias("fec_ctx_avg_indiv_contrib_share"),
                F.avg("fec_committee_contrib_share").alias("fec_ctx_avg_committee_contrib_share"),
                F.avg("fec_party_contrib_share").alias("fec_ctx_avg_party_contrib_share"),
                F.avg("fec_num_linked_committees").alias("fec_ctx_avg_num_linked_committees"),
                F.avg("fec_num_principal_committees").alias("fec_ctx_avg_num_principal_committees"),
                F.avg("fec_num_authorized_committees").alias("fec_ctx_avg_num_authorized_committees"),
                F.avg("fec_sum_linked_cmte_receipts").alias("fec_ctx_avg_sum_linked_cmte_receipts"),
            )
        )

        model_with_context = (
            model_with_context
            .join(
                F.broadcast(fec_context),
                (model_with_context["year"] == fec_context["year"]) &
                (model_with_context["state_group"] == fec_context["fec_state_group"]),
                "left"
            )
            .drop(fec_context["year"])
            .drop("fec_state_group")
        )

    fec_cols = [c for c in model_with_context.columns if c.startswith("fec_")]
    fec_numeric_cols = [c for c, dtype in model_with_context.dtypes if c.startswith("fec_") and dtype.lower() in ("double", "bigint", "int", "long")]
    model_with_context = model_with_context.fillna({c: 0.0 for c in fec_numeric_cols})

    print("Joined FEC columns:", len(fec_cols))
    print(fec_cols)

    print("FEC join/context coverage by year:")
    coverage_col = "fec_adjusted_receipts" if "fec_adjusted_receipts" in model_with_context.columns else "fec_ctx_candidate_count"
    fec_coverage = (
        model_with_context
        .groupBy("year")
        .agg(
            F.count("*").alias("dime_rows"),
            F.sum(F.when(F.col(coverage_col).isNotNull() & (F.col(coverage_col) != 0), 1).otherwise(0)).alias("rows_with_fec_signal"),
            F.avg(F.when(F.col(coverage_col).isNotNull() & (F.col(coverage_col) != 0), 1.0).otherwise(0.0)).alias("fec_signal_rate"),
        )
        .orderBy("year")
    )
    show_df(fec_coverage, 100, truncate=False)
else:
    print("No FEC features were joined.")
# Out:
# Reading existing FEC features: data/dime_fec_final_project/processed/fec_candidate_committee_features_2018_2024_parquet
# FEC feature columns: 45
# ['year', 'fec_cand_id', 'fec_cand_name', 'fec_party_group', 'fec_incumbent_challenger', 'fec_state_group', 'fec_district_group', 'fec_ttl_receipts', 'fec_trans_from_auth', 'fec_ttl_disb', 'fec_trans_to_auth', 'fec_coh_bop', 'fec_coh_cop', 'fec_cand_contrib', 'fec_cand_loans', 'fec_other_loans', 'fec_debts_owed_by', 'fec_ttl_indiv_contrib', 'fec_other_pol_cmte_contrib', 'fec_pol_pty_contrib', 'fec_indiv_refunds', 'fec_cmte_refunds', 'fec_office_group', 'fec_candidate_status', 'fec_principal_cmte_id', 'fec_num_linked_committees', 'fec_num_principal_committees', 'fec_num_authorized_committees', 'fec_num_candidate_committees', 'fec_num_pac_party_like_committees', 'fec_avg_linked_cmte_receipts', 'fec_sum_linked_cmte_receipts', 'fec_sum_linked_cmte_disb', 'fec_sum_linked_cmte_indv_contrib', 'fec_sum_linked_cmte_other_pol_cmte_contrib', 'fec_sum_linked_cmte_party_contrib', 'fec_adjusted_receipts', 'fec_adjusted_disb', 'fec_spend_to_receipts_ratio', 'fec_indiv_contrib_share', 'fec_committee_contrib_share', 'fec_party_contrib_share', 'fec_log_adjusted_receipts', 'fec_log_adjusted_disb', 'fec_log_num_linked_committees']
# FEC candidate feature rows: 18752
# No DIME FEC candidate ID found. Adding FEC year-state context instead.
# Important: the join does NOT use party_group, because that would leak the target label.
# Joined FEC columns: 11
# ['fec_ctx_candidate_count', 'fec_ctx_avg_adjusted_receipts', 'fec_ctx_avg_adjusted_disb', 'fec_ctx_avg_spend_to_receipts_ratio', 'fec_ctx_avg_indiv_contrib_share', 'fec_ctx_avg_committee_contrib_share', 'fec_ctx_avg_party_contrib_share', 'fec_ctx_avg_num_linked_committees', 'fec_ctx_avg_num_principal_committees', 'fec_ctx_avg_num_authorized_committees', 'fec_ctx_avg_sum_linked_cmte_receipts']
# FEC join/context coverage by year:
# +----+---------+--------------------+------------------+
# |year|dime_rows|rows_with_fec_signal|fec_signal_rate   |
# +----+---------+--------------------+------------------+
# |2018|32213    |29840               |0.9263340887219446|
# |2020|24336    |24229               |0.99560322156476  |
# |2022|23557    |23520               |0.9984293415969775|
# |2024|6755     |6681                |0.9890451517394523|
# +----+---------+--------------------+------------------+

# %% [markdown]
# ## Spark 4 safe-cast diagnostic
#
# This checks the final table schema before the Parquet write. If another strict-cast issue appears, the schema helps identify which derived column is still not safely parsed.

# %%
print('model_with_context columns:', len(model_with_context.columns))
model_with_context.printSchema()
# Out:
# model_with_context columns: 32
# root
#  |-- year: integer (nullable = true)
#  |-- recipient_id: string (nullable = true)
#  |-- party_raw: string (nullable = true)
#  |-- recipient_type_group: string (nullable = true)
#  |-- state_group: string (nullable = false)
#  |-- seat_group: string (nullable = false)
#  |-- district_group: string (nullable = false)
#  |-- gender_group: string (nullable = false)
#  |-- recipient_name: string (nullable = true)
#  |-- total_receipts: double (nullable = false)
#  |-- total_indiv_contribs: double (nullable = false)
#  |-- total_pac_contribs: double (nullable = false)
#  |-- num_givers: double (nullable = false)
#  |-- primary_vote_pct: double (nullable = false)
#  |-- general_vote_pct: double (nullable = false)
#  |-- recipient_cfscore: double (nullable = false)
#  |-- party_group: string (nullable = true)
#  |-- log_total_receipts: double (nullable = true)
#  |-- log_total_indiv_contribs: double (nullable = true)
#  |-- log_total_pac_contribs: double (nullable = true)
#  |-- log_num_givers: double (nullable = true)
#  |-- fec_ctx_candidate_count: long (nullable = true)
#  |-- fec_ctx_avg_adjusted_receipts: double (nullable = false)
#  |-- fec_ctx_avg_adjusted_disb: double (nullable = false)
#  |-- fec_ctx_avg_spend_to_receipts_ratio: double (nullable = false)
#  |-- fec_ctx_avg_indiv_contrib_share: double (nullable = false)
#  |-- fec_ctx_avg_committee_contrib_share: double (nullable = false)
#  |-- fec_ctx_avg_party_contrib_share: double (nullable = false)
#  |-- fec_ctx_avg_num_linked_committees: double (nullable = false)
#  |-- fec_ctx_avg_num_principal_committees: double (nullable = false)
#  |-- fec_ctx_avg_num_authorized_committees: double (nullable = false)
#  |-- fec_ctx_avg_sum_linked_cmte_receipts: double (nullable = false)

# %%
def parquet_has_data(path: Path) -> bool:
    if not path.exists():
        return False
    if (path / "_SUCCESS").exists():
        return True
    return any(path.rglob("*.parquet"))


if READ_FINAL_MODEL_IF_EXISTS and not FORCE_REBUILD_FINAL_MODEL and parquet_has_data(FINAL_MODEL_PARQUET):
    print("Reading existing final model Parquet:", FINAL_MODEL_PARQUET)
    model_df = spark.read.parquet(str(FINAL_MODEL_PARQUET))
else:
    if WRITE_FINAL_MODEL_PARQUET:
        print("Writing final model Parquet:", FINAL_MODEL_PARQUET)

        temp_path = PROCESSED_DIR / f"_tmp_dime_fec_only_party_model_{YEAR_LABEL}_parquet"
        if temp_path.exists():
            shutil.rmtree(temp_path)

        final_model_source = make_columns_unique(model_with_context)

        if DROP_CONSTANT_ZERO_COLUMNS:
            protected_cols = {
                "party_group", "party_raw", "recipient_id", "recipient_name",
                "recipient_type_group", "state_group", "seat_group", "district_group", "gender_group"
            }
            final_model_source, dropped_column_audit = drop_uninformative_numeric_columns(
                final_model_source,
                protected_cols=protected_cols
            )
            print("Column drop audit:")
            show_df(dropped_column_audit.orderBy(F.desc(F.col("drop_reason").isNotNull()), "column"), 200, truncate=False)
        dup_key_cols = [c for c in final_model_source.columns if c.startswith('year_dup')]
        if dup_key_cols:
            print('Dropping duplicate join key columns before write:', dup_key_cols)
            final_model_source = final_model_source.drop(*dup_key_cols)

        model_to_write = final_model_source.repartition(MODEL_PARTITIONS)

        (
            model_to_write
            .write
            .mode("overwrite")
            .option("compression", "snappy")
            .parquet(str(temp_path))
        )

        out_size_gb = path_size_gb(temp_path)
        print("Final table size GB:", round(out_size_gb, 3))

        if out_size_gb > MAX_FINAL_TABLE_GB:
            shutil.rmtree(temp_path, ignore_errors=True)
            raise RuntimeError(
                f"Final table would be {out_size_gb:.2f} GB, above MAX_FINAL_TABLE_GB={MAX_FINAL_TABLE_GB}. "
                "Reduce years/features or use fewer FEC cycles."
            )

        if FINAL_MODEL_PARQUET.exists():
            shutil.rmtree(FINAL_MODEL_PARQUET)
        shutil.move(str(temp_path), str(FINAL_MODEL_PARQUET))

        model_df = spark.read.parquet(str(FINAL_MODEL_PARQUET))

    else:
        print("Using model in lineage only; no Parquet write.")
        model_df = make_columns_unique(model_with_context).repartition(MODEL_PARTITIONS)

model_df = make_columns_unique(model_df)

# If an old cached Parquet is read, still remove constant/all-zero numeric columns in memory.
if DROP_CONSTANT_ZERO_COLUMNS:
    protected_cols = {
        "party_group", "party_raw", "recipient_id", "recipient_name",
        "recipient_type_group", "state_group", "seat_group", "district_group", "gender_group",
        "fec_incumbent_challenger", "fec_office_group", "fec_candidate_status"
    }
    model_df, dropped_column_audit_after_read = drop_uninformative_numeric_columns(
        model_df,
        protected_cols=protected_cols
    )
    print("Dropped-column audit after reading/writing final model table:")
    show_df(dropped_column_audit_after_read.orderBy(F.desc(F.col("drop_reason").isNotNull()), "column"), 200, truncate=False)

print("Final model columns:", len(model_df.columns))
print("Final model partitions:", model_df.rdd.getNumPartitions())
print("Final model path:", FINAL_MODEL_PARQUET)
print("Final model size GB:", round(path_size_gb(FINAL_MODEL_PARQUET), 3))
# Out:
# Reading existing final model Parquet: data/dime_fec_final_project/processed/dime_no_dimeplus_party_model_2018_2024_parquet
# No uninformative numeric columns detected.
# Dropped-column audit after reading/writing final model table:
# +-------------------------------------+------------------+-------------------+--------------+---------------+-----------+
# |column                               |min               |max                |non_null_count|approx_distinct|drop_reason|
# +-------------------------------------+------------------+-------------------+--------------+---------------+-----------+
# |fec_ctx_avg_num_authorized_committees|0.0               |0.16666666666666666|86861         |111            |NULL       |
# |fec_ctx_avg_num_linked_committees    |0.0               |1.7857142857142858 |86861         |180            |NULL       |
# |fec_ctx_avg_num_principal_committees |0.0               |1.5                |86861         |173            |NULL       |
# |fec_ctx_avg_sum_linked_cmte_receipts |0.0               |2.347347404125E7   |86861         |234            |NULL       |
# |fec_ctx_candidate_count              |0.0               |424.0              |86861         |119            |NULL       |
# |log_num_givers                       |0.6931471805599453|15.24565217288943  |86861         |4776           |NULL       |
# |log_total_indiv_contribs             |0.0               |20.039086508726037 |86861         |13676          |NULL       |
# |log_total_pac_contribs               |0.0               |18.155475380382256 |86861         |6936           |NULL       |
# |log_total_receipts                   |0.0               |20.84068698111019  |86861         |19081          |NULL       |
# |num_givers                           |1.0               |4179290.0          |86861         |4484           |NULL       |
# |recipient_cfscore                    |-5.76             |5.762              |86861         |4288           |NULL       |
# |total_indiv_contribs                 |-53908.14         |5.04504091E8       |86861         |14400          |NULL       |
# |total_pac_contribs                   |-2000.0           |7.670484E7         |86861         |6816           |NULL       |
# |total_receipts                       |-600000.0         |1.12459294473E9    |86861         |18371          |NULL       |
# |year                                 |2018.0            |2024.0             |86861         |4              |NULL       |
# +-------------------------------------+------------------+-------------------+--------------+---------------+-----------+
#
# Final model columns: 24
# Final model partitions: 20
# Final model path: data/dime_fec_final_project/processed/dime_no_dimeplus_party_model_2018_2024_parquet
# Final model size GB: 0.004

# %% [markdown]
# # EDA

# %%
def avg_if_exists(df: DataFrame, col_name: str, alias_name: str):
    """
    Returns avg(col_name) if the column exists; otherwise returns null as alias_name.
    This prevents EDA cells from failing when optional FEC context is off/missing.
    """
    if col_name in df.columns:
        return F.avg(F.col(col_name)).alias(alias_name)
    return F.lit(None).cast("double").alias(alias_name)

def sum_if_exists(df: DataFrame, col_name: str, alias_name: str):
    if col_name in df.columns:
        return F.sum(F.col(col_name)).alias(alias_name)
    return F.lit(None).cast("double").alias(alias_name)

def count_if_exists(df: DataFrame, col_name: str, alias_name: str):
    if col_name in df.columns:
        return F.count(F.col(col_name)).alias(alias_name)
    return F.lit(None).cast("long").alias(alias_name)

# %%
if RUN_EXPENSIVE_COUNTS:
    print("Model row count:", model_df.count())

class_balance = (
    model_df
    .groupBy("party_group")
    .agg(
        F.count("*").alias("rows"),
        F.avg("total_receipts").alias("avg_total_receipts"),
        F.avg("recipient_cfscore").alias("avg_recipient_cfscore"),
    )
    .orderBy(F.desc("rows"))
)

show_df(class_balance, 20)
# Out:
# Model row count: 86861
# +-----------+-----+------------------+---------------------+
# |party_group|rows |avg_total_receipts|avg_recipient_cfscore|
# +-----------+-----+------------------+---------------------+
# |DEMOCRAT   |29933|725483.7789977614 |-0.7985725453512843  |
# |REPUBLICAN |29722|472088.7823373258 |1.1477693627615908   |
# |OTHER      |27206|491889.66231125494|0.03384135852385503  |
# +-----------+-----+------------------+---------------------+

# %%
eda_year_party = (
    model_df
    .groupBy("year", "party_group")
    .agg(
        F.count("*").alias("rows"),
        F.avg("total_receipts").alias("avg_total_receipts"),
        F.avg("recipient_cfscore").alias("avg_recipient_cfscore")
    )
    .orderBy("year", "party_group")
)

show_df(eda_year_party, 200)
# Out:
# +----+-----------+-----+------------------+---------------------+
# |year|party_group|rows |avg_total_receipts|avg_recipient_cfscore|
# +----+-----------+-----+------------------+---------------------+
# |2018|DEMOCRAT   |10748|312056.8951265352 |-0.7887099925567546  |
# |2018|OTHER      |11836|98502.86502619128 |0.060159344373099034 |
# |2018|REPUBLICAN |9629 |258655.30734551867|1.0988185689064285   |
# |2020|DEMOCRAT   |9209 |916688.9655880117 |-0.8005414268650233  |
# |2020|OTHER      |6331 |529880.0868061916 |0.01699715684725952  |
# |2020|REPUBLICAN |8796 |516248.04930650303|1.141329467939973    |
# |2022|DEMOCRAT   |8177 |519426.91824752354|-0.7992620765561943  |
# |2022|OTHER      |5762 |471579.8976119403 |0.07298923984727526  |
# |2022|REPUBLICAN |9618 |316215.8735215221 |1.1925777708463299   |
# |2024|DEMOCRAT   |1799 |3153293.970711506 |-0.844282934963869   |
# |2024|OTHER      |3277 |1875055.2464998472|-0.09750717119316446 |
# |2024|REPUBLICAN |1679 |2357682.382948184 |1.205556879094699    |
# +----+-----------+-----+------------------+---------------------+

# %%
eda_state_party = (
    model_df
    .groupBy("state_group", "party_group")
    .agg(
        F.count("*").alias("rows"),
        F.avg("total_receipts").alias("avg_total_receipts"),
        F.avg("recipient_cfscore").alias("avg_recipient_cfscore")
    )
    .orderBy("state_group", F.desc("rows"))
)

show_df(eda_state_party, 150)
# Out:
# +-----------+-----------+----+-------------------+---------------------+
# |state_group|party_group|rows|avg_total_receipts |avg_recipient_cfscore|
# +-----------+-----------+----+-------------------+---------------------+
# |00         |DEMOCRAT   |106 |3.561066731867925E7|-0.9811792452830188  |
# |00         |OTHER      |58  |1793295.200172414  |0.10027586206896552  |
# |00         |REPUBLICAN |45  |3.421296064888888E7|0.7027333333333333   |
# |AK         |REPUBLICAN |259 |202752.56366795368 |1.178930501930502    |
# |AK         |DEMOCRAT   |166 |214343.66759036144 |-0.7591746987951807  |
# |AK         |OTHER      |103 |466803.4583495146  |0.03953398058252426  |
# |AL         |REPUBLICAN |782 |205912.49878516624 |1.1222915601023018   |
# |AL         |DEMOCRAT   |401 |221706.04501246882 |-0.7789950124688276  |
# |AL         |OTHER      |96  |746066.4307291666  |0.8596979166666666   |
# |AR         |REPUBLICAN |514 |225345.08291828792 |1.0656089494163425   |
# |AR         |DEMOCRAT   |265 |75773.38664150942  |-0.7205283018867925  |
# |AR         |OTHER      |104 |79322.40663461538  |0.2755096153846153   |
# |AS         |REPUBLICAN |4   |91342.145          |0.914                |
# |AS         |DEMOCRAT   |2   |31411.5            |-0.6970000000000001  |
# |AZ         |REPUBLICAN |530 |604326.8768490567  |1.242420754716981    |
# |AZ         |DEMOCRAT   |462 |1706184.194307359  |-0.7729242424242424  |
# |AZ         |OTHER      |200 |688919.5272        |-0.135185            |
# |CA         |OTHER      |4937|89085.24455944909  |-0.3200694753899129  |
# |CA         |DEMOCRAT   |1873|575372.9339348639  |-0.8460646022423918  |
# |CA         |REPUBLICAN |1105|549423.6683076924  |1.1627013574660634   |
# |CO         |DEMOCRAT   |559 |387240.55899821105 |-0.850330948121646   |
# |CO         |REPUBLICAN |463 |252035.19967602592 |1.2713261339092872   |
# |CO         |OTHER      |298 |407271.7994966443  |-0.01042953020134231 |
# |CT         |DEMOCRAT   |626 |157789.48827476034 |-0.6841246006389777  |
# |CT         |REPUBLICAN |562 |43948.92850533808  |1.126064056939502    |
# |CT         |OTHER      |265 |9214.266264150943  |-0.040762264150943396|
# |DC         |OTHER      |1734|2933123.6412053052 |-0.5761147635524798  |
# |DC         |DEMOCRAT   |350 |1.727844760202857E7|-0.7792885714285713  |
# |DC         |REPUBLICAN |99  |3.591257428747475E7|1.149979797979798    |
# |DE         |DEMOCRAT   |283 |180805.1487279152  |-0.7402862190812721  |
# |DE         |REPUBLICAN |186 |38791.57978494623  |1.2488064516129032   |
# |DE         |OTHER      |89  |608486.7453932585  |0.2338202247191011   |
# |FL         |REPUBLICAN |1057|561825.1146452223  |1.125021759697256    |
# |FL         |DEMOCRAT   |990 |680527.0069191919  |-0.8105161616161616  |
# |FL         |OTHER      |490 |937765.9801020407  |0.24890000000000004  |
# |GA         |REPUBLICAN |979 |568119.1174157303  |1.1099989785495403   |
# |GA         |DEMOCRAT   |797 |811225.2495357591  |-0.8857691342534505  |
# |GA         |OTHER      |438 |728388.6720776254  |0.3070045662100456   |
# |GU         |DEMOCRAT   |13  |181686.95153846155 |-0.2764615384615385  |
# |GU         |REPUBLICAN |7   |362254.1757142857  |0.6231428571428571   |
# |HI         |DEMOCRAT   |433 |112755.81108545033 |-0.6180392609699769  |
# |HI         |REPUBLICAN |154 |24439.050714285713 |1.5094350649350647   |
# |HI         |OTHER      |66  |41813.54045454546  |-0.1421818181818182  |
# |IA         |REPUBLICAN |543 |303247.2284898712  |1.2108821362799265   |
# |IA         |DEMOCRAT   |525 |351310.1700380952  |-0.8525390476190478  |
# |IA         |OTHER      |64  |130256.0525        |0.07973437500000001  |
# |ID         |REPUBLICAN |597 |49409.73391959799  |1.2391172529313235   |
# |ID         |DEMOCRAT   |215 |73070.6308372093   |-0.8497488372093023  |
# |ID         |OTHER      |57  |19865.32473684211  |0.5488771929824561   |
# |IL         |DEMOCRAT   |1026|364259.95696881105 |-0.7707017543859648  |
# |IL         |REPUBLICAN |707 |166634.62309759547 |1.1650155586987272   |
# |IL         |OTHER      |549 |828747.0378324225  |-0.14749180327868852 |
# |IN         |REPUBLICAN |671 |319137.9534873323  |1.206754098360656    |
# |IN         |DEMOCRAT   |500 |153039.14178000003 |-0.874368            |
# |IN         |OTHER      |101 |131119.85188118808 |0.4674356435643565   |
# |KS         |REPUBLICAN |665 |150729.9872180451  |1.1477518796992483   |
# |KS         |DEMOCRAT   |421 |220982.91707838478 |-0.7879477434679336  |
# |KS         |OTHER      |59  |327881.3683050847  |0.6714237288135594   |
# |KY         |REPUBLICAN |678 |294168.03533923294 |1.0202153392330384   |
# |KY         |DEMOCRAT   |561 |286929.4328877005  |-0.7948752228163994  |
# |KY         |OTHER      |260 |92401.7021153846   |0.02550384615384617  |
# |LA         |REPUBLICAN |585 |366978.151008547   |0.953111111111111    |
# |LA         |DEMOCRAT   |434 |89723.89442396314  |-0.5821751152073732  |
# |LA         |OTHER      |107 |292583.7275700934  |0.4023364485981307   |
# |MA         |DEMOCRAT   |1164|215087.28049828182 |-0.6812328178694158  |
# |MA         |OTHER      |502 |1715457.2080079685 |-0.19983665338645412 |
# |MA         |REPUBLICAN |371 |108193.75088948787 |1.0311347708894878   |
# |MD         |DEMOCRAT   |1037|482075.5441465767  |-0.7446422372227577  |
# |MD         |REPUBLICAN |549 |104088.64302367944 |0.976424408014572    |
# |MD         |OTHER      |270 |320663.1707407408  |-0.2982888888888889  |
# |ME         |DEMOCRAT   |582 |261007.00068728518 |-0.8840773195876289  |
# |ME         |REPUBLICAN |549 |121200.96792349724 |1.3963369763205826   |
# |ME         |OTHER      |160 |12294.888749999998 |-0.15179375          |
# |MI         |DEMOCRAT   |936 |469434.70624999993 |-0.8880534188034189  |
# |MI         |REPUBLICAN |765 |374752.4115947712  |1.0742862745098036   |
# |MI         |OTHER      |370 |162945.43791891893 |0.18822162162162162  |
# |MISSING    |OTHER      |2233|0.0                |0.20560367218987907  |
# |MISSING    |REPUBLICAN |76  |0.0                |1.307907894736842    |
# |MISSING    |DEMOCRAT   |68  |0.0                |-0.8972500000000001  |
# |MN         |DEMOCRAT   |817 |341598.4922766218  |-0.8473476132190944  |
# |MN         |REPUBLICAN |699 |197917.9055221745  |1.308150214592275    |
# |MN         |OTHER      |112 |217625.4327678572  |-0.06688392857142855 |
# |MO         |REPUBLICAN |934 |179495.2992719486  |1.1195235546038544   |
# |MO         |DEMOCRAT   |690 |238444.5752463768  |-0.8689000000000001  |
# |MO         |OTHER      |414 |87810.30818840579  |0.12687681159420294  |
# |MP         |OTHER      |3   |71153.98           |-0.28                |
# |MP         |DEMOCRAT   |3   |49213.82666666666  |-0.5533333333333333  |
# |MP         |REPUBLICAN |2   |117090.495         |0.040499999999999994 |
# |MS         |REPUBLICAN |465 |128730.7097849462  |1.0750666666666666   |
# |MS         |DEMOCRAT   |266 |160141.27172932334 |-0.6932669172932332  |
# |MS         |OTHER      |132 |43758.4028030303   |0.28874999999999995  |
# |MT         |REPUBLICAN |520 |360888.6624230768  |1.282053846153846    |
# |MT         |DEMOCRAT   |397 |622162.5880352644  |-0.7887884130982368  |
# |MT         |OTHER      |140 |167749.33199999997 |0.03388571428571428  |
# |NC         |REPUBLICAN |857 |441510.0663010502  |1.230362893815636    |
# |NC         |DEMOCRAT   |770 |345957.12723376625 |-0.8597000000000002  |
# |NC         |OTHER      |531 |137860.8766290019  |0.36831638418079093  |
# |ND         |REPUBLICAN |305 |203742.87331147544 |1.1325639344262295   |
# |ND         |DEMOCRAT   |171 |297012.3719298246  |-0.681017543859649   |
# |ND         |OTHER      |29  |40989.19413793103  |0.921448275862069    |
# |NE         |OTHER      |271 |81119.66977859779  |0.24036900369003691  |
# |NE         |REPUBLICAN |66  |1036988.0810606062 |1.1016818181818184   |
# |NE         |DEMOCRAT   |56  |794475.1255357142  |-0.8602678571428573  |
# |NH         |DEMOCRAT   |670 |217908.52440298506 |-0.7933134328358209  |
# |NH         |REPUBLICAN |521 |99104.50276391553  |1.311380038387716    |
# |NH         |OTHER      |43  |173016.14232558137 |0.09920930232558138  |
# |NJ         |DEMOCRAT   |516 |620344.5916472869  |-0.6654554263565892  |
# |NJ         |REPUBLICAN |372 |342871.48715053767 |0.886258064516129    |
# |NJ         |OTHER      |172 |492986.4383139536  |-0.13154069767441864 |
# |NM         |DEMOCRAT   |459 |296120.44043572986 |-0.769124183006536   |
# |NM         |REPUBLICAN |361 |127906.04772853186 |1.1249806094182826   |
# |NM         |OTHER      |150 |28397.209200000005 |0.025440000000000018 |
# |NV         |REPUBLICAN |360 |380640.14380555565 |1.204722222222222    |
# |NV         |DEMOCRAT   |314 |1070076.9806687897 |-0.7625732484076433  |
# |NV         |OTHER      |136 |204136.6467647059  |0.33525              |
# |NY         |OTHER      |1951|331865.95103024086 |-0.23299487442337266 |
# |NY         |DEMOCRAT   |1199|511342.36647206015 |-0.7325521267723102  |
# |NY         |REPUBLICAN |613 |366567.1524306689  |0.898075040783034    |
# |OH         |REPUBLICAN |758 |518109.0866490764  |0.9860501319261215   |
# |OH         |DEMOCRAT   |666 |540986.7617117118  |-0.7892897897897898  |
# |OH         |OTHER      |379 |256408.7698944591  |0.009630606860158306 |
# |OK         |REPUBLICAN |866 |122335.86807159353 |1.0700600461893766   |
# |OK         |DEMOCRAT   |384 |71384.26588541667  |-0.8834218750000001  |
# |OK         |OTHER      |106 |63905.65103773585  |0.3675754716981133   |
# |OR         |DEMOCRAT   |453 |284746.9640397351  |-0.8176225165562914  |
# |OR         |REPUBLICAN |363 |133557.3214325069  |1.282669421487603    |
# |OR         |OTHER      |198 |365639.0682828283  |-0.2303080808080808  |
# |PA         |DEMOCRAT   |1048|479799.2316316794  |-0.8330868320610686  |
# |PA         |REPUBLICAN |1004|371379.997689243   |1.0778735059760955   |
# |PA         |OTHER      |284 |380951.04017605627 |-0.04388028169014086 |
# |PR         |OTHER      |20  |242281.27250000002 |-0.16485             |
# |PR         |DEMOCRAT   |9   |280858.7344444445  |-0.6053333333333333  |
# |PR         |REPUBLICAN |2   |430797.02          |-0.22450000000000003 |
# |RI         |DEMOCRAT   |571 |97836.44068301225  |-0.722108581436077   |
# |RI         |REPUBLICAN |191 |44731.45790575917  |1.6845706806282728   |
# |RI         |OTHER      |107 |199341.71663551405 |0.14190654205607475  |
# |SC         |REPUBLICAN |732 |391112.565751366   |1.1726448087431696   |
# |SC         |DEMOCRAT   |464 |437973.43810344825 |-0.7568750000000001  |
# |SC         |OTHER      |109 |253096.556146789   |0.35625688073394507  |
# |SD         |REPUBLICAN |423 |122526.06777777779 |1.1681489361702129   |
# |SD         |DEMOCRAT   |179 |52499.76536312849  |-0.7724301675977653  |
# |SD         |OTHER      |51  |77010.07960784313  |0.3867254901960783   |
# |TN         |REPUBLICAN |623 |325708.77146067424 |1.1408266452648474   |
# |TN         |DEMOCRAT   |387 |170347.3425839793  |-0.870925064599483   |
# |TN         |OTHER      |125 |308145.33904000005 |0.5122479999999999   |
# |TX         |OTHER      |5633|133643.64622581218 |0.2869501153914432   |
# |TX         |REPUBLICAN |1318|454643.33981031866 |1.2269430955993932   |
# |TX         |DEMOCRAT   |1205|642015.0703485479  |-0.7667659751037345  |
# |UT         |REPUBLICAN |592 |206406.3147804054  |1.1398462837837837   |
# |UT         |DEMOCRAT   |289 |93378.91387543255  |-0.9090173010380621  |
# +-----------+-----------+----+-------------------+---------------------+
# only showing top 150 rows

# %%
eda_seat_party = (
    model_df
    .groupBy("seat_group", "party_group")
    .agg(
        F.count("*").alias("rows"),
        F.avg("total_receipts").alias("avg_total_receipts"),
        F.avg("total_indiv_contribs").alias("avg_indiv_contribs"),
        F.avg("total_pac_contribs").alias("avg_pac_contribs"),
        F.avg("recipient_cfscore").alias("avg_recipient_cfscore")
    )
    .orderBy("seat_group", F.desc("rows"))
)

show_df(eda_seat_party, 100)
# Out:
# +-----------------------+-----------+-----+-------------------+--------------------+------------------+---------------------+
# |seat_group             |party_group|rows |avg_total_receipts |avg_indiv_contribs  |avg_pac_contribs  |avg_recipient_cfscore|
# +-----------------------+-----------+-----+-------------------+--------------------+------------------+---------------------+
# |AGRICULTUR             |OTHER      |4    |0.0                |0.0                 |0.0               |-0.379               |
# |FEDERAL:527            |OTHER      |547  |0.0                |0.0                 |0.0               |-0.10847166361974406 |
# |FEDERAL:COMMITTEE      |OTHER      |8436 |1563215.8433831204 |867414.052024656    |155196.59736130864|-0.03980713608345186 |
# |FEDERAL:COMMITTEE      |DEMOCRAT   |1712 |4890948.958884345  |1420699.8481950932  |460785.63995911216|-0.8900379672897195  |
# |FEDERAL:COMMITTEE      |REPUBLICAN |1498 |3712952.6455206946 |1065290.4595126836  |324206.77052069426|1.1438344459279037   |
# |FEDERAL:HOUSE          |DEMOCRAT   |4789 |1068393.1440071    |539583.0730194196   |172806.39021716436|-0.8573311756107747  |
# |FEDERAL:HOUSE          |REPUBLICAN |4188 |935198.2733261699  |382729.6458595989   |202110.50689111746|1.2235286532951288   |
# |FEDERAL:HOUSE          |OTHER      |274  |117531.68193430656 |64615.03810218977   |7426.384525547445 |0.01705109489051095  |
# |FEDERAL:PRESIDENT      |DEMOCRAT   |105  |3.589326321790477E7|1.0948270464190476E7|9778.885428571428 |-0.9815047619047619  |
# |FEDERAL:PRESIDENT      |OTHER      |58   |1793295.200172414  |935261.3681034483   |572.3413793103449 |0.10027586206896552  |
# |FEDERAL:PRESIDENT      |REPUBLICAN |46   |3.34721169647826E7 |8000481.671956521   |46336.43304347826 |0.7093260869565219   |
# |FEDERAL:SENATE         |REPUBLICAN |808  |3725234.696349011  |1563220.3372648517  |291267.5722400991 |1.244232673267327    |
# |FEDERAL:SENATE         |DEMOCRAT   |699  |6354312.891931331  |3067301.737911302   |280517.4944062948 |-0.8852732474964237  |
# |FEDERAL:SENATE         |OTHER      |106  |553181.5180188679  |277265.5139622642   |7587.85924528302  |0.25839622641509435  |
# |LOCAL                  |OTHER      |2    |0.0                |0.0                 |0.0               |0.4685               |
# |LOCAL:ASSESSOR         |DEMOCRAT   |7    |0.0                |0.0                 |0.0               |-0.17442857142857143 |
# |LOCAL:ASSESSOR         |OTHER      |3    |0.0                |0.0                 |0.0               |0.9790000000000001   |
# |LOCAL:ASSESSOR         |REPUBLICAN |2    |0.0                |0.0                 |0.0               |1.244                |
# |LOCAL:ATTORNEY         |REPUBLICAN |21   |0.0                |0.0                 |0.0               |1.4495714285714285   |
# |LOCAL:ATTORNEY         |DEMOCRAT   |16   |0.0                |0.0                 |0.0               |-0.7540000000000001  |
# |LOCAL:ATTORNEY         |OTHER      |8    |0.0                |0.0                 |0.0               |-0.059875            |
# |LOCAL:AUDITOR          |OTHER      |1    |0.0                |0.0                 |0.0               |-1.046               |
# |LOCAL:COMMISSIONER     |REPUBLICAN |29   |0.0                |0.0                 |0.0               |1.3174482758620691   |
# |LOCAL:COMMISSIONER     |OTHER      |13   |0.0                |0.0                 |0.0               |-0.06346153846153847 |
# |LOCAL:COMMISSIONER     |DEMOCRAT   |12   |0.0                |0.0                 |0.0               |-0.9500000000000001  |
# |LOCAL:COUNCIL          |OTHER      |1160 |0.0                |0.0                 |0.0               |-0.2290396551724138  |
# |LOCAL:COUNCIL          |DEMOCRAT   |111  |0.0                |0.0                 |0.0               |-0.7618108108108109  |
# |LOCAL:COUNCIL          |REPUBLICAN |22   |0.0                |0.0                 |0.0               |1.095227272727273    |
# |LOCAL:COUNTY-EXECUTIVE |OTHER      |28   |0.0                |0.0                 |0.0               |0.06900000000000003  |
# |LOCAL:COUNTY-EXECUTIVE |DEMOCRAT   |3    |0.0                |0.0                 |0.0               |-0.6266666666666666  |
# |LOCAL:COUNTY-EXECUTIVE |REPUBLICAN |2    |0.0                |0.0                 |0.0               |0.772                |
# |LOCAL:DISTRICT-ATTORNEY|OTHER      |61   |0.0                |0.0                 |0.0               |0.3115737704918033   |
# |LOCAL:DISTRICT-ATTORNEY|DEMOCRAT   |28   |0.0                |0.0                 |0.0               |-0.6403571428571428  |
# |LOCAL:DISTRICT-ATTORNEY|REPUBLICAN |18   |0.0                |0.0                 |0.0               |0.782388888888889    |
# |LOCAL:LAW-ENFORCE      |OTHER      |5    |0.0                |0.0                 |0.0               |-0.031199999999999985|
# |LOCAL:LAW-ENFORCE      |REPUBLICAN |1    |0.0                |0.0                 |0.0               |2.594                |
# |LOCAL:MAYOR            |OTHER      |292  |0.0                |0.0                 |0.0               |0.024585616438356172 |
# |LOCAL:MAYOR            |DEMOCRAT   |48   |0.0                |0.0                 |0.0               |-0.6533958333333335  |
# |LOCAL:MAYOR            |REPUBLICAN |18   |0.0                |0.0                 |0.0               |1.2809444444444444   |
# |LOCAL:OTHER            |OTHER      |544  |0.0                |0.0                 |0.0               |-0.11299264705882352 |
# |LOCAL:OTHER            |DEMOCRAT   |165  |0.0                |0.0                 |0.0               |-0.7868424242424243  |
# |LOCAL:OTHER            |REPUBLICAN |77   |0.0                |0.0                 |0.0               |1.2394285714285713   |
# |LOCAL:PARTY-COMMITTEE  |DEMOCRAT   |5    |0.0                |0.0                 |0.0               |-0.8277999999999999  |
# |LOCAL:PARTY-COMMITTEE  |REPUBLICAN |1    |0.0                |0.0                 |0.0               |1.018                |
# |LOCAL:PUBLIC-DEFENDER  |OTHER      |6    |0.0                |0.0                 |0.0               |-0.48866666666666664 |
# |LOCAL:PUBLIC-DEFENDER  |DEMOCRAT   |2    |0.0                |0.0                 |0.0               |-0.8155              |
# |LOCAL:RECORDER         |DEMOCRAT   |1    |0.0                |0.0                 |0.0               |-0.566               |
# |LOCAL:REGISTER-DEEDS   |DEMOCRAT   |10   |0.0                |0.0                 |0.0               |-0.5815              |
# |LOCAL:REGISTER-DEEDS   |OTHER      |2    |0.0                |0.0                 |0.0               |-0.9495              |
# |LOCAL:REGISTER-PROBATE |DEMOCRAT   |6    |0.0                |0.0                 |0.0               |-0.647               |
# |LOCAL:REGISTER-PROBATE |OTHER      |1    |0.0                |0.0                 |0.0               |-0.411               |
# |LOCAL:REGISTER-PROBATE |REPUBLICAN |1    |0.0                |0.0                 |0.0               |1.019                |
# |LOCAL:SCHOOL-BOARD     |OTHER      |135  |0.0                |0.0                 |0.0               |-0.09748148148148147 |
# |LOCAL:SCHOOL-BOARD     |DEMOCRAT   |12   |0.0                |0.0                 |0.0               |-0.8870833333333333  |
# |LOCAL:SCHOOL-BOARD     |REPUBLICAN |4    |0.0                |0.0                 |0.0               |1.3632499999999999   |
# |LOCAL:SHERIFF          |REPUBLICAN |97   |0.0                |0.0                 |0.0               |1.0533917525773195   |
# |LOCAL:SHERIFF          |DEMOCRAT   |72   |0.0                |0.0                 |0.0               |-0.6736805555555557  |
# |LOCAL:SHERIFF          |OTHER      |62   |0.0                |0.0                 |0.0               |0.37559677419354837  |
# |LOCAL:SOLICITOR        |OTHER      |1    |0.0                |0.0                 |0.0               |1.062                |
# |LOCAL:SUPERVISOR       |OTHER      |133  |0.0                |0.0                 |0.0               |0.08771428571428573  |
# |LOCAL:SUPERVISOR       |REPUBLICAN |71   |0.0                |0.0                 |0.0               |1.3685774647887325   |
# |LOCAL:SUPERVISOR       |DEMOCRAT   |57   |0.0                |0.0                 |0.0               |-0.8787543859649123  |
# |LOCAL:TAX-COLLECTOR    |OTHER      |8    |0.0                |0.0                 |0.0               |0.48400000000000004  |
# |STATE:ATTORNEY         |OTHER      |33   |0.0                |0.0                 |0.0               |0.3953333333333333   |
# |STATE:ATTORNEY         |DEMOCRAT   |3    |0.0                |0.0                 |0.0               |-0.24933333333333332 |
# |STATE:ATTORNEY         |REPUBLICAN |2    |0.0                |0.0                 |0.0               |1.2205               |
# |STATE:ATTORNEYG        |REPUBLICAN |162  |0.0                |0.0                 |0.0               |1.12529012345679     |
# |STATE:ATTORNEYG        |DEMOCRAT   |142  |38069.407464788725 |16704.551971830984  |6947.327535211268 |-0.7780704225352114  |
# |STATE:ATTORNEYG        |OTHER      |19   |0.0                |0.0                 |0.0               |0.29500000000000004  |
# |STATE:BALLOT           |OTHER      |840  |0.0                |0.0                 |0.0               |-0.08590119047619049 |
# |STATE:COMMITTEE        |OTHER      |7932 |6.8689725163893085 |0.0                 |0.0               |0.12519616742309628  |
# |STATE:COMMITTEE        |DEMOCRAT   |400  |0.0                |0.0                 |0.0               |-0.7163124999999999  |
# |STATE:COMMITTEE        |REPUBLICAN |398  |55.46482412060301  |0.0                 |0.0               |1.0542412060301507   |
# |STATE:EDUCATION        |REPUBLICAN |148  |0.0                |0.0                 |0.0               |1.132452702702703    |
# |STATE:EDUCATION        |DEMOCRAT   |133  |0.0                |0.0                 |0.0               |-0.791172932330827   |
# |STATE:EDUCATION        |OTHER      |124  |0.0                |0.0                 |0.0               |0.2345322580645161   |
# |STATE:GOVERNOR         |REPUBLICAN |408  |0.0                |0.0                 |0.0               |1.1751446078431373   |
# |STATE:GOVERNOR         |DEMOCRAT   |323  |0.0                |0.0                 |0.0               |-0.7998947368421054  |
# |STATE:GOVERNOR         |OTHER      |200  |0.0                |0.0                 |0.0               |0.35796000000000006  |
# |STATE:JUDICIAL         |OTHER      |2247 |6.653315531820205  |0.0                 |0.0               |-0.026004895416110365|
# |STATE:JUDICIAL         |REPUBLICAN |429  |37.646433566433565 |0.0                 |0.0               |0.9726433566433567   |
# |STATE:JUDICIAL         |DEMOCRAT   |398  |39.108040201005025 |0.0                 |0.0               |-0.6543894472361809  |
# |STATE:LOCAL            |OTHER      |76   |0.0                |0.0                 |0.0               |-0.36344736842105274 |
# |STATE:LOCAL            |DEMOCRAT   |7    |0.0                |0.0                 |0.0               |-0.6735714285714286  |
# |STATE:LOCAL            |REPUBLICAN |4    |0.0                |0.0                 |0.0               |0.8775               |
# |STATE:LOWER            |REPUBLICAN |15144|202.33205229793978 |155.9425680137348   |4.846804014791337 |1.1483365689381932   |
# |STATE:LOWER            |DEMOCRAT   |15133|673.2176224145907  |428.21112139033903  |88.19904975880526 |-0.7927118879270468  |
# |STATE:LOWER            |OTHER      |2035 |68.5995085995086   |0.0                 |0.0               |0.20844815724815724  |
# |STATE:OFFICE           |REPUBLICAN |737  |0.0                |0.0                 |0.0               |1.113192672998643    |
# |STATE:OFFICE           |DEMOCRAT   |562  |0.0                |0.0                 |0.0               |-0.7967882562277581  |
# |STATE:OFFICE           |OTHER      |288  |0.7638888888888888 |0.0                 |0.0               |-0.039354166666666676|
# |STATE:OTHER            |OTHER      |218  |0.0                |0.0                 |0.0               |0.01748623853211007  |
# |STATE:OTHER            |REPUBLICAN |11   |0.0                |0.0                 |0.0               |0.9586363636363636   |
# |STATE:OTHER            |DEMOCRAT   |8    |0.0                |0.0                 |0.0               |-0.735125            |
# |STATE:OTHER:CONVENTION |OTHER      |8    |0.0                |0.0                 |0.0               |-0.34225             |
# |STATE:SECOFSTATE       |REPUBLICAN |7    |0.0                |0.0                 |0.0               |1.1611428571428573   |
# |STATE:SECOFSTATE       |OTHER      |7    |0.0                |0.0                 |0.0               |0.4042857142857143   |
# |STATE:SECOFSTATE       |DEMOCRAT   |1    |0.0                |0.0                 |0.0               |-0.575               |
# |STATE:TREASURER        |REPUBLICAN |142  |0.0                |0.0                 |0.0               |1.1142676056338026   |
# |STATE:TREASURER        |DEMOCRAT   |118  |0.0                |0.0                 |0.0               |-0.7870593220338985  |
# +-----------------------+-----------+-----+-------------------+--------------------+------------------+---------------------+
# only showing top 100 rows

# %%
class_balance_pd = class_balance.toPandas()

ax = class_balance_pd.plot(
    kind="bar",
    x="party_group",
    y="rows",
    legend=False,
    title=f"DIME Aggregate Party Class Balance ({START_YEAR}-{END_YEAR})"
)
ax.set_xlabel("Party")
ax.set_ylabel("Rows")
# Out:
# Text(0, 0.5, 'Rows')

# %%
eda_cols = [
    "party_group", "year", "recipient_type_group", "state_group", "seat_group", "district_group", "gender_group",
    "total_receipts", "total_indiv_contribs", "total_pac_contribs", "num_givers",
    "primary_vote_pct", "general_vote_pct", "recipient_cfscore"
] + [c for c in model_df.columns if c.startswith("ctx_")]

eda_cols = [c for c in eda_cols if c in model_df.columns]

total_rows_for_missing = model_df.count() if RUN_EXPENSIVE_COUNTS else None

missing_exprs = [
    F.sum(F.when(F.col(c).isNull(), 1).otherwise(0)).alias(c)
    for c in eda_cols
]

missing_counts = model_df.select(*missing_exprs)
missing_long = []
row = missing_counts.collect()[0].asDict()

for c in eda_cols:
    missing_n = int(row[c])
    missing_pct = None if total_rows_for_missing is None else float(missing_n / total_rows_for_missing)
    missing_long.append((c, missing_n, missing_pct))

missing_df = spark.createDataFrame(missing_long, ["column", "missing_count", "missing_pct"])
show_df(missing_df.orderBy(F.desc("missing_count")), 100)
# Out:
# +--------------------+-------------+-----------+
# |column              |missing_count|missing_pct|
# +--------------------+-------------+-----------+
# |year                |0            |0.0        |
# |recipient_cfscore   |0            |0.0        |
# |num_givers          |0            |0.0        |
# |total_pac_contribs  |0            |0.0        |
# |total_indiv_contribs|0            |0.0        |
# |total_receipts      |0            |0.0        |
# |gender_group        |0            |0.0        |
# |district_group      |0            |0.0        |
# |seat_group          |0            |0.0        |
# |state_group         |0            |0.0        |
# |recipient_type_group|0            |0.0        |
# |party_group         |0            |0.0        |
# +--------------------+-------------+-----------+

# %%
numeric_eda_cols = [
    "total_receipts", "total_indiv_contribs", "total_pac_contribs", "num_givers",
    "primary_vote_pct", "general_vote_pct", "recipient_cfscore",
    "log_total_receipts", "log_total_indiv_contribs", "log_total_pac_contribs", "log_num_givers"
]
numeric_eda_cols = [c for c in numeric_eda_cols if c in model_df.columns]

show_df(
    model_df.select(numeric_eda_cols).summary("count", "mean", "stddev", "min", "25%", "50%", "75%", "max"),
    100,
    truncate=False
)

for c in [c for c in ["total_receipts", "total_indiv_contribs", "total_pac_contribs", "num_givers"] if c in model_df.columns]:
    qs = model_df.approxQuantile(c, [0.0, 0.25, 0.5, 0.75, 0.95, 0.99, 1.0], 0.01)
    print(c, "quantiles:", qs)
# Out:
# +-------+--------------------+--------------------+------------------+------------------+-------------------+------------------+------------------------+----------------------+------------------+
# |summary|total_receipts      |total_indiv_contribs|total_pac_contribs|num_givers        |recipient_cfscore  |log_total_receipts|log_total_indiv_contribs|log_total_pac_contribs|log_num_givers    |
# +-------+--------------------+--------------------+------------------+------------------+-------------------+------------------+------------------------+----------------------+------------------+
# |count  |86861               |86861               |86861             |86861             |86861              |86861             |86861                   |86861                 |86861             |
# |mean   |565612.632806553    |236812.30208781848  |54082.09690908462 |1255.0838350928495|0.12814746549084163|2.823059949960238 |2.4225811152910857      |1.3412944634614683    |3.8809602981596525|
# |stddev |1.0204497743938802E7|4508883.5519742975  |802794.0074309482 |24103.165019935335|1.0579441601660315 |5.164374826765443 |4.694680365581755       |3.6482569519771264    |1.9938301393750035|
# |min    |-600000.0           |-53908.14           |-2000.0           |1.0               |-5.76              |0.0               |0.0                     |0.0                   |0.6931471805599453|
# |25%    |0.0                 |0.0                 |0.0               |10.0              |-0.849             |0.0               |0.0                     |0.0                   |2.3978952727983707|
# |50%    |0.0                 |0.0                 |0.0               |47.0              |-0.131             |0.0               |0.0                     |0.0                   |3.8712010109078907|
# |75%    |0.0                 |0.0                 |0.0               |169.0             |1.132              |0.0               |0.0                     |0.0                   |5.135798437050262 |
# |max    |1.12459294473E9     |5.04504091E8        |7.670484E7        |4179290.0         |5.762              |20.84068698111019 |20.039086508726037      |18.155475380382256    |15.24565217288943 |
# +-------+--------------------+--------------------+------------------+------------------+-------------------+------------------+------------------------+----------------------+------------------+
#
# total_receipts quantiles: [-600000.0, 0.0, 0.0, 0.0, 852512.89, 1124592944.73, 1124592944.73]
# total_indiv_contribs quantiles: [-53908.14, 0.0, 0.0, 0.0, 305000.0, 504504091.0, 504504091.0]
# total_pac_contribs quantiles: [-2000.0, 0.0, 0.0, 0.0, 63143.19, 76704840.0, 76704840.0]
# num_givers quantiles: [1.0, 10.0, 46.0, 161.0, 1085.0, 4179290.0, 4179290.0]

# %% [markdown]
# ## Numeric feature quality check
#
# Some DIME aggregate fields are extremely sparse, skewed, or unavailable for many recipient types. This diagnostic identifies:
#
# - all-zero / constant fields
# - negative finance values, which usually represent refunds or accounting reversals
# - very large outliers
# - fields that should be excluded from modeling if they have no variance

# %%
quality_cols = [
    "total_receipts", "total_indiv_contribs", "total_pac_contribs", "num_givers",
    "primary_vote_pct", "general_vote_pct", "recipient_cfscore",
    "log_total_receipts", "log_total_indiv_contribs", "log_total_pac_contribs", "log_num_givers",    "fec_log_adjusted_receipts", "fec_log_adjusted_disb", "fec_spend_to_receipts_ratio",
    "fec_indiv_contrib_share", "fec_committee_contrib_share", "fec_party_contrib_share",
    "fec_ctx_candidate_count", "fec_ctx_avg_adjusted_receipts", "fec_ctx_avg_num_linked_committees"
]
quality_cols = [c for c in quality_cols if c in model_df.columns]

quality_rows = []
for c in quality_cols:
    stats = (
        model_df
        .agg(
            F.count(F.col(c)).alias("non_null_count"),
            F.sum(F.when(F.col(c).isNull(), 1).otherwise(0)).alias("missing_count"),
            F.sum(F.when(F.col(c) == 0, 1).otherwise(0)).alias("zero_count"),
            F.sum(F.when(F.col(c) < 0, 1).otherwise(0)).alias("negative_count"),
            F.approx_count_distinct(F.col(c)).alias("approx_distinct"),
            F.stddev(F.col(c)).alias("stddev"),
            F.min(F.col(c)).alias("min"),
            F.max(F.col(c)).alias("max"),
        )
        .collect()[0]
        .asDict()
    )
    quality_rows.append((
        c,
        int(stats["non_null_count"] or 0),
        int(stats["missing_count"] or 0),
        int(stats["zero_count"] or 0),
        int(stats["negative_count"] or 0),
        int(stats["approx_distinct"] or 0),
        float(stats["stddev"]) if stats["stddev"] is not None else None,
        float(stats["min"]) if stats["min"] is not None else None,
        float(stats["max"]) if stats["max"] is not None else None,
    ))

feature_quality_df = spark.createDataFrame(
    quality_rows,
    ["feature", "non_null_count", "missing_count", "zero_count", "negative_count", "approx_distinct", "stddev", "min", "max"]
)

show_df(feature_quality_df.orderBy(F.asc("stddev")), 100, truncate=False)

print("Likely unusable numeric fields because they are constant or nearly constant:")
show_df(
    feature_quality_df
    .filter((F.col("approx_distinct") <= 1) | (F.col("stddev").isNull()) | (F.col("stddev") == 0))
    .orderBy("feature"),
    100,
    truncate=False
)
# Out:
# +---------------------------------+--------------+-------------+----------+--------------+---------------+--------------------+------------------+------------------+
# |feature                          |non_null_count|missing_count|zero_count|negative_count|approx_distinct|stddev              |min               |max               |
# +---------------------------------+--------------+-------------+----------+--------------+---------------+--------------------+------------------+------------------+
# |fec_ctx_avg_num_linked_committees|86861         |0            |2591      |0             |180            |0.20271805986170766 |0.0               |1.7857142857142858|
# |recipient_cfscore                |86861         |0            |6         |44359         |4288           |1.0579441601660315  |-5.76             |5.762             |
# |log_num_givers                   |86861         |0            |0         |0             |4776           |1.9938301393750035  |0.6931471805599453|15.24565217288943 |
# |log_total_pac_contribs           |86861         |0            |75884     |0             |6936           |3.6482569519771264  |0.0               |18.155475380382256|
# |log_total_indiv_contribs         |86861         |0            |67676     |0             |13676          |4.694680365581755   |0.0               |20.039086508726037|
# |log_total_receipts               |86861         |0            |65864     |0             |19081          |5.164374826765443   |0.0               |20.84068698111019 |
# |fec_ctx_candidate_count          |86861         |0            |2591      |0             |119            |128.9315878357298   |0.0               |424.0             |
# |num_givers                       |86861         |0            |0         |0             |4484           |24103.165019935335  |1.0               |4179290.0         |
# |total_pac_contribs               |86861         |0            |75880     |4             |6816           |802794.0074309482   |-2000.0           |7.670484E7        |
# |total_indiv_contribs             |86861         |0            |67663     |13            |14400          |4508883.5519742975  |-53908.14         |5.04504091E8      |
# |total_receipts                   |86861         |0            |65853     |11            |18371          |1.0204497743938802E7|-600000.0         |1.12459294473E9   |
# +---------------------------------+--------------+-------------+----------+--------------+---------------+--------------------+------------------+------------------+
#
# Likely unusable numeric fields because they are constant or nearly constant:
# +-------+--------------+-------------+----------+--------------+---------------+------+---+---+
# |feature|non_null_count|missing_count|zero_count|negative_count|approx_distinct|stddev|min|max|
# +-------+--------------+-------------+----------+--------------+---------------+------+---+---+
# +-------+--------------+-------------+----------+--------------+---------------+------+---+---+

# %%
print("Top rows by total_receipts:")
show_df(
    model_df
    .select("year", "party_group", "recipient_type_group", "state_group", "seat_group",
            "total_receipts", "total_indiv_contribs", "total_pac_contribs", "num_givers", "recipient_cfscore")
    .orderBy(F.desc("total_receipts")),
    20,
    truncate=False
)

print("Negative contribution amount counts:")
negative_summary = model_df.agg(
    F.sum(F.when(F.col("total_receipts") < 0, 1).otherwise(0)).alias("negative_total_receipts_rows"),
    F.sum(F.when(F.col("total_indiv_contribs") < 0, 1).otherwise(0)).alias("negative_indiv_rows"),
    F.sum(F.when(F.col("total_pac_contribs") < 0, 1).otherwise(0)).alias("negative_pac_rows"),
)
show_df(negative_summary, 20)

print("Rows with negative total_receipts:")
show_df(
    model_df
    .filter(F.col("total_receipts") < 0)
    .select("year", "party_group", "recipient_type_group", "state_group", "seat_group",
            "total_receipts", "total_indiv_contribs", "total_pac_contribs", "recipient_cfscore")
    .orderBy("total_receipts"),
    20,
    truncate=False
)
# Out:
# Top rows by total_receipts:
# +----+-----------+--------------------+-----------+-----------------+---------------+--------------------+------------------+----------+-----------------+
# |year|party_group|recipient_type_group|state_group|seat_group       |total_receipts |total_indiv_contribs|total_pac_contribs|num_givers|recipient_cfscore|
# +----+-----------+--------------------+-----------+-----------------+---------------+--------------------+------------------+----------+-----------------+
# |2020|DEMOCRAT   |CANDIDATE           |00         |FEDERAL:PRESIDENT|1.12459294473E9|65062.0             |0.0               |128.0     |-0.873           |
# |2020|DEMOCRAT   |CANDIDATE           |00         |FEDERAL:PRESIDENT|1.07417997603E9|5.04504091E8        |563064.21         |4179290.0 |-1.006           |
# |2020|REPUBLICAN |COMMITTEE_OR_PAC    |DC         |FEDERAL:COMMITTEE|8.9053896324E8 |2.1610038618E8      |692808.5          |919880.0  |1.355            |
# |2020|REPUBLICAN |CANDIDATE           |00         |FEDERAL:PRESIDENT|7.4435022926E8 |2.48186618E8        |846953.3          |2029054.0 |1.563            |
# |2024|DEMOCRAT   |COMMITTEE_OR_PAC    |DC         |FEDERAL:COMMITTEE|6.8364909681E8 |1.037232204E8       |1236125.25        |696876.0  |-1.044           |
# |2024|OTHER      |COMMITTEE_OR_PAC    |DC         |FEDERAL:COMMITTEE|5.5928996596E8 |6255.0              |5000.0            |437.0     |-1.038           |
# |2024|REPUBLICAN |CANDIDATE           |00         |FEDERAL:PRESIDENT|4.958532703E8  |4.394301997E7       |341116.46         |759751.0  |1.563            |
# |2020|DEMOCRAT   |COMMITTEE_OR_PAC    |DC         |FEDERAL:COMMITTEE|4.9172734443E8 |1.1417795083E8      |1369983.25        |1043865.0 |-1.044           |
# |2024|REPUBLICAN |COMMITTEE_OR_PAC    |DC         |FEDERAL:COMMITTEE|4.7576400828E8 |8.726968009E7       |487750.0          |408051.0  |1.355            |
# |2020|OTHER      |COMMITTEE_OR_PAC    |VA         |FEDERAL:COMMITTEE|4.7535350674E8 |3.8327252698E8      |4661962.35        |1389.0    |1.12             |
# |2024|OTHER      |COMMITTEE_OR_PAC    |MA         |FEDERAL:COMMITTEE|4.1050993112E8 |3.8379714998E8      |1.475941125E7     |297.0     |1.299            |
# |2024|DEMOCRAT   |COMMITTEE_OR_PAC    |DC         |FEDERAL:COMMITTEE|3.8996827837E8 |2.7116204521E8      |7.367901321E7     |119650.0  |-0.996           |
# |2020|DEMOCRAT   |CANDIDATE           |00         |FEDERAL:PRESIDENT|3.84E8         |3.84E8              |0.0               |2.0       |-1.999           |
# |2020|DEMOCRAT   |COMMITTEE_OR_PAC    |DC         |FEDERAL:COMMITTEE|3.7229374673E8 |2.6920637963E8      |6.666399721E7     |226461.0  |-0.996           |
# |2022|DEMOCRAT   |COMMITTEE_OR_PAC    |DC         |FEDERAL:COMMITTEE|3.6296711114E8 |1.1651518531E8      |5.597267953E7     |621831.0  |-0.888           |
# |2020|DEMOCRAT   |CANDIDATE           |00         |FEDERAL:PRESIDENT|3.5304195553E8 |1213511.0           |0.0               |59468.0   |-0.97            |
# |2020|DEMOCRAT   |COMMITTEE_OR_PAC    |DC         |FEDERAL:COMMITTEE|3.4578450352E8 |1.1094128499E8      |5.318161053E7     |677553.0  |-0.888           |
# |2024|DEMOCRAT   |COMMITTEE_OR_PAC    |DC         |FEDERAL:COMMITTEE|3.3993585288E8 |1.0551795648E8      |6.032739969E7     |470835.0  |-0.888           |
# |2022|DEMOCRAT   |COMMITTEE_OR_PAC    |DC         |FEDERAL:COMMITTEE|3.3734931985E8 |2.2359370497E8      |6.659623624E7     |103878.0  |-0.996           |
# |2022|REPUBLICAN |COMMITTEE_OR_PAC    |DC         |FEDERAL:COMMITTEE|3.3519620901E8 |1.2346474727E8      |505000.0          |463261.0  |1.355            |
# +----+-----------+--------------------+-----------+-----------------+---------------+--------------------+------------------+----------+-----------------+
# only showing top 20 rows
# Negative contribution amount counts:
# +----------------------------+-------------------+-----------------+
# |negative_total_receipts_rows|negative_indiv_rows|negative_pac_rows|
# +----------------------------+-------------------+-----------------+
# |11                          |13                 |4                |
# +----------------------------+-------------------+-----------------+
#
# Rows with negative total_receipts:
# +----+-----------+--------------------+-----------+-----------------+--------------+--------------------+------------------+-----------------+
# |year|party_group|recipient_type_group|state_group|seat_group       |total_receipts|total_indiv_contribs|total_pac_contribs|recipient_cfscore|
# +----+-----------+--------------------+-----------+-----------------+--------------+--------------------+------------------+-----------------+
# |2022|REPUBLICAN |CANDIDATE           |PA         |FEDERAL:HOUSE    |-600000.0     |0.0                 |0.0               |0.52             |
# |2024|REPUBLICAN |CANDIDATE           |FL         |FEDERAL:HOUSE    |-185240.76    |0.0                 |0.0               |1.562            |
# |2022|REPUBLICAN |CANDIDATE           |MD         |FEDERAL:HOUSE    |-36839.33     |-51150.0            |0.0               |1.512            |
# |2022|REPUBLICAN |COMMITTEE_OR_PAC    |GA         |FEDERAL:COMMITTEE|-8721.95      |0.0                 |0.0               |0.511            |
# |2018|REPUBLICAN |CANDIDATE           |MD         |FEDERAL:SENATE   |-2661.0       |-2700.0             |0.0               |1.01             |
# |2024|REPUBLICAN |CANDIDATE           |RI         |FEDERAL:HOUSE    |-2350.0       |-2250.0             |0.0               |0.981            |
# |2024|REPUBLICAN |CANDIDATE           |CO         |FEDERAL:SENATE   |-1686.1       |-1697.55            |0.0               |1.389            |
# |2024|REPUBLICAN |COMMITTEE_OR_PAC    |VA         |FEDERAL:COMMITTEE|-1240.3       |-1810.0             |0.0               |1.458            |
# |2022|REPUBLICAN |CANDIDATE           |VA         |FEDERAL:HOUSE    |-214.05       |0.0                 |0.0               |1.293            |
# |2022|OTHER      |COMMITTEE_OR_PAC    |LA         |FEDERAL:COMMITTEE|-23.0         |0.0                 |0.0               |-1.034           |
# |2022|REPUBLICAN |CANDIDATE           |PA         |FEDERAL:HOUSE    |-3.2          |0.0                 |0.0               |1.343            |
# +----+-----------+--------------------+-----------+-----------------+--------------+--------------------+------------------+-----------------+

# %%
if MAKE_GRAPHS:
    # Year-by-party trend
    year_party_pd = eda_year_party.select("year", "party_group", "rows").toPandas()
    if len(year_party_pd) > 0:
        pivot_year = year_party_pd.pivot(index="year", columns="party_group", values="rows").fillna(0)
        ax = pivot_year.plot(kind="line", marker="o", title="Rows by Year and Party")
        ax.set_xlabel("Year")
        ax.set_ylabel("Rows")
        plt.tight_layout()
        plt.show()

    # Log receipts by party
    sample_fraction = 0.25
    receipts_pd = (
        model_df
        .select("party_group", "log_total_receipts")
        .sample(False, sample_fraction, seed=RANDOM_SEED)
        .toPandas()
    )
    if len(receipts_pd) > 0:
        ax = receipts_pd.boxplot(column="log_total_receipts", by="party_group")
        ax.set_title("Log Total Receipts by Party")
        ax.set_xlabel("Party")
        ax.set_ylabel("log1p(total_receipts)")
        plt.suptitle("")
        plt.tight_layout()
        plt.show()

    # Seat group stacked party distribution
    seat_party_pd = eda_seat_party.select("seat_group", "party_group", "rows").toPandas()
    if len(seat_party_pd) > 0:
        top_seats = seat_party_pd.groupby("seat_group")["rows"].sum().sort_values(ascending=False).head(10).index
        seat_plot = seat_party_pd[seat_party_pd["seat_group"].isin(top_seats)]
        pivot_seat = seat_plot.pivot_table(index="seat_group", columns="party_group", values="rows", aggfunc="sum").fillna(0)
        ax = pivot_seat.plot(kind="bar", stacked=True, title="Top Seat Groups by Party")
        ax.set_xlabel("Seat group")
        ax.set_ylabel("Rows")
        plt.tight_layout()
        plt.show()

# %%
categorical_eda_cols = [
    "recipient_type_group",
    "state_group",
    "seat_group",
    "district_group",
    "gender_group",
]
categorical_eda_cols = [c for c in categorical_eda_cols if c in model_df.columns]

cardinality_rows = []
for c in categorical_eda_cols:
    n_distinct = model_df.select(c).distinct().count()
    cardinality_rows.append((c, int(n_distinct)))

cardinality_df = spark.createDataFrame(cardinality_rows, ["categorical_column", "distinct_values"])
show_df(cardinality_df.orderBy(F.desc("distinct_values")), 50)

for c in categorical_eda_cols:
    print(f"Top values for {c}:")
    show_df(model_df.groupBy(c).count().orderBy(F.desc("count")), 15)
# Out:
# +--------------------+---------------+
# |categorical_column  |distinct_values|
# +--------------------+---------------+
# |district_group      |5901           |
# |state_group         |58             |
# |seat_group          |45             |
# |recipient_type_group|2              |
# |gender_group        |1              |
# +--------------------+---------------+
#
# Top values for recipient_type_group:
# +--------------------+-----+
# |recipient_type_group|count|
# +--------------------+-----+
# |CANDIDATE           |65047|
# |COMMITTEE_OR_PAC    |21814|
# +--------------------+-----+
#
# Top values for state_group:
# +-----------+-----+
# |state_group|count|
# +-----------+-----+
# |TX         |8156 |
# |CA         |7915 |
# |NY         |3763 |
# |VA         |3010 |
# |FL         |2537 |
# |MISSING    |2377 |
# |PA         |2336 |
# |IL         |2282 |
# |GA         |2214 |
# |DC         |2183 |
# |NC         |2158 |
# |MI         |2071 |
# |MO         |2038 |
# |MA         |2037 |
# |MD         |1856 |
# +-----------+-----+
# only showing top 15 rows
# Top values for seat_group:
# +-----------------+-----+
# |seat_group       |count|
# +-----------------+-----+
# |STATE:LOWER      |32312|
# |FEDERAL:COMMITTEE|11646|
# |STATE:UPPER      |10864|
# |FEDERAL:HOUSE    |9251 |
# |STATE:COMMITTEE  |8730 |
# |STATE:JUDICIAL   |3074 |
# |FEDERAL:SENATE   |1613 |
# |STATE:OFFICE     |1587 |
# |LOCAL:COUNCIL    |1293 |
# |STATE:GOVERNOR   |931  |
# |STATE:BALLOT     |840  |
# |LOCAL:OTHER      |786  |
# |FEDERAL:527      |547  |
# |STATE:UNKNOWN    |439  |
# |STATE:EDUCATION  |405  |
# +-----------------+-----+
# only showing top 15 rows
# Top values for district_group:
# +--------------+-----+
# |district_group|count|
# +--------------+-----+
# |MISSING       |30380|
# |PRES          |209  |
# |2             |198  |
# |1             |175  |
# |4             |141  |
# |3             |118  |
# |5             |117  |
# |6             |94   |
# |9             |86   |
# |7             |83   |
# |NH-2          |71   |
# |11            |70   |
# |10            |68   |
# |8             |65   |
# |NH-6          |65   |
# +--------------+-----+
# only showing top 15 rows
# Top values for gender_group:
# +------------+-----+
# |gender_group|count|
# +------------+-----+
# |MISSING     |86861|
# +------------+-----+

# %%
party_year_pct = (
    model_df
    .groupBy("year", "party_group")
    .count()
    .withColumn("year_total", F.sum("count").over(Window.partitionBy("year")))
    .withColumn("party_pct", F.col("count") / F.col("year_total"))
    .orderBy("year", "party_group")
)
show_df(party_year_pct, 200)

state_party_pct = (
    model_df
    .groupBy("state_group", "party_group")
    .count()
    .withColumn("state_total", F.sum("count").over(Window.partitionBy("state_group")))
    .withColumn("party_pct", F.col("count") / F.col("state_total"))
    .filter(F.col("state_total") >= 20)
    .orderBy(F.desc("state_total"), "state_group", "party_group")
)
show_df(state_party_pct, 200)

seat_party_pct = (
    model_df
    .groupBy("seat_group", "party_group")
    .count()
    .withColumn("seat_total", F.sum("count").over(Window.partitionBy("seat_group")))
    .withColumn("party_pct", F.col("count") / F.col("seat_total"))
    .filter(F.col("seat_total") >= 20)
    .orderBy(F.desc("seat_total"), "seat_group", "party_group")
)
show_df(seat_party_pct, 200)
# Out:
# +----+-----------+-----+----------+-------------------+
# |year|party_group|count|year_total|party_pct          |
# +----+-----------+-----+----------+-------------------+
# |2018|DEMOCRAT   |10748|32213     |0.3336541147983733 |
# |2018|OTHER      |11836|32213     |0.36742929873032626|
# |2018|REPUBLICAN |9629 |32213     |0.2989165864713004 |
# |2020|DEMOCRAT   |9209 |24336     |0.3784105851413544 |
# |2020|OTHER      |6331 |24336     |0.26014957264957267|
# |2020|REPUBLICAN |8796 |24336     |0.361439842209073  |
# |2022|DEMOCRAT   |8177 |23557     |0.3471155070679628 |
# |2022|OTHER      |5762 |23557     |0.244598208600416  |
# |2022|REPUBLICAN |9618 |23557     |0.4082862843316212 |
# |2024|DEMOCRAT   |1799 |6755      |0.26632124352331604|
# |2024|OTHER      |3277 |6755      |0.4851221317542561 |
# |2024|REPUBLICAN |1679 |6755      |0.24855662472242784|
# +----+-----------+-----+----------+-------------------+
#
# +-----------+-----------+-----+-----------+-------------------+
# |state_group|party_group|count|state_total|party_pct          |
# +-----------+-----------+-----+-----------+-------------------+
# |TX         |DEMOCRAT   |1205 |8156       |0.14774399215301617|
# |TX         |OTHER      |5633 |8156       |0.6906571848945562 |
# |TX         |REPUBLICAN |1318 |8156       |0.16159882295242767|
# |CA         |DEMOCRAT   |1873 |7915       |0.2366392924826279 |
# |CA         |OTHER      |4937 |7915       |0.6237523689197726 |
# |CA         |REPUBLICAN |1105 |7915       |0.1396083385975995 |
# |NY         |DEMOCRAT   |1199 |3763       |0.31862875365399945|
# |NY         |OTHER      |1951 |3763       |0.5184693064044645 |
# |NY         |REPUBLICAN |613  |3763       |0.162901939941536  |
# |VA         |DEMOCRAT   |853  |3010       |0.28338870431893687|
# |VA         |OTHER      |1237 |3010       |0.41096345514950167|
# |VA         |REPUBLICAN |920  |3010       |0.30564784053156147|
# |FL         |DEMOCRAT   |990  |2537       |0.390224674812771  |
# |FL         |OTHER      |490  |2537       |0.19314150571541192|
# |FL         |REPUBLICAN |1057 |2537       |0.4166338194718171 |
# |MISSING    |DEMOCRAT   |68   |2377       |0.02860748843079512|
# |MISSING    |OTHER      |2233 |2377       |0.9394194362641985 |
# |MISSING    |REPUBLICAN |76   |2377       |0.03197307530500631|
# |PA         |DEMOCRAT   |1048 |2336       |0.4486301369863014 |
# |PA         |OTHER      |284  |2336       |0.12157534246575342|
# |PA         |REPUBLICAN |1004 |2336       |0.4297945205479452 |
# |IL         |DEMOCRAT   |1026 |2282       |0.44960560911481157|
# |IL         |OTHER      |549  |2282       |0.24057843996494302|
# |IL         |REPUBLICAN |707  |2282       |0.3098159509202454 |
# |GA         |DEMOCRAT   |797  |2214       |0.35998193315266486|
# |GA         |OTHER      |438  |2214       |0.1978319783197832 |
# |GA         |REPUBLICAN |979  |2214       |0.4421860885275519 |
# |DC         |DEMOCRAT   |350  |2183       |0.1603298213467705 |
# |DC         |OTHER      |1734 |2183       |0.7943197434722858 |
# |DC         |REPUBLICAN |99   |2183       |0.04535043518094366|
# |NC         |DEMOCRAT   |770  |2158       |0.3568118628359592 |
# |NC         |OTHER      |531  |2158       |0.24606116774791473|
# |NC         |REPUBLICAN |857  |2158       |0.397126969416126  |
# |MI         |DEMOCRAT   |936  |2071       |0.4519555770159343 |
# |MI         |OTHER      |370  |2071       |0.17865765330758088|
# |MI         |REPUBLICAN |765  |2071       |0.3693867696764848 |
# |MO         |DEMOCRAT   |690  |2038       |0.338567222767419  |
# |MO         |OTHER      |414  |2038       |0.20314033366045142|
# |MO         |REPUBLICAN |934  |2038       |0.45829244357212956|
# |MA         |DEMOCRAT   |1164 |2037       |0.5714285714285714 |
# |MA         |OTHER      |502  |2037       |0.24644084437898872|
# |MA         |REPUBLICAN |371  |2037       |0.18213058419243985|
# |MD         |DEMOCRAT   |1037 |1856       |0.5587284482758621 |
# |MD         |OTHER      |270  |1856       |0.14547413793103448|
# |MD         |REPUBLICAN |549  |1856       |0.2957974137931034 |
# |OH         |DEMOCRAT   |666  |1803       |0.36938435940099834|
# |OH         |OTHER      |379  |1803       |0.21020521353300056|
# |OH         |REPUBLICAN |758  |1803       |0.4204104270660011 |
# |WA         |DEMOCRAT   |641  |1673       |0.3831440526001195 |
# |WA         |OTHER      |491  |1673       |0.29348475791990436|
# |WA         |REPUBLICAN |541  |1673       |0.3233711894799761 |
# |MN         |DEMOCRAT   |817  |1628       |0.5018427518427518 |
# |MN         |OTHER      |112  |1628       |0.0687960687960688 |
# |MN         |REPUBLICAN |699  |1628       |0.42936117936117935|
# |WI         |DEMOCRAT   |582  |1558       |0.3735558408215661 |
# |WI         |OTHER      |406  |1558       |0.2605905006418485 |
# |WI         |REPUBLICAN |570  |1558       |0.36585365853658536|
# |KY         |DEMOCRAT   |561  |1499       |0.3742494996664443 |
# |KY         |OTHER      |260  |1499       |0.1734489659773182 |
# |KY         |REPUBLICAN |678  |1499       |0.4523015343562375 |
# |CT         |DEMOCRAT   |626  |1453       |0.43083275980729524|
# |CT         |OTHER      |265  |1453       |0.182381280110117  |
# |CT         |REPUBLICAN |562  |1453       |0.38678596008258775|
# |OK         |DEMOCRAT   |384  |1356       |0.2831858407079646 |
# |OK         |OTHER      |106  |1356       |0.07817109144542773|
# |OK         |REPUBLICAN |866  |1356       |0.6386430678466076 |
# |CO         |DEMOCRAT   |559  |1320       |0.42348484848484846|
# |CO         |OTHER      |298  |1320       |0.22575757575757577|
# |CO         |REPUBLICAN |463  |1320       |0.35075757575757577|
# |SC         |DEMOCRAT   |464  |1305       |0.35555555555555557|
# |SC         |OTHER      |109  |1305       |0.08352490421455938|
# |SC         |REPUBLICAN |732  |1305       |0.5609195402298851 |
# |ME         |DEMOCRAT   |582  |1291       |0.45081332300542215|
# |ME         |OTHER      |160  |1291       |0.12393493415956623|
# |ME         |REPUBLICAN |549  |1291       |0.4252517428350116 |
# |AL         |DEMOCRAT   |401  |1279       |0.31352619233776385|
# |AL         |OTHER      |96   |1279       |0.07505863956215794|
# |AL         |REPUBLICAN |782  |1279       |0.6114151681000782 |
# |IN         |DEMOCRAT   |500  |1272       |0.39308176100628933|
# |IN         |OTHER      |101  |1272       |0.07940251572327044|
# |IN         |REPUBLICAN |671  |1272       |0.5275157232704403 |
# |NH         |DEMOCRAT   |670  |1234       |0.5429497568881686 |
# |NH         |OTHER      |43   |1234       |0.03484602917341977|
# |NH         |REPUBLICAN |521  |1234       |0.4222042139384117 |
# |AZ         |DEMOCRAT   |462  |1192       |0.3875838926174497 |
# |AZ         |OTHER      |200  |1192       |0.16778523489932887|
# |AZ         |REPUBLICAN |530  |1192       |0.4446308724832215 |
# |KS         |DEMOCRAT   |421  |1145       |0.36768558951965064|
# |KS         |OTHER      |59   |1145       |0.05152838427947598|
# |KS         |REPUBLICAN |665  |1145       |0.5807860262008734 |
# |TN         |DEMOCRAT   |387  |1135       |0.3409691629955947 |
# |TN         |OTHER      |125  |1135       |0.11013215859030837|
# |TN         |REPUBLICAN |623  |1135       |0.5488986784140969 |
# |IA         |DEMOCRAT   |525  |1132       |0.4637809187279152 |
# |IA         |OTHER      |64   |1132       |0.05653710247349823|
# |IA         |REPUBLICAN |543  |1132       |0.4796819787985866 |
# |LA         |DEMOCRAT   |434  |1126       |0.38543516873889877|
# |LA         |OTHER      |107  |1126       |0.09502664298401421|
# |LA         |REPUBLICAN |585  |1126       |0.5195381882770871 |
# |WV         |DEMOCRAT   |446  |1086       |0.4106813996316759 |
# |WV         |OTHER      |80   |1086       |0.07366482504604052|
# |WV         |REPUBLICAN |560  |1086       |0.5156537753222836 |
# |UT         |DEMOCRAT   |289  |1063       |0.2718720602069614 |
# |UT         |OTHER      |182  |1063       |0.17121354656632173|
# |UT         |REPUBLICAN |592  |1063       |0.5569143932267169 |
# |NJ         |DEMOCRAT   |516  |1060       |0.4867924528301887 |
# |NJ         |OTHER      |172  |1060       |0.16226415094339622|
# |NJ         |REPUBLICAN |372  |1060       |0.35094339622641507|
# |MT         |DEMOCRAT   |397  |1057       |0.37559129612109743|
# |MT         |OTHER      |140  |1057       |0.13245033112582782|
# |MT         |REPUBLICAN |520  |1057       |0.49195837275307475|
# |OR         |DEMOCRAT   |453  |1014       |0.4467455621301775 |
# |OR         |OTHER      |198  |1014       |0.1952662721893491 |
# |OR         |REPUBLICAN |363  |1014       |0.35798816568047337|
# |NM         |DEMOCRAT   |459  |970        |0.4731958762886598 |
# |NM         |OTHER      |150  |970        |0.15463917525773196|
# |NM         |REPUBLICAN |361  |970        |0.37216494845360826|
# |AR         |DEMOCRAT   |265  |883        |0.3001132502831257 |
# |AR         |OTHER      |104  |883        |0.11778029445073612|
# |AR         |REPUBLICAN |514  |883        |0.5821064552661381 |
# |ID         |DEMOCRAT   |215  |869        |0.2474108170310702 |
# |ID         |OTHER      |57   |869        |0.06559263521288838|
# |ID         |REPUBLICAN |597  |869        |0.6869965477560415 |
# |RI         |DEMOCRAT   |571  |869        |0.6570771001150748 |
# |RI         |OTHER      |107  |869        |0.12313003452243959|
# |RI         |REPUBLICAN |191  |869        |0.21979286536248563|
# |MS         |DEMOCRAT   |266  |863        |0.3082271147161066 |
# |MS         |OTHER      |132  |863        |0.15295480880648898|
# |MS         |REPUBLICAN |465  |863        |0.5388180764774044 |
# |VT         |DEMOCRAT   |512  |830        |0.6168674698795181 |
# |VT         |OTHER      |62   |830        |0.0746987951807229 |
# |VT         |REPUBLICAN |256  |830        |0.30843373493975906|
# |NV         |DEMOCRAT   |314  |810        |0.38765432098765434|
# |NV         |OTHER      |136  |810        |0.16790123456790124|
# |NV         |REPUBLICAN |360  |810        |0.4444444444444444 |
# |HI         |DEMOCRAT   |433  |653        |0.663093415007657  |
# |HI         |OTHER      |66   |653        |0.10107197549770292|
# |HI         |REPUBLICAN |154  |653        |0.23583460949464014|
# |SD         |DEMOCRAT   |179  |653        |0.27411944869831545|
# |SD         |OTHER      |51   |653        |0.0781010719754977 |
# |SD         |REPUBLICAN |423  |653        |0.6477794793261868 |
# |WY         |DEMOCRAT   |117  |580        |0.20172413793103447|
# |WY         |OTHER      |42   |580        |0.07241379310344828|
# |WY         |REPUBLICAN |421  |580        |0.7258620689655172 |
# |DE         |DEMOCRAT   |283  |558        |0.507168458781362  |
# |DE         |OTHER      |89   |558        |0.15949820788530467|
# |DE         |REPUBLICAN |186  |558        |0.3333333333333333 |
# |AK         |DEMOCRAT   |166  |528        |0.3143939393939394 |
# |AK         |OTHER      |103  |528        |0.19507575757575757|
# |AK         |REPUBLICAN |259  |528        |0.49053030303030304|
# |ND         |DEMOCRAT   |171  |505        |0.33861386138613864|
# |ND         |OTHER      |29   |505        |0.05742574257425743|
# |ND         |REPUBLICAN |305  |505        |0.6039603960396039 |
# |NE         |DEMOCRAT   |56   |393        |0.14249363867684478|
# |NE         |OTHER      |271  |393        |0.6895674300254453 |
# |NE         |REPUBLICAN |66   |393        |0.16793893129770993|
# |00         |DEMOCRAT   |106  |209        |0.507177033492823  |
# |00         |OTHER      |58   |209        |0.27751196172248804|
# |00         |REPUBLICAN |45   |209        |0.215311004784689  |
# |PR         |DEMOCRAT   |9    |31         |0.2903225806451613 |
# |PR         |OTHER      |20   |31         |0.6451612903225806 |
# |PR         |REPUBLICAN |2    |31         |0.06451612903225806|
# |GU         |DEMOCRAT   |13   |20         |0.65               |
# |GU         |REPUBLICAN |7    |20         |0.35               |
# +-----------+-----------+-----+-----------+-------------------+
#
# +-----------------------+-----------+-----+----------+--------------------+
# |seat_group             |party_group|count|seat_total|party_pct           |
# +-----------------------+-----------+-----+----------+--------------------+
# |STATE:LOWER            |DEMOCRAT   |15133|32312     |0.4683399356276306  |
# |STATE:LOWER            |OTHER      |2035 |32312     |0.0629796979450359  |
# |STATE:LOWER            |REPUBLICAN |15144|32312     |0.4686803664273335  |
# |FEDERAL:COMMITTEE      |DEMOCRAT   |1712 |11646     |0.14700326292289198 |
# |FEDERAL:COMMITTEE      |OTHER      |8436 |11646     |0.7243688820195775  |
# |FEDERAL:COMMITTEE      |REPUBLICAN |1498 |11646     |0.1286278550575305  |
# |STATE:UPPER            |DEMOCRAT   |4817 |10864     |0.44339101620029453 |
# |STATE:UPPER            |OTHER      |848  |10864     |0.0780559646539028  |
# |STATE:UPPER            |REPUBLICAN |5199 |10864     |0.47855301914580267 |
# |FEDERAL:HOUSE          |DEMOCRAT   |4789 |9251      |0.5176737649983786  |
# |FEDERAL:HOUSE          |OTHER      |274  |9251      |0.029618419630310238|
# |FEDERAL:HOUSE          |REPUBLICAN |4188 |9251      |0.4527078153713112  |
# |STATE:COMMITTEE        |DEMOCRAT   |400  |8730      |0.045819014891179836|
# |STATE:COMMITTEE        |OTHER      |7932 |8730      |0.9085910652920962  |
# |STATE:COMMITTEE        |REPUBLICAN |398  |8730      |0.04558991981672394 |
# |STATE:JUDICIAL         |DEMOCRAT   |398  |3074      |0.12947299934938192 |
# |STATE:JUDICIAL         |OTHER      |2247 |3074      |0.7309694209499024  |
# |STATE:JUDICIAL         |REPUBLICAN |429  |3074      |0.13955757970071567 |
# |FEDERAL:SENATE         |DEMOCRAT   |699  |1613      |0.4333539987600744  |
# |FEDERAL:SENATE         |OTHER      |106  |1613      |0.0657160570365778  |
# |FEDERAL:SENATE         |REPUBLICAN |808  |1613      |0.5009299442033478  |
# |STATE:OFFICE           |DEMOCRAT   |562  |1587      |0.354127284183995   |
# |STATE:OFFICE           |OTHER      |288  |1587      |0.18147448015122875 |
# |STATE:OFFICE           |REPUBLICAN |737  |1587      |0.4643982356647763  |
# |LOCAL:COUNCIL          |DEMOCRAT   |111  |1293      |0.08584686774941995 |
# |LOCAL:COUNCIL          |OTHER      |1160 |1293      |0.897138437741686   |
# |LOCAL:COUNCIL          |REPUBLICAN |22   |1293      |0.017014694508894045|
# |STATE:GOVERNOR         |DEMOCRAT   |323  |931       |0.3469387755102041  |
# |STATE:GOVERNOR         |OTHER      |200  |931       |0.21482277121374865 |
# |STATE:GOVERNOR         |REPUBLICAN |408  |931       |0.43823845327604727 |
# |STATE:BALLOT           |OTHER      |840  |840       |1.0                 |
# |LOCAL:OTHER            |DEMOCRAT   |165  |786       |0.2099236641221374  |
# |LOCAL:OTHER            |OTHER      |544  |786       |0.6921119592875318  |
# |LOCAL:OTHER            |REPUBLICAN |77   |786       |0.09796437659033079 |
# |FEDERAL:527            |OTHER      |547  |547       |1.0                 |
# |STATE:UNKNOWN          |DEMOCRAT   |28   |439       |0.06378132118451026 |
# |STATE:UNKNOWN          |OTHER      |384  |439       |0.8747152619589977  |
# |STATE:UNKNOWN          |REPUBLICAN |27   |439       |0.06150341685649203 |
# |STATE:EDUCATION        |DEMOCRAT   |133  |405       |0.32839506172839505 |
# |STATE:EDUCATION        |OTHER      |124  |405       |0.30617283950617286 |
# |STATE:EDUCATION        |REPUBLICAN |148  |405       |0.3654320987654321  |
# |LOCAL:MAYOR            |DEMOCRAT   |48   |358       |0.1340782122905028  |
# |LOCAL:MAYOR            |OTHER      |292  |358       |0.8156424581005587  |
# |LOCAL:MAYOR            |REPUBLICAN |18   |358       |0.05027932960893855 |
# |STATE:ATTORNEYG        |DEMOCRAT   |142  |323       |0.43962848297213625 |
# |STATE:ATTORNEYG        |OTHER      |19   |323       |0.058823529411764705|
# |STATE:ATTORNEYG        |REPUBLICAN |162  |323       |0.5015479876160991  |
# |STATE:TREASURER        |DEMOCRAT   |118  |315       |0.3746031746031746  |
# |STATE:TREASURER        |OTHER      |55   |315       |0.1746031746031746  |
# |STATE:TREASURER        |REPUBLICAN |142  |315       |0.4507936507936508  |
# |LOCAL:SUPERVISOR       |DEMOCRAT   |57   |261       |0.21839080459770116 |
# |LOCAL:SUPERVISOR       |OTHER      |133  |261       |0.5095785440613027  |
# |LOCAL:SUPERVISOR       |REPUBLICAN |71   |261       |0.2720306513409962  |
# |STATE:OTHER            |DEMOCRAT   |8    |237       |0.03375527426160337 |
# |STATE:OTHER            |OTHER      |218  |237       |0.919831223628692   |
# |STATE:OTHER            |REPUBLICAN |11   |237       |0.046413502109704644|
# |LOCAL:SHERIFF          |DEMOCRAT   |72   |231       |0.3116883116883117  |
# |LOCAL:SHERIFF          |OTHER      |62   |231       |0.2683982683982684  |
# |LOCAL:SHERIFF          |REPUBLICAN |97   |231       |0.4199134199134199  |
# |FEDERAL:PRESIDENT      |DEMOCRAT   |105  |209       |0.5023923444976076  |
# |FEDERAL:PRESIDENT      |OTHER      |58   |209       |0.27751196172248804 |
# |FEDERAL:PRESIDENT      |REPUBLICAN |46   |209       |0.22009569377990432 |
# |LOCAL:SCHOOL-BOARD     |DEMOCRAT   |12   |151       |0.07947019867549669 |
# |LOCAL:SCHOOL-BOARD     |OTHER      |135  |151       |0.8940397350993378  |
# |LOCAL:SCHOOL-BOARD     |REPUBLICAN |4    |151       |0.026490066225165563|
# |LOCAL:DISTRICT-ATTORNEY|DEMOCRAT   |28   |107       |0.2616822429906542  |
# |LOCAL:DISTRICT-ATTORNEY|OTHER      |61   |107       |0.5700934579439252  |
# |LOCAL:DISTRICT-ATTORNEY|REPUBLICAN |18   |107       |0.16822429906542055 |
# |STATE:LOCAL            |DEMOCRAT   |7    |87        |0.08045977011494253 |
# |STATE:LOCAL            |OTHER      |76   |87        |0.8735632183908046  |
# |STATE:LOCAL            |REPUBLICAN |4    |87        |0.04597701149425287 |
# |LOCAL:COMMISSIONER     |DEMOCRAT   |12   |54        |0.2222222222222222  |
# |LOCAL:COMMISSIONER     |OTHER      |13   |54        |0.24074074074074073 |
# |LOCAL:COMMISSIONER     |REPUBLICAN |29   |54        |0.5370370370370371  |
# |LOCAL:ATTORNEY         |DEMOCRAT   |16   |45        |0.35555555555555557 |
# |LOCAL:ATTORNEY         |OTHER      |8    |45        |0.17777777777777778 |
# |LOCAL:ATTORNEY         |REPUBLICAN |21   |45        |0.4666666666666667  |
# |STATE:ATTORNEY         |DEMOCRAT   |3    |38        |0.07894736842105263 |
# |STATE:ATTORNEY         |OTHER      |33   |38        |0.868421052631579   |
# |STATE:ATTORNEY         |REPUBLICAN |2    |38        |0.05263157894736842 |
# |LOCAL:COUNTY-EXECUTIVE |DEMOCRAT   |3    |33        |0.09090909090909091 |
# |LOCAL:COUNTY-EXECUTIVE |OTHER      |28   |33        |0.8484848484848485  |
# |LOCAL:COUNTY-EXECUTIVE |REPUBLICAN |2    |33        |0.06060606060606061 |
# +-----------------------+-----------+-----+----------+--------------------+

# %% [markdown]
# # EDA: FEC Feature Summaries
#
# These cells show how the FEC candidate and committee tables add federal campaign-finance context without using the huge DIME `contribDB` file.

# %%
fec_cols = [c for c in model_df.columns if c.startswith("fec_")]
print("FEC columns:", fec_cols)

if fec_cols:
    key_fec_cols = [
        "fec_adjusted_receipts",
        "fec_adjusted_disb",
        "fec_spend_to_receipts_ratio",
        "fec_indiv_contrib_share",
        "fec_committee_contrib_share",
        "fec_party_contrib_share",
        "fec_log_adjusted_receipts",
        "fec_log_adjusted_disb",
        "fec_num_linked_committees",
        "fec_num_principal_committees",
        "fec_num_authorized_committees",
        "fec_ctx_candidate_count",
        "fec_ctx_avg_adjusted_receipts",
        "fec_ctx_avg_indiv_contrib_share",
        "fec_ctx_avg_committee_contrib_share",
        "fec_ctx_avg_num_linked_committees",
    ]
    key_fec_cols = [c for c in key_fec_cols if c in model_df.columns]

    if key_fec_cols:
        show_df(
            model_df.select(key_fec_cols).summary("count", "mean", "stddev", "min", "25%", "50%", "75%", "max"),
            100,
            truncate=False
        )

        fec_by_party = (
            model_df
            .groupBy("party_group")
            .agg(*[F.avg(c).alias(f"avg_{c}") for c in key_fec_cols[:12]])
            .orderBy("party_group")
        )
        show_df(fec_by_party, 50, truncate=False)

        fec_by_year_party = (
            model_df
            .groupBy("year", "party_group")
            .agg(*[F.avg(c).alias(f"avg_{c}") for c in key_fec_cols[:8]])
            .orderBy("year", "party_group")
        )
        show_df(fec_by_year_party, 200, truncate=False)
else:
    print("No FEC columns found. Check ADD_FEC_CONTEXT and FORCE_REBUILD_FINAL_MODEL.")
# Out:
# FEC columns: ['fec_ctx_candidate_count', 'fec_ctx_avg_num_linked_committees', 'fec_ctx_avg_num_principal_committees', 'fec_ctx_avg_num_authorized_committees', 'fec_ctx_avg_sum_linked_cmte_receipts']
# +-------+-----------------------+---------------------------------+
# |summary|fec_ctx_candidate_count|fec_ctx_avg_num_linked_committees|
# +-------+-----------------------+---------------------------------+
# |count  |86861                  |86861                            |
# |mean   |136.1053407167774      |0.8516986449089398               |
# |stddev |128.9315878357298      |0.20271805986170766              |
# |min    |0                      |0.0                              |
# |25%    |38                     |0.7888563049853372               |
# |50%    |91                     |0.8820754716981132               |
# |75%    |165                    |0.9470404984423676               |
# |max    |424                    |1.7857142857142858               |
# +-------+-----------------------+---------------------------------+
#
# +-----------+---------------------------+-------------------------------------+
# |party_group|avg_fec_ctx_candidate_count|avg_fec_ctx_avg_num_linked_committees|
# +-----------+---------------------------+-------------------------------------+
# |DEMOCRAT   |114.78866134366753         |0.8726002635933996                   |
# |OTHER      |193.8483790340366          |0.8053882673034299                   |
# |REPUBLICAN |104.71832312764955         |0.8730387963473494                   |
# +-----------+---------------------------+-------------------------------------+
#
# +----+-----------+---------------------------+-------------------------------------+
# |year|party_group|avg_fec_ctx_candidate_count|avg_fec_ctx_avg_num_linked_committees|
# +----+-----------+---------------------------+-------------------------------------+
# |2018|DEMOCRAT   |100.1309080759211          |0.9100580188468336                   |
# |2018|OTHER      |147.27238932071646         |0.7362265229153063                   |
# |2018|REPUBLICAN |91.42143524768927          |0.9051607426166021                   |
# |2020|DEMOCRAT   |107.21359539580845         |0.8648340386352261                   |
# |2020|OTHER      |242.88264097299006         |0.85944317963803                     |
# |2020|REPUBLICAN |98.45884492951342          |0.8824645519807001                   |
# |2022|DEMOCRAT   |128.468753821695           |0.8393289742222783                   |
# |2022|OTHER      |240.90662964248526         |0.857802923082192                    |
# |2022|REPUBLICAN |115.69058016219589         |0.8384276589871966                   |
# |2024|DEMOCRAT   |178.95664257921067         |0.8397945634064322                   |
# |2024|OTHER      |184.59841318278913         |0.8585965401109796                   |
# |2024|REPUBLICAN |150.91423466349016         |0.8377074991183495                   |
# +----+-----------+---------------------------+-------------------------------------+

# %%
if MAKE_GRAPHS:
    fec_metric = None
    for candidate_metric in ["fec_log_adjusted_receipts", "fec_ctx_avg_adjusted_receipts", "fec_ctx_candidate_count"]:
        if candidate_metric in model_df.columns:
            fec_metric = candidate_metric
            break

    if fec_metric is not None:
        fec_plot_pd = (
            model_df
            .groupBy("year", "party_group")
            .agg(F.avg(fec_metric).alias(f"avg_{fec_metric}"))
            .orderBy("year", "party_group")
            .toPandas()
        )

        if len(fec_plot_pd) > 0:
            pivot_fec = fec_plot_pd.pivot(index="year", columns="party_group", values=f"avg_{fec_metric}").fillna(0)
            ax = pivot_fec.plot(kind="line", marker="o", title=f"Average {fec_metric} by Year and Party")
            ax.set_xlabel("Year")
            ax.set_ylabel(f"Average {fec_metric}")
            plt.tight_layout()
            plt.show()

    if "fec_ctx_avg_indiv_contrib_share" in model_df.columns:
        fec_share_pd = (
            model_df
            .select("party_group", "fec_ctx_avg_indiv_contrib_share")
            .sample(False, 0.25, seed=RANDOM_SEED)
            .toPandas()
        )
        if len(fec_share_pd) > 0:
            ax = fec_share_pd.boxplot(column="fec_ctx_avg_indiv_contrib_share", by="party_group")
            ax.set_title("FEC Individual Contribution Share Context by Party")
            ax.set_xlabel("Party")
            ax.set_ylabel("Context avg individual contribution share")
            plt.suptitle("")
            plt.tight_layout()
            plt.show()

# %%
corr_base = (
    model_df
    .withColumn("is_democrat", F.when(F.col("party_group") == "DEMOCRAT", 1.0).otherwise(0.0))
    .withColumn("is_republican", F.when(F.col("party_group") == "REPUBLICAN", 1.0).otherwise(0.0))
    .withColumn("is_other", F.when(F.col("party_group") == "OTHER", 1.0).otherwise(0.0))
)

corr_numeric_cols = [
    "total_receipts", "total_indiv_contribs", "total_pac_contribs", "num_givers",
    "recipient_cfscore", "log_total_receipts", "log_total_indiv_contribs",
    "log_total_pac_contribs", "log_num_givers",
    "ctx_year_avg_donor_cfscore", "ctx_state_avg_donor_cfscore",
    "ctx_year_left_share", "ctx_year_right_share",
    "ctx_state_left_share", "ctx_state_right_share",
]
corr_numeric_cols = [c for c in corr_numeric_cols if c in corr_base.columns]

corr_rows = []
for c in corr_numeric_cols:
    for target_col in ["is_democrat", "is_republican", "is_other"]:
        try:
            corr_val = corr_base.stat.corr(c, target_col)
            corr_rows.append((c, target_col, float(corr_val) if corr_val is not None else None))
        except Exception as e:
            corr_rows.append((c, target_col, None))

corr_df = spark.createDataFrame(corr_rows, ["feature", "target_indicator", "correlation"])
show_df(corr_df.orderBy(F.desc(F.abs(F.col("correlation")))), 100)
# Out:
# +------------------------+----------------+----------------------+
# |feature                 |target_indicator|correlation           |
# +------------------------+----------------+----------------------+
# |recipient_cfscore       |is_republican   |0.6951069091647852    |
# |recipient_cfscore       |is_democrat     |-0.6351853236744772   |
# |log_num_givers          |is_other        |-0.2440095483946071   |
# |log_num_givers          |is_democrat     |0.19957695472878187   |
# |log_total_receipts      |is_other        |0.07646899849139395   |
# |log_total_indiv_contribs|is_other        |0.07026506832772161   |
# |recipient_cfscore       |is_other        |-0.06019889137925314  |
# |log_total_receipts      |is_republican   |-0.04245294603894642  |
# |log_num_givers          |is_republican   |0.03862385735367171   |
# |log_total_indiv_contribs|is_republican   |-0.036477465495241286 |
# |log_total_receipts      |is_democrat     |-0.03224684218777086  |
# |log_total_indiv_contribs|is_democrat     |-0.032157661372770575 |
# |num_givers              |is_democrat     |0.029977571138036434  |
# |log_total_pac_contribs  |is_other        |-0.020683083615056934 |
# |num_givers              |is_other        |-0.01748279255291686  |
# |log_total_pac_contribs  |is_democrat     |0.01600352419138167   |
# |num_givers              |is_republican   |-0.012937437993427803 |
# |total_indiv_contribs    |is_republican   |-0.011874379895314716 |
# |total_receipts          |is_democrat     |0.011360386686977524  |
# |total_receipts          |is_republican   |-0.006610068224713578 |
# |total_indiv_contribs    |is_democrat     |0.006609878393464301  |
# |total_pac_contribs      |is_democrat     |0.005945412344315403  |
# |total_indiv_contribs    |is_other        |0.005373843906901858  |
# |total_pac_contribs      |is_other        |-0.004923943190632579 |
# |total_receipts          |is_other        |-0.0048789078285660795|
# |log_total_pac_contribs  |is_republican   |0.004188733319820529  |
# |total_pac_contribs      |is_republican   |-0.0011419243992304656|
# +------------------------+----------------+----------------------+

# %%
if MAKE_GRAPHS:
    # Party percentage over time
    party_year_pct_pd = party_year_pct.toPandas()
    if len(party_year_pct_pd) > 0:
        pivot_pct = party_year_pct_pd.pivot(index="year", columns="party_group", values="party_pct").fillna(0)
        ax = pivot_pct.plot(kind="line", marker="o", title="Party Percentage by Year")
        ax.set_xlabel("Year")
        ax.set_ylabel("Share of rows")
        plt.tight_layout()
        plt.show()

    # Top state party shares
    state_party_pct_pd = state_party_pct.toPandas()
    if len(state_party_pct_pd) > 0:
        top_states = state_party_pct_pd.groupby("state_group")["state_total"].max().sort_values(ascending=False).head(12).index
        state_plot = state_party_pct_pd[state_party_pct_pd["state_group"].isin(top_states)]
        pivot_state = state_plot.pivot_table(index="state_group", columns="party_group", values="party_pct", aggfunc="mean").fillna(0)
        ax = pivot_state.plot(kind="bar", stacked=True, title="Party Share by Top States")
        ax.set_xlabel("State")
        ax.set_ylabel("Share")
        plt.tight_layout()
        plt.show()

    # Donor context over time if available
    donor_cols_for_plot = [c for c in ["ctx_year_avg_donor_cfscore", "ctx_year_left_share", "ctx_year_right_share"] if c in model_df.columns]
    if donor_cols_for_plot:
        donor_year_pd = (
            model_df
            .groupBy("year")
            .agg(*[F.avg(c).alias(c) for c in donor_cols_for_plot])
            .orderBy("year")
            .toPandas()
        )
        for c in donor_cols_for_plot:
            ax = donor_year_pd.plot(kind="line", x="year", y=c, marker="o", legend=False, title=f"{c} by Year")
            ax.set_xlabel("Year")
            ax.set_ylabel(c)
            plt.tight_layout()
            plt.show()

# %% [markdown]
# # Data Splitting, Cross-Validation, Hyperparameter Tuning, and Modeling
#
# Model construction, evaluation, and K-fold cross-validation of hyperparameters. This section uses a held-out test set and runs cross-validation only on the training data.

# %%
drop_from_features = {
    "party_raw",
    "party_group",
    "recipient_id",
    "recipient_name",
}

base_numeric_features = [
    "year",
    "recipient_cfscore",
    "primary_vote_pct",
    "general_vote_pct",
    "log_total_receipts",
    "log_total_indiv_contribs",
    "log_total_pac_contribs",
    "log_num_givers",
    "total_receipts_is_negative",
    "total_indiv_contribs_is_negative",
    "total_pac_contribs_is_negative",
]

if not USE_RECIPIENT_CFSCORE_FEATURE and "recipient_cfscore" in base_numeric_features:
    base_numeric_features.remove("recipient_cfscore")

context_numeric_features = [
    c for c in model_df.columns
    if c.startswith("fec_")
]

numeric_features = [
    c for c in base_numeric_features + context_numeric_features
    if c in model_df.columns and c not in drop_from_features
]

categorical_features = [
    c for c in [
        "recipient_type_group",
        "state_group",
        "seat_group",
        "district_group",
        "gender_group",
        "fec_incumbent_challenger",
        "fec_office_group",
        "fec_candidate_status",
    ]
    if c in model_df.columns and c not in drop_from_features
]

numeric_quality_for_model = []
for c in numeric_features:
    row = model_df.agg(
        F.approx_count_distinct(F.col(c)).alias("approx_distinct"),
        F.stddev(F.col(c)).alias("stddev")
    ).collect()[0].asDict()
    approx_distinct = int(row["approx_distinct"] or 0)
    stddev = row["stddev"]
    keep = (approx_distinct > 1) and (stddev is not None) and (float(stddev) > 0.0)
    numeric_quality_for_model.append((c, approx_distinct, float(stddev) if stddev is not None else None, keep))

numeric_model_quality_df = spark.createDataFrame(
    numeric_quality_for_model,
    ["feature", "approx_distinct", "stddev", "keep_for_model"]
)
print("Numeric model feature quality:")
show_df(numeric_model_quality_df.orderBy("keep_for_model", "feature"), 100, truncate=False)

numeric_features = [row[0] for row in numeric_quality_for_model if row[3]]

exclude_fec_numeric_features = {
    "fec_ttl_receipts", "fec_ttl_disb", "fec_trans_from_auth", "fec_trans_to_auth",
    "fec_coh_bop", "fec_coh_cop", "fec_cand_contrib", "fec_cand_loans",
    "fec_other_loans", "fec_debts_owed_by", "fec_ttl_indiv_contrib",
    "fec_other_pol_cmte_contrib", "fec_pol_pty_contrib", "fec_indiv_refunds",
    "fec_cmte_refunds", "fec_adjusted_receipts", "fec_adjusted_disb",
    "fec_sum_linked_cmte_receipts", "fec_sum_linked_cmte_disb",
    "fec_sum_linked_cmte_indv_contrib", "fec_sum_linked_cmte_other_pol_cmte_contrib",
    "fec_sum_linked_cmte_party_contrib",
}
numeric_features = [c for c in numeric_features if c not in exclude_fec_numeric_features]

print("Numeric features after zero-variance filtering:", numeric_features)
print("Categorical features:", categorical_features)

fill_numeric = {c: 0.0 for c in numeric_features}
fill_cats = {c: "MISSING" for c in categorical_features}

model_ready = (
    model_df
    .select(["party_group"] + numeric_features + categorical_features)
    .fillna(fill_numeric)
    .fillna(fill_cats)
    .filter(F.col("party_group").isNotNull())
)

train_df, test_df = model_ready.randomSplit([1.0 - TEST_FRACTION, TEST_FRACTION], seed=RANDOM_SEED)

if MAX_TRAIN_ROWS_FOR_TUNING is not None:
    train_df = train_df.limit(MAX_TRAIN_ROWS_FOR_TUNING)

train_df = train_df.repartition(MODEL_PARTITIONS).persist(StorageLevel.MEMORY_AND_DISK)
test_df = test_df.repartition(MODEL_PARTITIONS).persist(StorageLevel.MEMORY_AND_DISK)

if RUN_EXPENSIVE_COUNTS:
    print("Train rows:", train_df.count())
    print("Test rows:", test_df.count())

print("Train class balance:")
show_df(train_df.groupBy("party_group").count().orderBy(F.desc("count")), 20)

print("Test class balance:")
show_df(test_df.groupBy("party_group").count().orderBy(F.desc("count")), 20)
# Out:
# Numeric model feature quality:
# +-------------------------------------+---------------+--------------------+--------------+
# |feature                              |approx_distinct|stddev              |keep_for_model|
# +-------------------------------------+---------------+--------------------+--------------+
# |fec_ctx_avg_num_authorized_committees|111            |0.030770209077863177|true          |
# |fec_ctx_avg_num_linked_committees    |180            |0.20271805986170766 |true          |
# |fec_ctx_avg_num_principal_committees |173            |0.17592688112583055 |true          |
# |fec_ctx_avg_sum_linked_cmte_receipts |234            |1204414.709132342   |true          |
# |fec_ctx_candidate_count              |119            |128.9315878357298   |true          |
# |log_num_givers                       |4776           |1.9938301393750035  |true          |
# |log_total_indiv_contribs             |13676          |4.694680365581755   |true          |
# |log_total_pac_contribs               |6936           |3.6482569519771264  |true          |
# |log_total_receipts                   |19081          |5.164374826765443   |true          |
# |recipient_cfscore                    |4288           |1.0579441601660315  |true          |
# |year                                 |4              |1.9493795029292436  |true          |
# +-------------------------------------+---------------+--------------------+--------------+
#
# Numeric features after zero-variance filtering: ['year', 'recipient_cfscore', 'log_total_receipts', 'log_total_indiv_contribs', 'log_total_pac_contribs', 'log_num_givers', 'fec_ctx_candidate_count', 'fec_ctx_avg_num_linked_committees', 'fec_ctx_avg_num_principal_committees', 'fec_ctx_avg_num_authorized_committees', 'fec_ctx_avg_sum_linked_cmte_receipts']
# Categorical features: ['recipient_type_group', 'state_group', 'seat_group', 'district_group', 'gender_group']
# Train rows: 69647
# Test rows: 17214
# Train class balance:
# +-----------+-----+
# |party_group|count|
# +-----------+-----+
# |DEMOCRAT   |24052|
# |REPUBLICAN |23726|
# |OTHER      |21869|
# +-----------+-----+
#
# Test class balance:
# +-----------+-----+
# |party_group|count|
# +-----------+-----+
# |REPUBLICAN |5996 |
# |DEMOCRAT   |5881 |
# |OTHER      |5337 |
# +-----------+-----+

# %%
evaluator_acc = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="f1")
evaluator_weighted_precision = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedPrecision")
evaluator_weighted_recall = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedRecall")

# Cross-validation optimizes weighted F1.
cv_evaluator = evaluator_f1

def build_preprocess_stages(numeric_cols, categorical_cols, output_features_col="features", scale_numeric=True):
    label_indexer = StringIndexer(inputCol="party_group", outputCol="label", handleInvalid="skip")

    cat_indexers = [
        StringIndexer(inputCol=c, outputCol=f"{c}_idx", handleInvalid="keep")
        for c in categorical_cols
    ]

    encoder = OneHotEncoder(
        inputCols=[f"{c}_idx" for c in categorical_cols],
        outputCols=[f"{c}_ohe" for c in categorical_cols],
        handleInvalid="keep"
    )

    assembler_inputs = numeric_cols + [f"{c}_ohe" for c in categorical_cols]

    assembler = VectorAssembler(
        inputCols=assembler_inputs,
        outputCol="features_raw",
        handleInvalid="keep"
    )

    stages = [label_indexer] + cat_indexers + [encoder, assembler]

    if scale_numeric:
        scaler = StandardScaler(
            inputCol="features_raw",
            outputCol=output_features_col,
            withMean=False,
            withStd=True
        )
        stages.append(scaler)

    return stages

def get_label_names_from_pipeline_model(model):
    for st in model.stages:
        if hasattr(st, "labels"):
            return list(st.labels)
    return []

def compute_multiclass_ovr_auc(pred_df, labels):
    if "probability" not in pred_df.columns:
        return {"macro_ovr_auc": None, "weighted_ovr_auc": None}

    label_counts = {
        row["label"]: row["count"]
        for row in pred_df.groupBy("label").count().collect()
    }
    total = sum(label_counts.values())
    if total == 0:
        return {"macro_ovr_auc": None, "weighted_ovr_auc": None}

    prob_df = pred_df.withColumn("prob_array", vector_to_array(F.col("probability")))

    binary_eval = BinaryClassificationEvaluator(
        labelCol="binary_label",
        rawPredictionCol="score",
        metricName="areaUnderROC"
    )

    aucs = []
    weighted_parts = []

    for i, label_name in enumerate(labels):
        tmp = (
            prob_df
            .select(
                F.when(F.col("label") == float(i), 1.0).otherwise(0.0).alias("binary_label"),
                F.col("prob_array")[i].alias("score")
            )
            .filter(F.col("score").isNotNull())
        )

        pos_neg = tmp.groupBy("binary_label").count().collect()
        if len(pos_neg) < 2:
            auc = None
        else:
            auc = binary_eval.evaluate(tmp)

        if auc is not None:
            aucs.append(float(auc))
            weighted_parts.append(float(auc) * (label_counts.get(float(i), 0) / total))

    return {
        "macro_ovr_auc": sum(aucs) / len(aucs) if aucs else None,
        "weighted_ovr_auc": sum(weighted_parts) if weighted_parts else None,
    }

def evaluate_predictions(pred_df, model_name, labels):
    metrics = {
        "model": model_name,
        "accuracy": evaluator_acc.evaluate(pred_df),
        "weighted_f1": evaluator_f1.evaluate(pred_df),
        "weighted_precision": evaluator_weighted_precision.evaluate(pred_df),
        "weighted_recall": evaluator_weighted_recall.evaluate(pred_df),
    }

    try:
        metrics.update(compute_multiclass_ovr_auc(pred_df, labels))
    except Exception as e:
        print(f"AUROC could not be computed for {model_name}: {e}")
        metrics["macro_ovr_auc"] = None
        metrics["weighted_ovr_auc"] = None

    return metrics

def confusion_table(pred_df, labels):
    mapping = spark.createDataFrame(
        [(float(i), label) for i, label in enumerate(labels)],
        ["label_index", "label_name"]
    )

    pred_mapping = spark.createDataFrame(
        [(float(i), label) for i, label in enumerate(labels)],
        ["prediction_index", "prediction_name"]
    )

    return (
        pred_df
        .groupBy("label", "prediction")
        .count()
        .join(mapping, F.col("label") == F.col("label_index"), "left")
        .join(pred_mapping, F.col("prediction") == F.col("prediction_index"), "left")
        .select("label_name", "prediction_name", "count")
        .orderBy("label_name", "prediction_name")
    )

def cv_results_table(cv_model, param_names, model_name):
    rows = []
    for param_map, metric in zip(cv_model.getEstimatorParamMaps(), cv_model.avgMetrics):
        row = {"model": model_name, "cv_weighted_f1": float(metric)}
        for param_obj, display_name in param_names:
            row[display_name] = str(param_map.get(param_obj, None))
        rows.append(row)

    if not rows:
        rows = [{"model": model_name, "cv_weighted_f1": None}]

    return spark.createDataFrame(pd.DataFrame(rows))

# %%
def get_stage_by_type(pipeline_model, type_name: str):
    for st in pipeline_model.stages:
        if st.__class__.__name__ == type_name:
            return st
    return None

def get_stages_by_type(pipeline_model, type_name: str):
    return [st for st in pipeline_model.stages if st.__class__.__name__ == type_name]

def build_feature_names_from_pipeline_model(pipeline_model, numeric_cols, categorical_cols):
    """
    Reconstructs the feature vector names after:
    StringIndexer -> OneHotEncoder -> VectorAssembler.

    Numeric features appear first. Then OHE categorical levels are expanded.
    """
    feature_names = list(numeric_cols)

    # StringIndexerModels have inputCol and labels.
    indexer_models = {
        st.getInputCol(): list(st.labels)
        for st in pipeline_model.stages
        if st.__class__.__name__ == "StringIndexerModel" and st.getInputCol() in categorical_cols
    }

    # OHE usually drops the last category by default. If dropLast=True, vector size is len(labels)-1.
    encoder_model = get_stage_by_type(pipeline_model, "OneHotEncoderModel")
    drop_last = True
    category_sizes = None
    if encoder_model is not None:
        try:
            drop_last = encoder_model.getDropLast()
        except Exception:
            drop_last = True
        try:
            category_sizes = list(encoder_model.categorySizes)
        except Exception:
            category_sizes = None

    for idx, c in enumerate(categorical_cols):
        labels = indexer_models.get(c, [])
        if category_sizes is not None and idx < len(category_sizes):
            size = int(category_sizes[idx])
        else:
            size = max(len(labels) - 1, 1) if drop_last else len(labels)

        for j in range(size):
            if j < len(labels):
                feature_names.append(f"{c}={labels[j]}")
            else:
                feature_names.append(f"{c}=__unknown_{j}")

    return feature_names

def random_forest_feature_importance_df(cv_model, numeric_cols, categorical_cols, model_name="Random Forest"):
    best_pipeline = cv_model.bestModel
    rf_model = best_pipeline.stages[-1]

    feature_names = build_feature_names_from_pipeline_model(best_pipeline, numeric_cols, categorical_cols)
    importances = rf_model.featureImportances.toArray().tolist()

    # Align lengths safely.
    n = min(len(feature_names), len(importances))
    rows = [(model_name, feature_names[i], float(importances[i])) for i in range(n)]

    # Add unnamed features if Spark vector is longer than reconstructed names.
    if len(importances) > len(feature_names):
        for i in range(len(feature_names), len(importances)):
            rows.append((model_name, f"feature_{i}", float(importances[i])))

    return spark.createDataFrame(rows, ["model", "feature", "importance"]).orderBy(F.desc("importance"))

def logistic_coefficient_importance_df(cv_model, numeric_cols, categorical_cols, model_name="Logistic Regression"):
    """
    For multinomial logistic regression, coefficientMatrix is classes x features.
    We summarize feature importance as the mean absolute coefficient across classes.
    """
    best_pipeline = cv_model.bestModel
    lr_model = best_pipeline.stages[-1]

    feature_names = build_feature_names_from_pipeline_model(best_pipeline, numeric_cols, categorical_cols)
    coef_matrix = lr_model.coefficientMatrix.toArray()

    mean_abs = abs(coef_matrix).mean(axis=0).tolist()

    n = min(len(feature_names), len(mean_abs))
    rows = [(model_name, feature_names[i], float(mean_abs[i])) for i in range(n)]

    if len(mean_abs) > len(feature_names):
        for i in range(len(feature_names), len(mean_abs)):
            rows.append((model_name, f"feature_{i}", float(mean_abs[i])))

    return spark.createDataFrame(rows, ["model", "feature", "mean_abs_coefficient"]).orderBy(F.desc("mean_abs_coefficient"))

def group_ohe_importance(importance_df: DataFrame, value_col: str):
    """
    Groups one-hot encoded feature levels back to the original feature name.
    Example: state_group=CA, state_group=NY -> state_group.
    """
    grouped = (
        importance_df
        .withColumn(
            "feature_group",
            F.when(F.col("feature").contains("="), F.split(F.col("feature"), "=").getItem(0))
             .otherwise(F.col("feature"))
        )
        .groupBy("model", "feature_group")
        .agg(F.sum(F.col(value_col)).alias(f"grouped_{value_col}"))
        .orderBy(F.desc(f"grouped_{value_col}"))
    )
    return grouped

# %% [markdown]
# # Model 1: Benchmark Logistic Regression with CV

# %%
benchmark_numeric = [c for c in ["log_total_receipts", "log_num_givers", "year"] if c in numeric_features]
benchmark_categorical = [c for c in ["seat_group"] if c in categorical_features]

benchmark_preprocess = build_preprocess_stages(
    benchmark_numeric,
    benchmark_categorical,
    output_features_col="features",
    scale_numeric=True
)

benchmark_lr = LogisticRegression(
    featuresCol="features",
    labelCol="label",
    family="multinomial",
    maxIter=30
)

benchmark_pipeline = Pipeline(stages=benchmark_preprocess + [benchmark_lr])

if FAST_CV:
    benchmark_grid = (
        ParamGridBuilder()
        .addGrid(benchmark_lr.regParam, [0.0, 0.05])
        .addGrid(benchmark_lr.elasticNetParam, [0.0])
        .build()
    )
else:
    benchmark_grid = (
        ParamGridBuilder()
        .addGrid(benchmark_lr.regParam, [0.0, 0.01, 0.05, 0.1])
        .addGrid(benchmark_lr.elasticNetParam, [0.0, 0.5])
        .build()
    )

benchmark_cv = CrossValidator(
    estimator=benchmark_pipeline,
    estimatorParamMaps=benchmark_grid,
    evaluator=cv_evaluator,
    numFolds=NUM_FOLDS,
    parallelism=max(1, min(NUM_CORES, 4)),
    seed=RANDOM_SEED
)

benchmark_cv_model = benchmark_cv.fit(train_df)
benchmark_pred = benchmark_cv_model.transform(test_df)
benchmark_labels = get_label_names_from_pipeline_model(benchmark_cv_model.bestModel)

benchmark_metrics = evaluate_predictions(benchmark_pred, "Benchmark Logistic Regression", benchmark_labels)
benchmark_metrics
# Out:
# 26/07/01 11:50:50 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# {'model': 'Benchmark Logistic Regression',
#  'accuracy': 0.6256535378180551,
#  'weighted_f1': 0.623062544283796,
#  'weighted_precision': 0.6210817166698894,
#  'weighted_recall': 0.6256535378180551,
#  'macro_ovr_auc': 0.7996620342593278,
#  'weighted_ovr_auc': 0.7955161535340893}

# %%
# Benchmark CV sensitivity table and confusion matrix
benchmark_cv_table = cv_results_table(
    benchmark_cv_model,
    [(benchmark_lr.regParam, "regParam"), (benchmark_lr.elasticNetParam, "elasticNetParam")],
    "Benchmark Logistic Regression"
).orderBy(F.desc("cv_weighted_f1"))

show_df(benchmark_cv_table, 50)
show_df(confusion_table(benchmark_pred, benchmark_labels), 100)
# Out:
# +-----------------------------+------------------+--------+---------------+
# |model                        |cv_weighted_f1    |regParam|elasticNetParam|
# +-----------------------------+------------------+--------+---------------+
# |Benchmark Logistic Regression|0.620547355089263 |0.0     |0.0            |
# |Benchmark Logistic Regression|0.6138412991900339|0.05    |0.0            |
# +-----------------------------+------------------+--------+---------------+
# [Stage 1144:=========>   (29 + 10) / 40][Stage 1146:>              (0 + 0) / 20]
# +----------+---------------+-----+
# |label_name|prediction_name|count|
# +----------+---------------+-----+
# |DEMOCRAT  |DEMOCRAT       |3194 |
# |DEMOCRAT  |OTHER          |575  |
# |DEMOCRAT  |REPUBLICAN     |2112 |
# |OTHER     |DEMOCRAT       |311  |
# |OTHER     |OTHER          |4503 |
# |OTHER     |REPUBLICAN     |523  |
# |REPUBLICAN|DEMOCRAT       |2361 |
# |REPUBLICAN|OTHER          |562  |
# |REPUBLICAN|REPUBLICAN     |3073 |
# +----------+---------------+-----+

# %% [markdown]
# # Model 2: Full Multinomial Logistic Regression with CV

# %%
full_lr_preprocess = build_preprocess_stages(
    numeric_features,
    categorical_features,
    output_features_col="features",
    scale_numeric=True
)

full_lr = LogisticRegression(
    featuresCol="features",
    labelCol="label",
    family="multinomial",
    maxIter=60
)

full_lr_pipeline = Pipeline(stages=full_lr_preprocess + [full_lr])

if FAST_CV:
    full_lr_grid = (
        ParamGridBuilder()
        .addGrid(full_lr.regParam, [0.01, 0.05])
        .addGrid(full_lr.elasticNetParam, [0.0, 0.5])
        .build()
    )
else:
    full_lr_grid = (
        ParamGridBuilder()
        .addGrid(full_lr.regParam, [0.001, 0.01, 0.05, 0.1])
        .addGrid(full_lr.elasticNetParam, [0.0, 0.25, 0.5, 1.0])
        .build()
    )

full_lr_cv = CrossValidator(
    estimator=full_lr_pipeline,
    estimatorParamMaps=full_lr_grid,
    evaluator=cv_evaluator,
    numFolds=NUM_FOLDS,
    parallelism=max(1, min(NUM_CORES, 4)),
    seed=RANDOM_SEED
)

full_lr_cv_model = full_lr_cv.fit(train_df)
full_lr_pred = full_lr_cv_model.transform(test_df)
full_lr_labels = get_label_names_from_pipeline_model(full_lr_cv_model.bestModel)

full_lr_metrics = evaluate_predictions(full_lr_pred, "Full Multinomial Logistic Regression", full_lr_labels)
full_lr_metrics
# Out:
# {'model': 'Full Multinomial Logistic Regression',
#  'accuracy': 0.880504240734286,
#  'weighted_f1': 0.8805030042719104,
#  'weighted_precision': 0.8805078448097026,
#  'weighted_recall': 0.880504240734286,
#  'macro_ovr_auc': 0.962232626500823,
#  'weighted_ovr_auc': 0.9629713498166326}

# %%
full_lr_cv_table = cv_results_table(
    full_lr_cv_model,
    [(full_lr.regParam, "regParam"), (full_lr.elasticNetParam, "elasticNetParam")],
    "Full Multinomial Logistic Regression"
).orderBy(F.desc("cv_weighted_f1"))

show_df(full_lr_cv_table, 100)
show_df(confusion_table(full_lr_pred, full_lr_labels), 100)
# Out:
# +------------------------------------+------------------+--------+---------------+
# |model                               |cv_weighted_f1    |regParam|elasticNetParam|
# +------------------------------------+------------------+--------+---------------+
# |Full Multinomial Logistic Regression|0.8813224519215339|0.01    |0.5            |
# |Full Multinomial Logistic Regression|0.8812414812925825|0.05    |0.0            |
# |Full Multinomial Logistic Regression|0.8810271649613811|0.01    |0.0            |
# |Full Multinomial Logistic Regression|0.8648753614172998|0.05    |0.5            |
# +------------------------------------+------------------+--------+---------------+
# [Stage 3388:=============>(38 + 2) / 40][Stage 3391:>              (0 + 8) / 20]
# +----------+---------------+-----+
# |label_name|prediction_name|count|
# +----------+---------------+-----+
# |DEMOCRAT  |DEMOCRAT       |5295 |
# |DEMOCRAT  |OTHER          |485  |
# |DEMOCRAT  |REPUBLICAN     |101  |
# |OTHER     |DEMOCRAT       |468  |
# |OTHER     |OTHER          |4430 |
# |OTHER     |REPUBLICAN     |439  |
# |REPUBLICAN|DEMOCRAT       |146  |
# |REPUBLICAN|OTHER          |418  |
# |REPUBLICAN|REPUBLICAN     |5432 |
# +----------+---------------+-----+

# %% [markdown]
# # Model 3: Random Forest with CV

# %%
rf_preprocess = build_preprocess_stages(
    numeric_features,
    categorical_features,
    output_features_col="features",
    scale_numeric=False
)

rf = RandomForestClassifier(
    featuresCol="features_raw",
    labelCol="label",
    seed=RANDOM_SEED
)

rf_pipeline = Pipeline(stages=rf_preprocess + [rf])

if FAST_CV:
    rf_grid = (
        ParamGridBuilder()
        .addGrid(rf.numTrees, [50])
        .addGrid(rf.maxDepth, [5])
        .addGrid(rf.featureSubsetStrategy, ["sqrt"])
        .build()
    )
else:
    rf_grid = (
        ParamGridBuilder()
        .addGrid(rf.numTrees, [50, 100, 150])
        .addGrid(rf.maxDepth, [5, 8, 12])
        .addGrid(rf.featureSubsetStrategy, ["sqrt", "log2"])
        .build()
    )

rf_cv = CrossValidator(
    estimator=rf_pipeline,
    estimatorParamMaps=rf_grid,
    evaluator=cv_evaluator,
    numFolds=NUM_FOLDS,
    parallelism=max(1, min(NUM_CORES, 5)),
    seed=RANDOM_SEED
)

rf_cv_model = rf_cv.fit(train_df)
rf_pred = rf_cv_model.transform(test_df)
rf_labels = get_label_names_from_pipeline_model(rf_cv_model.bestModel)

rf_metrics = evaluate_predictions(rf_pred, "Random Forest", rf_labels)
rf_metrics
# Out:
# 26/07/01 11:52:19 WARN MemoryStore: Not enough space to cache rdd_7020_4 in memory! (computed 38.1 MiB so far)
# 26/07/01 11:52:19 WARN MemoryStore: Not enough space to cache rdd_7020_2 in memory! (computed 38.1 MiB so far)
# 26/07/01 11:52:19 WARN BlockManager: Persisting block rdd_7020_2 to disk instead.
# 26/07/01 11:52:19 WARN BlockManager: Persisting block rdd_7020_4 to disk instead.
# 26/07/01 11:52:19 WARN MemoryStore: Not enough space to cache rdd_7020_1 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:52:19 WARN BlockManager: Persisting block rdd_7020_1 to disk instead.
# 26/07/01 11:52:19 WARN MemoryStore: Not enough space to cache rdd_7020_7 in memory! (computed 38.1 MiB so far)
# 26/07/01 11:52:19 WARN BlockManager: Persisting block rdd_7020_7 to disk instead.
# 26/07/01 11:52:19 WARN MemoryStore: Not enough space to cache rdd_7020_0 in memory! (computed 38.1 MiB so far)
# 26/07/01 11:52:19 WARN BlockManager: Persisting block rdd_7020_0 to disk instead.
# 26/07/01 11:52:19 WARN MemoryStore: Not enough space to cache rdd_7020_3 in memory! (computed 38.1 MiB so far)
# 26/07/01 11:52:19 WARN BlockManager: Persisting block rdd_7020_3 to disk instead.
# 26/07/01 11:52:19 WARN MemoryStore: Not enough space to cache rdd_7020_8 in memory! (computed 38.1 MiB so far)
# 26/07/01 11:52:19 WARN BlockManager: Persisting block rdd_7020_8 to disk instead.
# 26/07/01 11:52:19 WARN MemoryStore: Not enough space to cache rdd_7020_0 in memory! (computed 38.1 MiB so far)
# 26/07/01 11:52:19 WARN MemoryStore: Not enough space to cache rdd_7020_2 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:52:19 WARN MemoryStore: Not enough space to cache rdd_7020_1 in memory! (computed 16.4 MiB so far)
# 26/07/01 11:52:20 WARN MemoryStore: Not enough space to cache rdd_7020_11 in memory! (computed 16.4 MiB so far)
# 26/07/01 11:52:20 WARN BlockManager: Persisting block rdd_7020_11 to disk instead.
# 26/07/01 11:52:20 WARN MemoryStore: Not enough space to cache rdd_7020_10 in memory! (computed 38.1 MiB so far)
# 26/07/01 11:52:20 WARN BlockManager: Persisting block rdd_7020_10 to disk instead.
# 26/07/01 11:52:20 WARN MemoryStore: Not enough space to cache rdd_7020_12 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:52:20 WARN BlockManager: Persisting block rdd_7020_12 to disk instead.
# 26/07/01 11:52:20 WARN MemoryStore: Not enough space to cache rdd_7020_15 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:52:20 WARN BlockManager: Persisting block rdd_7020_15 to disk instead.
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_14 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:52:21 WARN BlockManager: Persisting block rdd_7020_14 to disk instead.
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_10 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_16 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:52:21 WARN BlockManager: Persisting block rdd_7020_16 to disk instead.
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_11 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_14 in memory! (computed 1108.0 KiB so far)
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_17 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:52:21 WARN BlockManager: Persisting block rdd_7020_17 to disk instead.
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_15 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_18 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:52:21 WARN BlockManager: Persisting block rdd_7020_18 to disk instead.
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_12 in memory! (computed 1108.0 KiB so far)
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_17 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:52:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7020_16 in memory.
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_16 in memory! (computed 504.0 B so far)
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_19 in memory! (computed 1831.5 KiB so far)
# 26/07/01 11:52:21 WARN BlockManager: Persisting block rdd_7020_19 to disk instead.
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_18 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:52:21 WARN MemoryStore: Not enough space to cache rdd_7020_19 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:52:23 WARN MemoryStore: Not enough space to cache rdd_7020_0 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:52:23 WARN MemoryStore: Not enough space to cache rdd_7020_2 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:52:23 WARN MemoryStore: Not enough space to cache rdd_7020_1 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:52:25 WARN MemoryStore: Not enough space to cache rdd_7020_10 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:52:25 WARN MemoryStore: Not enough space to cache rdd_7020_11 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:52:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7020_12 in memory.
# 26/07/01 11:52:25 WARN MemoryStore: Not enough space to cache rdd_7020_12 in memory! (computed 504.0 B so far)
# 26/07/01 11:52:25 WARN MemoryStore: Not enough space to cache rdd_7020_14 in memory! (computed 1108.0 KiB so far)
# 26/07/01 11:52:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7020_15 in memory.
# 26/07/01 11:52:25 WARN MemoryStore: Not enough space to cache rdd_7020_15 in memory! (computed 504.0 B so far)
# 26/07/01 11:52:25 WARN MemoryStore: Not enough space to cache rdd_7020_16 in memory! (computed 1108.0 KiB so far)
# 26/07/01 11:52:25 WARN MemoryStore: Not enough space to cache rdd_7020_18 in memory! (computed 1831.5 KiB so far)
# 26/07/01 11:52:25 WARN MemoryStore: Not enough space to cache rdd_7020_17 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:52:25 WARN MemoryStore: Not enough space to cache rdd_7020_19 in memory! (computed 1108.0 KiB so far)
# 26/07/01 11:52:30 WARN DAGScheduler: Broadcasting large task binary with size 1017.4 KiB
# 26/07/01 11:52:30 WARN MemoryStore: Not enough space to cache rdd_7020_2 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:52:30 WARN MemoryStore: Not enough space to cache rdd_7020_1 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:52:30 WARN MemoryStore: Not enough space to cache rdd_7020_0 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:52:31 WARN MemoryStore: Not enough space to cache rdd_7020_10 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:52:31 WARN MemoryStore: Not enough space to cache rdd_7020_11 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:52:31 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7020_12 in memory.
# 26/07/01 11:52:31 WARN MemoryStore: Not enough space to cache rdd_7020_12 in memory! (computed 504.0 B so far)
# 26/07/01 11:52:32 WARN MemoryStore: Not enough space to cache rdd_7020_14 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:52:32 WARN MemoryStore: Not enough space to cache rdd_7020_15 in memory! (computed 1108.0 KiB so far)
# 26/07/01 11:52:32 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7020_16 in memory.
# 26/07/01 11:52:32 WARN MemoryStore: Not enough space to cache rdd_7020_16 in memory! (computed 504.0 B so far)
# 26/07/01 11:52:32 WARN MemoryStore: Not enough space to cache rdd_7020_17 in memory! (computed 1108.0 KiB so far)
# 26/07/01 11:52:32 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7020_18 in memory.
# 26/07/01 11:52:32 WARN MemoryStore: Not enough space to cache rdd_7020_18 in memory! (computed 504.0 B so far)
# 26/07/01 11:52:32 WARN MemoryStore: Not enough space to cache rdd_7020_19 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:52:38 WARN DAGScheduler: Broadcasting large task binary with size 1057.3 KiB
# 26/07/01 11:52:38 WARN MemoryStore: Not enough space to cache rdd_7020_2 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:52:38 WARN MemoryStore: Not enough space to cache rdd_7020_1 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:52:38 WARN MemoryStore: Not enough space to cache rdd_7020_0 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:52:39 WARN MemoryStore: Not enough space to cache rdd_7020_10 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:52:39 WARN MemoryStore: Not enough space to cache rdd_7020_11 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:52:40 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7020_12 in memory.
# 26/07/01 11:52:40 WARN MemoryStore: Not enough space to cache rdd_7020_12 in memory! (computed 504.0 B so far)
# 26/07/01 11:52:40 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7020_14 in memory.
# 26/07/01 11:52:40 WARN MemoryStore: Not enough space to cache rdd_7020_14 in memory! (computed 504.0 B so far)
# 26/07/01 11:52:40 WARN MemoryStore: Not enough space to cache rdd_7020_15 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:52:40 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7020_16 in memory.
# 26/07/01 11:52:40 WARN MemoryStore: Not enough space to cache rdd_7020_16 in memory! (computed 504.0 B so far)
# 26/07/01 11:52:40 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7020_17 in memory.
# 26/07/01 11:52:40 WARN MemoryStore: Not enough space to cache rdd_7020_17 in memory! (computed 504.0 B so far)
# 26/07/01 11:52:40 WARN MemoryStore: Not enough space to cache rdd_7020_18 in memory! (computed 1108.0 KiB so far)
# 26/07/01 11:52:40 WARN MemoryStore: Not enough space to cache rdd_7020_19 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:52:47 WARN DAGScheduler: Broadcasting large task binary with size 1104.0 KiB
# 26/07/01 11:52:47 WARN MemoryStore: Not enough space to cache rdd_7020_2 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:52:47 WARN MemoryStore: Not enough space to cache rdd_7020_0 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:52:47 WARN MemoryStore: Not enough space to cache rdd_7020_1 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:52:49 WARN MemoryStore: Not enough space to cache rdd_7020_10 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:52:49 WARN MemoryStore: Not enough space to cache rdd_7020_11 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:52:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7020_12 in memory.
# 26/07/01 11:52:49 WARN MemoryStore: Not enough space to cache rdd_7020_12 in memory! (computed 504.0 B so far)
# 26/07/01 11:52:49 WARN MemoryStore: Not enough space to cache rdd_7020_14 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:52:49 WARN MemoryStore: Not enough space to cache rdd_7020_15 in memory! (computed 1108.0 KiB so far)
# 26/07/01 11:52:49 WARN MemoryStore: Not enough space to cache rdd_7020_16 in memory! (computed 1108.0 KiB so far)
# 26/07/01 11:52:49 WARN MemoryStore: Not enough space to cache rdd_7020_17 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:52:49 WARN MemoryStore: Not enough space to cache rdd_7020_18 in memory! (computed 1108.0 KiB so far)
# 26/07/01 11:52:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7020_19 in memory.
# 26/07/01 11:52:49 WARN MemoryStore: Not enough space to cache rdd_7020_19 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:01 WARN MemoryStore: Not enough space to cache rdd_7162_7 in memory! (computed 38.0 MiB so far)
# 26/07/01 11:53:01 WARN BlockManager: Persisting block rdd_7162_7 to disk instead.
# 26/07/01 11:53:01 WARN MemoryStore: Not enough space to cache rdd_7162_2 in memory! (computed 38.0 MiB so far)
# 26/07/01 11:53:01 WARN BlockManager: Persisting block rdd_7162_2 to disk instead.
# 26/07/01 11:53:01 WARN MemoryStore: Not enough space to cache rdd_7162_3 in memory! (computed 38.0 MiB so far)
# 26/07/01 11:53:01 WARN BlockManager: Persisting block rdd_7162_3 to disk instead.
# 26/07/01 11:53:01 WARN MemoryStore: Not enough space to cache rdd_7162_4 in memory! (computed 38.0 MiB so far)
# 26/07/01 11:53:01 WARN BlockManager: Persisting block rdd_7162_4 to disk instead.
# 26/07/01 11:53:01 WARN MemoryStore: Not enough space to cache rdd_7162_9 in memory! (computed 38.0 MiB so far)
# 26/07/01 11:53:01 WARN BlockManager: Persisting block rdd_7162_9 to disk instead.
# 26/07/01 11:53:01 WARN MemoryStore: Not enough space to cache rdd_7162_6 in memory! (computed 38.0 MiB so far)
# 26/07/01 11:53:01 WARN BlockManager: Persisting block rdd_7162_6 to disk instead.
# 26/07/01 11:53:01 WARN MemoryStore: Not enough space to cache rdd_7162_8 in memory! (computed 38.0 MiB so far)
# 26/07/01 11:53:01 WARN BlockManager: Persisting block rdd_7162_8 to disk instead.
# 26/07/01 11:53:01 WARN MemoryStore: Not enough space to cache rdd_7162_1 in memory! (computed 38.0 MiB so far)
# 26/07/01 11:53:01 WARN BlockManager: Persisting block rdd_7162_1 to disk instead.
# 26/07/01 11:53:01 WARN MemoryStore: Not enough space to cache rdd_7162_6 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:01 WARN MemoryStore: Not enough space to cache rdd_7162_4 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:01 WARN MemoryStore: Not enough space to cache rdd_7162_9 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_12 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:03 WARN BlockManager: Persisting block rdd_7162_12 to disk instead.
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_10 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_15 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:03 WARN BlockManager: Persisting block rdd_7162_10 to disk instead.
# 26/07/01 11:53:03 WARN BlockManager: Persisting block rdd_7162_15 to disk instead.
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_11 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:03 WARN BlockManager: Persisting block rdd_7162_11 to disk instead.
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_17 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:03 WARN BlockManager: Persisting block rdd_7162_17 to disk instead.
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_14 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:03 WARN BlockManager: Persisting block rdd_7162_14 to disk instead.
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_13 in memory! (computed 38.0 MiB so far)
# 26/07/01 11:53:03 WARN BlockManager: Persisting block rdd_7162_13 to disk instead.
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_16 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:03 WARN BlockManager: Persisting block rdd_7162_16 to disk instead.
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_10 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7162_12 in memory.
# 26/07/01 11:53:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7162_13 in memory.
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_12 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_13 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_14 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_15 in memory! (computed 1107.6 KiB so far)
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_18 in memory! (computed 38.0 MiB so far)
# 26/07/01 11:53:03 WARN BlockManager: Persisting block rdd_7162_18 to disk instead.
# 26/07/01 11:53:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7162_11 in memory.
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_11 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_19 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:03 WARN BlockManager: Persisting block rdd_7162_19 to disk instead.
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_17 in memory! (computed 38.0 MiB so far)
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_16 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_18 in memory! (computed 1830.9 KiB so far)
# 26/07/01 11:53:03 WARN MemoryStore: Not enough space to cache rdd_7162_19 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:53:06 WARN MemoryStore: Not enough space to cache rdd_7162_4 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:06 WARN MemoryStore: Not enough space to cache rdd_7162_9 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:06 WARN MemoryStore: Not enough space to cache rdd_7162_6 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:07 WARN MemoryStore: Not enough space to cache rdd_7162_11 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:07 WARN MemoryStore: Not enough space to cache rdd_7162_13 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:53:07 WARN MemoryStore: Not enough space to cache rdd_7162_12 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:07 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7162_14 in memory.
# 26/07/01 11:53:07 WARN MemoryStore: Not enough space to cache rdd_7162_14 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:07 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7162_15 in memory.
# 26/07/01 11:53:07 WARN MemoryStore: Not enough space to cache rdd_7162_15 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:07 WARN MemoryStore: Not enough space to cache rdd_7162_16 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:53:07 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7162_17 in memory.
# 26/07/01 11:53:07 WARN MemoryStore: Not enough space to cache rdd_7162_17 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:07 WARN MemoryStore: Not enough space to cache rdd_7162_18 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:08 WARN MemoryStore: Not enough space to cache rdd_7162_19 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:53:11 WARN DAGScheduler: Broadcasting large task binary with size 1014.2 KiB
# 26/07/01 11:53:11 WARN MemoryStore: Not enough space to cache rdd_7162_6 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:11 WARN MemoryStore: Not enough space to cache rdd_7162_4 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:11 WARN MemoryStore: Not enough space to cache rdd_7162_9 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:13 WARN MemoryStore: Not enough space to cache rdd_7162_11 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:13 WARN MemoryStore: Not enough space to cache rdd_7162_13 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:13 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7162_15 in memory.
# 26/07/01 11:53:13 WARN MemoryStore: Not enough space to cache rdd_7162_15 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:13 WARN MemoryStore: Not enough space to cache rdd_7162_12 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:53:13 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7162_14 in memory.
# 26/07/01 11:53:13 WARN MemoryStore: Not enough space to cache rdd_7162_14 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:13 WARN MemoryStore: Not enough space to cache rdd_7162_17 in memory! (computed 1107.6 KiB so far)
# 26/07/01 11:53:13 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7162_18 in memory.
# 26/07/01 11:53:13 WARN MemoryStore: Not enough space to cache rdd_7162_18 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:13 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7162_16 in memory.
# 26/07/01 11:53:13 WARN MemoryStore: Not enough space to cache rdd_7162_16 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:13 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7162_19 in memory.
# 26/07/01 11:53:13 WARN MemoryStore: Not enough space to cache rdd_7162_19 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:18 WARN DAGScheduler: Broadcasting large task binary with size 1056.6 KiB
# 26/07/01 11:53:19 WARN MemoryStore: Not enough space to cache rdd_7162_4 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:19 WARN MemoryStore: Not enough space to cache rdd_7162_9 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:19 WARN MemoryStore: Not enough space to cache rdd_7162_6 in memory! (computed 16.4 MiB so far)
# 26/07/01 11:53:20 WARN MemoryStore: Not enough space to cache rdd_7162_11 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:20 WARN MemoryStore: Not enough space to cache rdd_7162_13 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:53:20 WARN MemoryStore: Not enough space to cache rdd_7162_12 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:20 WARN MemoryStore: Not enough space to cache rdd_7162_14 in memory! (computed 1107.6 KiB so far)
# 26/07/01 11:53:20 WARN MemoryStore: Not enough space to cache rdd_7162_15 in memory! (computed 1107.6 KiB so far)
# 26/07/01 11:53:21 WARN MemoryStore: Not enough space to cache rdd_7162_16 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:21 WARN MemoryStore: Not enough space to cache rdd_7162_17 in memory! (computed 1830.9 KiB so far)
# 26/07/01 11:53:21 WARN MemoryStore: Not enough space to cache rdd_7162_18 in memory! (computed 1830.9 KiB so far)
# 26/07/01 11:53:21 WARN MemoryStore: Not enough space to cache rdd_7162_19 in memory! (computed 1830.9 KiB so far)
# 26/07/01 11:53:28 WARN DAGScheduler: Broadcasting large task binary with size 1105.2 KiB
# 26/07/01 11:53:28 WARN MemoryStore: Not enough space to cache rdd_7162_6 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:28 WARN MemoryStore: Not enough space to cache rdd_7162_9 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:28 WARN MemoryStore: Not enough space to cache rdd_7162_4 in memory! (computed 16.4 MiB so far)
# 26/07/01 11:53:30 WARN MemoryStore: Not enough space to cache rdd_7162_13 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:53:30 WARN MemoryStore: Not enough space to cache rdd_7162_12 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:30 WARN MemoryStore: Not enough space to cache rdd_7162_11 in memory! (computed 24.9 MiB so far)
# 26/07/01 11:53:30 WARN MemoryStore: Not enough space to cache rdd_7162_14 in memory! (computed 1107.6 KiB so far)
# 26/07/01 11:53:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7162_15 in memory.
# 26/07/01 11:53:30 WARN MemoryStore: Not enough space to cache rdd_7162_15 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:30 WARN MemoryStore: Not enough space to cache rdd_7162_16 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:53:30 WARN MemoryStore: Not enough space to cache rdd_7162_17 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:30 WARN MemoryStore: Not enough space to cache rdd_7162_18 in memory! (computed 1107.6 KiB so far)
# 26/07/01 11:53:30 WARN MemoryStore: Not enough space to cache rdd_7162_19 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:53:42 WARN MemoryStore: Not enough space to cache rdd_7304_1 in memory! (computed 37.8 MiB so far)
# 26/07/01 11:53:42 WARN BlockManager: Persisting block rdd_7304_1 to disk instead.
# 26/07/01 11:53:42 WARN MemoryStore: Not enough space to cache rdd_7304_3 in memory! (computed 24.8 MiB so far)
# 26/07/01 11:53:42 WARN BlockManager: Persisting block rdd_7304_3 to disk instead.
# 26/07/01 11:53:42 WARN MemoryStore: Not enough space to cache rdd_7304_6 in memory! (computed 37.8 MiB so far)
# 26/07/01 11:53:42 WARN BlockManager: Persisting block rdd_7304_6 to disk instead.
# 26/07/01 11:53:42 WARN MemoryStore: Not enough space to cache rdd_7304_5 in memory! (computed 24.8 MiB so far)
# 26/07/01 11:53:42 WARN BlockManager: Persisting block rdd_7304_5 to disk instead.
# 26/07/01 11:53:42 WARN MemoryStore: Not enough space to cache rdd_7304_0 in memory! (computed 37.8 MiB so far)
# 26/07/01 11:53:42 WARN BlockManager: Persisting block rdd_7304_0 to disk instead.
# 26/07/01 11:53:42 WARN MemoryStore: Not enough space to cache rdd_7304_0 in memory! (computed 37.8 MiB so far)
# 26/07/01 11:53:42 WARN MemoryStore: Not enough space to cache rdd_7304_5 in memory! (computed 16.3 MiB so far)
# 26/07/01 11:53:42 WARN MemoryStore: Not enough space to cache rdd_7304_3 in memory! (computed 24.8 MiB so far)
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_11 in memory! (computed 16.3 MiB so far)
# 26/07/01 11:53:44 WARN BlockManager: Persisting block rdd_7304_11 to disk instead.
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_12 in memory! (computed 16.3 MiB so far)
# 26/07/01 11:53:44 WARN BlockManager: Persisting block rdd_7304_12 to disk instead.
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_14 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:44 WARN BlockManager: Persisting block rdd_7304_14 to disk instead.
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_17 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_16 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_15 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_19 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:53:44 WARN BlockManager: Persisting block rdd_7304_17 to disk instead.
# 26/07/01 11:53:44 WARN BlockManager: Persisting block rdd_7304_16 to disk instead.
# 26/07/01 11:53:44 WARN BlockManager: Persisting block rdd_7304_19 to disk instead.
# 26/07/01 11:53:44 WARN BlockManager: Persisting block rdd_7304_15 to disk instead.
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_11 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_18 in memory! (computed 16.3 MiB so far)
# 26/07/01 11:53:44 WARN BlockManager: Persisting block rdd_7304_18 to disk instead.
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_12 in memory! (computed 24.8 MiB so far)
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_14 in memory! (computed 1821.4 KiB so far)
# 26/07/01 11:53:44 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_17 in memory.
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_17 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_16 in memory! (computed 1101.9 KiB so far)
# 26/07/01 11:53:44 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_15 in memory.
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_15 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:44 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_18 in memory.
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_18 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:44 WARN MemoryStore: Not enough space to cache rdd_7304_19 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:46 WARN MemoryStore: Not enough space to cache rdd_7304_4 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:46 WARN MemoryStore: Not enough space to cache rdd_7304_0 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:46 WARN MemoryStore: Not enough space to cache rdd_7304_5 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:46 WARN MemoryStore: Not enough space to cache rdd_7304_3 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:48 WARN MemoryStore: Not enough space to cache rdd_7304_11 in memory! (computed 24.8 MiB so far)
# 26/07/01 11:53:48 WARN MemoryStore: Not enough space to cache rdd_7304_12 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:53:48 WARN MemoryStore: Not enough space to cache rdd_7304_14 in memory! (computed 4.6 MiB so far)
# 26/07/01 11:53:48 WARN MemoryStore: Not enough space to cache rdd_7304_15 in memory! (computed 1821.4 KiB so far)
# 26/07/01 11:53:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_17 in memory.
# 26/07/01 11:53:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_16 in memory.
# 26/07/01 11:53:48 WARN MemoryStore: Not enough space to cache rdd_7304_17 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:48 WARN MemoryStore: Not enough space to cache rdd_7304_16 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_18 in memory.
# 26/07/01 11:53:48 WARN MemoryStore: Not enough space to cache rdd_7304_18 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:48 WARN MemoryStore: Not enough space to cache rdd_7304_19 in memory! (computed 1821.4 KiB so far)
# 26/07/01 11:53:52 WARN DAGScheduler: Broadcasting large task binary with size 1008.0 KiB
# 26/07/01 11:53:52 WARN MemoryStore: Not enough space to cache rdd_7304_4 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:52 WARN MemoryStore: Not enough space to cache rdd_7304_5 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:52 WARN MemoryStore: Not enough space to cache rdd_7304_3 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:53:52 WARN MemoryStore: Not enough space to cache rdd_7304_0 in memory! (computed 1821.4 KiB so far)
# 26/07/01 11:53:54 WARN MemoryStore: Not enough space to cache rdd_7304_11 in memory! (computed 24.8 MiB so far)
# 26/07/01 11:53:54 WARN MemoryStore: Not enough space to cache rdd_7304_12 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:54 WARN MemoryStore: Not enough space to cache rdd_7304_14 in memory! (computed 1821.4 KiB so far)
# 26/07/01 11:53:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_15 in memory.
# 26/07/01 11:53:54 WARN MemoryStore: Not enough space to cache rdd_7304_15 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_16 in memory.
# 26/07/01 11:53:54 WARN MemoryStore: Not enough space to cache rdd_7304_16 in memory! (computed 504.0 B so far)
# 26/07/01 11:53:54 WARN MemoryStore: Not enough space to cache rdd_7304_17 in memory! (computed 1821.4 KiB so far)
# 26/07/01 11:53:54 WARN MemoryStore: Not enough space to cache rdd_7304_18 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:53:54 WARN MemoryStore: Not enough space to cache rdd_7304_19 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:53:59 WARN DAGScheduler: Broadcasting large task binary with size 1048.9 KiB
# 26/07/01 11:54:00 WARN MemoryStore: Not enough space to cache rdd_7304_3 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:54:00 WARN MemoryStore: Not enough space to cache rdd_7304_0 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:54:00 WARN MemoryStore: Not enough space to cache rdd_7304_4 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:54:00 WARN MemoryStore: Not enough space to cache rdd_7304_5 in memory! (computed 16.3 MiB so far)
# 26/07/01 11:54:02 WARN MemoryStore: Not enough space to cache rdd_7304_12 in memory! (computed 16.3 MiB so far)
# 26/07/01 11:54:02 WARN MemoryStore: Not enough space to cache rdd_7304_14 in memory! (computed 1821.4 KiB so far)
# 26/07/01 11:54:02 WARN MemoryStore: Not enough space to cache rdd_7304_11 in memory! (computed 16.3 MiB so far)
# 26/07/01 11:54:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_15 in memory.
# 26/07/01 11:54:02 WARN MemoryStore: Not enough space to cache rdd_7304_15 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:02 WARN MemoryStore: Not enough space to cache rdd_7304_16 in memory! (computed 1821.4 KiB so far)
# 26/07/01 11:54:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_17 in memory.
# 26/07/01 11:54:02 WARN MemoryStore: Not enough space to cache rdd_7304_17 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_18 in memory.
# 26/07/01 11:54:02 WARN MemoryStore: Not enough space to cache rdd_7304_18 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:02 WARN MemoryStore: Not enough space to cache rdd_7304_19 in memory! (computed 1821.4 KiB so far)
# 26/07/01 11:54:08 WARN DAGScheduler: Broadcasting large task binary with size 1090.9 KiB
# 26/07/01 11:54:09 WARN MemoryStore: Not enough space to cache rdd_7304_4 in memory! (computed 16.3 MiB so far)
# 26/07/01 11:54:09 WARN MemoryStore: Not enough space to cache rdd_7304_3 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:54:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_0 in memory.
# 26/07/01 11:54:09 WARN MemoryStore: Not enough space to cache rdd_7304_5 in memory! (computed 10.8 MiB so far)
# 26/07/01 11:54:09 WARN MemoryStore: Not enough space to cache rdd_7304_0 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:10 WARN MemoryStore: Not enough space to cache rdd_7304_11 in memory! (computed 24.8 MiB so far)
# 26/07/01 11:54:10 WARN MemoryStore: Not enough space to cache rdd_7304_12 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:54:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_16 in memory.
# 26/07/01 11:54:10 WARN MemoryStore: Not enough space to cache rdd_7304_16 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:10 WARN MemoryStore: Not enough space to cache rdd_7304_14 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:54:11 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7304_15 in memory.
# 26/07/01 11:54:11 WARN MemoryStore: Not enough space to cache rdd_7304_15 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:11 WARN MemoryStore: Not enough space to cache rdd_7304_17 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:54:11 WARN MemoryStore: Not enough space to cache rdd_7304_18 in memory! (computed 7.0 MiB so far)
# 26/07/01 11:54:11 WARN MemoryStore: Not enough space to cache rdd_7304_19 in memory! (computed 2.8 MiB so far)
# 26/07/01 11:54:20 WARN DAGScheduler: Broadcasting large task binary with size 1041.3 KiB
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_9 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_6 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:21 WARN BlockManager: Persisting block rdd_7440_9 to disk instead.
# 26/07/01 11:54:21 WARN BlockManager: Persisting block rdd_7440_6 to disk instead.
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_2 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:21 WARN BlockManager: Persisting block rdd_7440_2 to disk instead.
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_5 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:21 WARN BlockManager: Persisting block rdd_7440_5 to disk instead.
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_8 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:21 WARN BlockManager: Persisting block rdd_7440_8 to disk instead.
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_7 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:21 WARN BlockManager: Persisting block rdd_7440_7 to disk instead.
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_4 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:21 WARN BlockManager: Persisting block rdd_7440_4 to disk instead.
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_0 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:21 WARN BlockManager: Persisting block rdd_7440_0 to disk instead.
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_5 in memory! (computed 59.6 MiB so far)
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_6 in memory! (computed 11.2 MiB so far)
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_9 in memory! (computed 59.6 MiB so far)
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_0 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_4 in memory! (computed 1901.1 KiB so far)
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_2 in memory! (computed 25.9 MiB so far)
# 26/07/01 11:54:21 WARN MemoryStore: Not enough space to cache rdd_7440_7 in memory! (computed 3.0 MiB so far)
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_12 in memory! (computed 25.9 MiB so far)
# 26/07/01 11:54:23 WARN BlockManager: Persisting block rdd_7440_12 to disk instead.
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_14 in memory! (computed 11.2 MiB so far)
# 26/07/01 11:54:23 WARN BlockManager: Persisting block rdd_7440_14 to disk instead.
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_11 in memory! (computed 59.6 MiB so far)
# 26/07/01 11:54:23 WARN BlockManager: Persisting block rdd_7440_11 to disk instead.
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_10 in memory! (computed 59.6 MiB so far)
# 26/07/01 11:54:23 WARN BlockManager: Persisting block rdd_7440_10 to disk instead.
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_13 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:23 WARN BlockManager: Persisting block rdd_7440_13 to disk instead.
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_15 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:23 WARN BlockManager: Persisting block rdd_7440_15 to disk instead.
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_17 in memory! (computed 25.9 MiB so far)
# 26/07/01 11:54:23 WARN BlockManager: Persisting block rdd_7440_17 to disk instead.
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_12 in memory! (computed 25.9 MiB so far)
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_10 in memory! (computed 25.9 MiB so far)
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_18 in memory! (computed 11.2 MiB so far)
# 26/07/01 11:54:23 WARN BlockManager: Persisting block rdd_7440_18 to disk instead.
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_13 in memory! (computed 17.1 MiB so far)
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_16 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:23 WARN BlockManager: Persisting block rdd_7440_16 to disk instead.
# 26/07/01 11:54:23 WARN MemoryStore: Not enough space to cache rdd_7440_15 in memory! (computed 11.2 MiB so far)
# 26/07/01 11:54:24 WARN MemoryStore: Not enough space to cache rdd_7440_14 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:24 WARN MemoryStore: Not enough space to cache rdd_7440_17 in memory! (computed 3.0 MiB so far)
# 26/07/01 11:54:24 WARN MemoryStore: Not enough space to cache rdd_7440_19 in memory! (computed 1901.1 KiB so far)
# 26/07/01 11:54:24 WARN BlockManager: Persisting block rdd_7440_19 to disk instead.
# 26/07/01 11:54:24 WARN MemoryStore: Not enough space to cache rdd_7440_16 in memory! (computed 1901.1 KiB so far)
# 26/07/01 11:54:24 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7440_18 in memory.
# 26/07/01 11:54:24 WARN MemoryStore: Not enough space to cache rdd_7440_18 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:24 WARN MemoryStore: Not enough space to cache rdd_7440_19 in memory! (computed 59.6 MiB so far)
# 26/07/01 11:54:27 WARN DAGScheduler: Broadcasting large task binary with size 1071.9 KiB
# 26/07/01 11:54:27 WARN MemoryStore: Not enough space to cache rdd_7440_5 in memory! (computed 17.1 MiB so far)
# 26/07/01 11:54:27 WARN MemoryStore: Not enough space to cache rdd_7440_9 in memory! (computed 17.1 MiB so far)
# 26/07/01 11:54:27 WARN MemoryStore: Not enough space to cache rdd_7440_4 in memory! (computed 17.1 MiB so far)
# 26/07/01 11:54:27 WARN MemoryStore: Not enough space to cache rdd_7440_0 in memory! (computed 17.1 MiB so far)
# 26/07/01 11:54:27 WARN MemoryStore: Not enough space to cache rdd_7440_7 in memory! (computed 17.1 MiB so far)
# 26/07/01 11:54:27 WARN MemoryStore: Not enough space to cache rdd_7440_6 in memory! (computed 17.1 MiB so far)
# 26/07/01 11:54:27 WARN MemoryStore: Not enough space to cache rdd_7440_2 in memory! (computed 17.1 MiB so far)
# 26/07/01 11:54:29 WARN MemoryStore: Not enough space to cache rdd_7440_12 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:29 WARN MemoryStore: Not enough space to cache rdd_7440_14 in memory! (computed 3.0 MiB so far)
# 26/07/01 11:54:29 WARN MemoryStore: Not enough space to cache rdd_7440_13 in memory! (computed 3.0 MiB so far)
# 26/07/01 11:54:29 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7440_15 in memory.
# 26/07/01 11:54:29 WARN MemoryStore: Not enough space to cache rdd_7440_15 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:29 WARN MemoryStore: Not enough space to cache rdd_7440_16 in memory! (computed 3.0 MiB so far)
# 26/07/01 11:54:29 WARN MemoryStore: Not enough space to cache rdd_7440_17 in memory! (computed 3.0 MiB so far)
# 26/07/01 11:54:29 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7440_18 in memory.
# 26/07/01 11:54:29 WARN MemoryStore: Not enough space to cache rdd_7440_18 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:29 WARN MemoryStore: Not enough space to cache rdd_7440_19 in memory! (computed 4.8 MiB so far)
# 26/07/01 11:54:33 WARN DAGScheduler: Broadcasting large task binary with size 1112.7 KiB
# 26/07/01 11:54:33 WARN MemoryStore: Not enough space to cache rdd_7440_0 in memory! (computed 4.8 MiB so far)
# 26/07/01 11:54:33 WARN MemoryStore: Not enough space to cache rdd_7440_7 in memory! (computed 3.0 MiB so far)
# 26/07/01 11:54:33 WARN MemoryStore: Not enough space to cache rdd_7440_2 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:33 WARN MemoryStore: Not enough space to cache rdd_7440_9 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:33 WARN MemoryStore: Not enough space to cache rdd_7440_5 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:33 WARN MemoryStore: Not enough space to cache rdd_7440_4 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:33 WARN MemoryStore: Not enough space to cache rdd_7440_6 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:36 WARN MemoryStore: Not enough space to cache rdd_7440_12 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:36 WARN MemoryStore: Not enough space to cache rdd_7440_13 in memory! (computed 4.8 MiB so far)
# 26/07/01 11:54:36 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7440_14 in memory.
# 26/07/01 11:54:36 WARN MemoryStore: Not enough space to cache rdd_7440_14 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:36 WARN MemoryStore: Not enough space to cache rdd_7440_15 in memory! (computed 1150.1 KiB so far)
# 26/07/01 11:54:36 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7440_16 in memory.
# 26/07/01 11:54:36 WARN MemoryStore: Not enough space to cache rdd_7440_16 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:36 WARN MemoryStore: Not enough space to cache rdd_7440_17 in memory! (computed 4.8 MiB so far)
# 26/07/01 11:54:36 WARN MemoryStore: Not enough space to cache rdd_7440_18 in memory! (computed 1150.1 KiB so far)
# 26/07/01 11:54:36 WARN MemoryStore: Not enough space to cache rdd_7440_19 in memory! (computed 4.8 MiB so far)
# 26/07/01 11:54:43 WARN DAGScheduler: Broadcasting large task binary with size 1165.3 KiB
# 26/07/01 11:54:43 WARN MemoryStore: Not enough space to cache rdd_7440_5 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:43 WARN MemoryStore: Not enough space to cache rdd_7440_9 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:43 WARN MemoryStore: Not enough space to cache rdd_7440_0 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:43 WARN MemoryStore: Not enough space to cache rdd_7440_7 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:43 WARN MemoryStore: Not enough space to cache rdd_7440_6 in memory! (computed 11.2 MiB so far)
# 26/07/01 11:54:43 WARN MemoryStore: Not enough space to cache rdd_7440_2 in memory! (computed 3.0 MiB so far)
# 26/07/01 11:54:43 WARN MemoryStore: Not enough space to cache rdd_7440_4 in memory! (computed 1150.1 KiB so far)
# 26/07/01 11:54:46 WARN MemoryStore: Not enough space to cache rdd_7440_12 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:46 WARN MemoryStore: Not enough space to cache rdd_7440_13 in memory! (computed 4.8 MiB so far)
# 26/07/01 11:54:46 WARN MemoryStore: Not enough space to cache rdd_7440_14 in memory! (computed 1150.1 KiB so far)
# 26/07/01 11:54:46 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7440_15 in memory.
# 26/07/01 11:54:46 WARN MemoryStore: Not enough space to cache rdd_7440_15 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:46 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7440_16 in memory.
# 26/07/01 11:54:46 WARN MemoryStore: Not enough space to cache rdd_7440_16 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:46 WARN MemoryStore: Not enough space to cache rdd_7440_17 in memory! (computed 1150.1 KiB so far)
# 26/07/01 11:54:46 WARN MemoryStore: Not enough space to cache rdd_7440_18 in memory! (computed 1150.1 KiB so far)
# 26/07/01 11:54:46 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7440_19 in memory.
# 26/07/01 11:54:46 WARN MemoryStore: Not enough space to cache rdd_7440_19 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:56 WARN DAGScheduler: Broadcasting large task binary with size 1214.1 KiB
# 26/07/01 11:54:56 WARN MemoryStore: Not enough space to cache rdd_7440_7 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:56 WARN MemoryStore: Not enough space to cache rdd_7440_0 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:56 WARN MemoryStore: Not enough space to cache rdd_7440_5 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:56 WARN MemoryStore: Not enough space to cache rdd_7440_4 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:56 WARN MemoryStore: Not enough space to cache rdd_7440_2 in memory! (computed 7.3 MiB so far)
# 26/07/01 11:54:56 WARN MemoryStore: Not enough space to cache rdd_7440_6 in memory! (computed 4.8 MiB so far)
# 26/07/01 11:54:56 WARN MemoryStore: Not enough space to cache rdd_7440_9 in memory! (computed 3.0 MiB so far)
# 26/07/01 11:54:59 WARN MemoryStore: Not enough space to cache rdd_7440_12 in memory! (computed 39.5 MiB so far)
# 26/07/01 11:54:59 WARN MemoryStore: Not enough space to cache rdd_7440_13 in memory! (computed 4.8 MiB so far)
# 26/07/01 11:54:59 WARN MemoryStore: Not enough space to cache rdd_7440_14 in memory! (computed 1150.1 KiB so far)
# 26/07/01 11:54:59 WARN MemoryStore: Not enough space to cache rdd_7440_15 in memory! (computed 1150.1 KiB so far)
# 26/07/01 11:54:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7440_16 in memory.
# 26/07/01 11:54:59 WARN MemoryStore: Not enough space to cache rdd_7440_16 in memory! (computed 504.0 B so far)
# 26/07/01 11:54:59 WARN MemoryStore: Not enough space to cache rdd_7440_17 in memory! (computed 1150.1 KiB so far)
# 26/07/01 11:54:59 WARN MemoryStore: Not enough space to cache rdd_7440_18 in memory! (computed 4.8 MiB so far)
# 26/07/01 11:54:59 WARN MemoryStore: Not enough space to cache rdd_7440_19 in memory! (computed 1150.1 KiB so far)
# {'model': 'Random Forest',
#  'accuracy': 0.851458115487394,
#  'weighted_f1': 0.8512043350262226,
#  'weighted_precision': 0.8512806898680692,
#  'weighted_recall': 0.851458115487394,
#  'macro_ovr_auc': 0.9119972483394411,
#  'weighted_ovr_auc': 0.9115306348213126}

# %%
rf_cv_table = cv_results_table(
    rf_cv_model,
    [(rf.numTrees, "numTrees"), (rf.maxDepth, "maxDepth"), (rf.featureSubsetStrategy, "featureSubsetStrategy")],
    "Random Forest"
).orderBy(F.desc("cv_weighted_f1"))

show_df(rf_cv_table, 100)
show_df(confusion_table(rf_pred, rf_labels), 100)
# Out:
# +-------------+-----------------+--------+--------+---------------------+
# |model        |cv_weighted_f1   |numTrees|maxDepth|featureSubsetStrategy|
# +-------------+-----------------+--------+--------+---------------------+
# |Random Forest|0.833683101451841|50      |5       |sqrt                 |
# +-------------+-----------------+--------+--------+---------------------+
# +----------+---------------+-----+
# |label_name|prediction_name|count|
# +----------+---------------+-----+
# |DEMOCRAT  |DEMOCRAT       |5230 |
# |DEMOCRAT  |OTHER          |535  |
# |DEMOCRAT  |REPUBLICAN     |116  |
# |OTHER     |DEMOCRAT       |658  |
# |OTHER     |OTHER          |4166 |
# |OTHER     |REPUBLICAN     |513  |
# |REPUBLICAN|DEMOCRAT       |221  |
# |REPUBLICAN|OTHER          |514  |
# |REPUBLICAN|REPUBLICAN     |5261 |
# +----------+---------------+-----+

# %% [markdown]
# # Model Importance
#
# This section adds interpretability outputs:
#
# 1. **Random Forest feature importance** from the tuned champion candidate.
# 2. **Grouped Random Forest importance**, where one-hot encoded levels are grouped back to the original column.
# 3. **Logistic Regression coefficient importance**, based on mean absolute coefficients across party classes.

# %%
# Random Forest feature importance

rf_importance_df = random_forest_feature_importance_df(
    rf_cv_model,
    numeric_features,
    categorical_features,
    model_name="Random Forest"
)

print("Top Random Forest feature importances:")
show_df(rf_importance_df, 50, truncate=False)

rf_grouped_importance_df = group_ohe_importance(rf_importance_df, "importance")

print("Grouped Random Forest feature importances:")
show_df(rf_grouped_importance_df, 50, truncate=False)

if MAKE_GRAPHS:
    rf_imp_pd = rf_grouped_importance_df.limit(20).toPandas()
    if len(rf_imp_pd) > 0:
        ax = rf_imp_pd.sort_values("grouped_importance").plot(
            kind="barh",
            x="feature_group",
            y="grouped_importance",
            legend=False,
            title="Top Grouped Random Forest Feature Importances"
        )
        ax.set_xlabel("Grouped importance")
        ax.set_ylabel("Feature group")
        plt.tight_layout()
        plt.show()
# Out:
# Top Random Forest feature importances:
# +-------------+-------------------------------------+---------------------+
# |model        |feature                              |importance           |
# +-------------+-------------------------------------+---------------------+
# |Random Forest|district_group=MISSING               |0.08548745238715705  |
# |Random Forest|state_group=TX                       |0.06701034524084064  |
# |Random Forest|state_group=MISSING                  |0.06643071271471378  |
# |Random Forest|recipient_cfscore                    |0.0645502453514293   |
# |Random Forest|seat_group=STATE:BALLOT              |0.05661349608413666  |
# |Random Forest|fec_ctx_candidate_count              |0.05357412582206789  |
# |Random Forest|state_group=CA                       |0.05135387594350131  |
# |Random Forest|recipient_type_group=COMMITTEE_OR_PAC|0.04588691716185034  |
# |Random Forest|seat_group=STATE:JUDICIAL            |0.040377381501611714 |
# |Random Forest|fec_ctx_avg_sum_linked_cmte_receipts |0.03659944235565772  |
# |Random Forest|seat_group=STATE:LOWER               |0.03434992314710379  |
# |Random Forest|seat_group=LOCAL:COUNCIL             |0.03424172190454859  |
# |Random Forest|seat_group=STATE:UPPER               |0.03015229139783368  |
# |Random Forest|fec_ctx_avg_num_linked_committees    |0.02971760883262732  |
# |Random Forest|recipient_type_group=CANDIDATE       |0.02641185147225763  |
# |Random Forest|state_group=PA                       |0.0225205574059292   |
# |Random Forest|fec_ctx_avg_num_authorized_committees|0.021513729751295983 |
# |Random Forest|seat_group=FEDERAL:527               |0.018916750346835067 |
# |Random Forest|log_total_indiv_contribs             |0.017374838972369293 |
# |Random Forest|seat_group=FEDERAL:HOUSE             |0.01106236898570849  |
# |Random Forest|state_group=TN                       |0.010200416057840776 |
# |Random Forest|log_num_givers                       |0.010028430358205156 |
# |Random Forest|fec_ctx_avg_num_principal_committees |0.00921955652325921  |
# |Random Forest|state_group=MD                       |0.008928451181497361 |
# |Random Forest|seat_group=FEDERAL:COMMITTEE         |0.008605914186719675 |
# |Random Forest|seat_group=STATE:LOCAL               |0.008264407919093253 |
# |Random Forest|state_group=MA                       |0.0062424819940068545|
# |Random Forest|state_group=UT                       |0.006120563119055673 |
# |Random Forest|state_group=NE                       |0.005357745601378876 |
# |Random Forest|district_group=IL-1                  |0.005190168289240792 |
# |Random Forest|seat_group=STATE:COMMITTEE           |0.005143252752682145 |
# |Random Forest|state_group=AL                       |0.005120360340409706 |
# |Random Forest|state_group=NH                       |0.005019097983506604 |
# |Random Forest|state_group=GA                       |0.00465557168006634  |
# |Random Forest|seat_group=FEDERAL:SENATE            |0.004461249587286046 |
# |Random Forest|state_group=DE                       |0.004311568049430942 |
# |Random Forest|seat_group=LOCAL:SUPERVISOR          |0.004148054184885368 |
# |Random Forest|state_group=ME                       |0.003865098006943586 |
# |Random Forest|state_group=ID                       |0.003746777731762914 |
# |Random Forest|state_group=VT                       |0.0035156787850139696|
# |Random Forest|state_group=WV                       |0.0032870714893291743|
# |Random Forest|state_group=IN                       |0.003054311876916109 |
# |Random Forest|log_total_pac_contribs               |0.0026249200651032095|
# |Random Forest|state_group=MT                       |0.002432444427116303 |
# |Random Forest|district_group=MD07                  |0.0024229842542937323|
# |Random Forest|year                                 |0.002282213167826019 |
# |Random Forest|state_group=FL                       |0.002237026411976711 |
# |Random Forest|district_group=OK02                  |0.002230063269777758 |
# |Random Forest|state_group=MS                       |0.002026675676080894 |
# |Random Forest|state_group=VA                       |0.0019480545796523344|
# +-------------+-------------------------------------+---------------------+
# only showing top 50 rows
# Grouped Random Forest feature importances:
# +-------------+-------------------------------------+---------------------+
# |model        |feature_group                        |grouped_importance   |
# +-------------+-------------------------------------+---------------------+
# |Random Forest|state_group                          |0.3039097798140928   |
# |Random Forest|seat_group                           |0.26241567284658807  |
# |Random Forest|district_group                       |0.11374141289027175  |
# |Random Forest|recipient_type_group                 |0.07229876863410797  |
# |Random Forest|recipient_cfscore                    |0.0645502453514293   |
# |Random Forest|fec_ctx_candidate_count              |0.05357412582206789  |
# |Random Forest|fec_ctx_avg_sum_linked_cmte_receipts |0.03659944235565772  |
# |Random Forest|fec_ctx_avg_num_linked_committees    |0.02971760883262732  |
# |Random Forest|fec_ctx_avg_num_authorized_committees|0.021513729751295983 |
# |Random Forest|log_total_indiv_contribs             |0.017374838972369293 |
# |Random Forest|log_num_givers                       |0.010028430358205156 |
# |Random Forest|fec_ctx_avg_num_principal_committees |0.00921955652325921  |
# |Random Forest|log_total_pac_contribs               |0.0026249200651032095|
# |Random Forest|year                                 |0.002282213167826019 |
# |Random Forest|log_total_receipts                   |1.4925461509877362E-4|
# |Random Forest|gender_group                         |0.0                  |
# +-------------+-------------------------------------+---------------------+

# %%
# Logistic Regression coefficient importance

full_lr_coef_importance_df = logistic_coefficient_importance_df(
    full_lr_cv_model,
    numeric_features,
    categorical_features,
    model_name="Full Multinomial Logistic Regression"
)

print("Top Logistic Regression coefficient importances:")
show_df(full_lr_coef_importance_df, 50, truncate=False)

full_lr_grouped_coef_importance_df = group_ohe_importance(
    full_lr_coef_importance_df.withColumnRenamed("mean_abs_coefficient", "coef_importance"),
    "coef_importance"
)

print("Grouped Logistic Regression coefficient importances:")
show_df(full_lr_grouped_coef_importance_df, 50, truncate=False)

if MAKE_GRAPHS:
    lr_imp_pd = full_lr_grouped_coef_importance_df.limit(20).toPandas()
    if len(lr_imp_pd) > 0:
        ax = lr_imp_pd.sort_values("grouped_coef_importance").plot(
            kind="barh",
            x="feature_group",
            y="grouped_coef_importance",
            legend=False,
            title="Top Grouped Logistic Regression Coefficient Importances"
        )
        ax.set_xlabel("Grouped mean absolute coefficient")
        ax.set_ylabel("Feature group")
        plt.tight_layout()
        plt.show()
# Out:
# Top Logistic Regression coefficient importances:
# +------------------------------------+-------------------------------------+--------------------+
# |model                               |feature                              |mean_abs_coefficient|
# +------------------------------------+-------------------------------------+--------------------+
# |Full Multinomial Logistic Regression|recipient_cfscore                    |1.0965931624236356  |
# |Full Multinomial Logistic Regression|district_group=MISSING               |0.1652936090756747  |
# |Full Multinomial Logistic Regression|log_num_givers                       |0.15986267122441725 |
# |Full Multinomial Logistic Regression|recipient_type_group=CANDIDATE       |0.15920052257512243 |
# |Full Multinomial Logistic Regression|recipient_type_group=COMMITTEE_OR_PAC|0.15920052257510964 |
# |Full Multinomial Logistic Regression|state_group=TX                       |0.13695970286998174 |
# |Full Multinomial Logistic Regression|seat_group=STATE:LOWER               |0.11834237664670022 |
# |Full Multinomial Logistic Regression|seat_group=LOCAL:COUNCIL             |0.11539178030734681 |
# |Full Multinomial Logistic Regression|seat_group=FEDERAL:HOUSE             |0.10997503767578977 |
# |Full Multinomial Logistic Regression|seat_group=STATE:JUDICIAL            |0.10319346300671312 |
# |Full Multinomial Logistic Regression|fec_ctx_candidate_count              |0.10266980799236751 |
# |Full Multinomial Logistic Regression|log_total_pac_contribs               |0.09131003137365573 |
# |Full Multinomial Logistic Regression|state_group=MISSING                  |0.07634174369579345 |
# |Full Multinomial Logistic Regression|state_group=NE                       |0.06847147341756676 |
# |Full Multinomial Logistic Regression|state_group=NY                       |0.06654109196709347 |
# |Full Multinomial Logistic Regression|seat_group=LOCAL:OTHER               |0.0575685937415562  |
# |Full Multinomial Logistic Regression|state_group=DC                       |0.05668740957191439 |
# |Full Multinomial Logistic Regression|seat_group=STATE:BALLOT              |0.0566555941447506  |
# |Full Multinomial Logistic Regression|seat_group=STATE:UNKNOWN             |0.056350866892358346|
# |Full Multinomial Logistic Regression|seat_group=STATE:UPPER               |0.049914912055948425|
# |Full Multinomial Logistic Regression|seat_group=FEDERAL:527               |0.04068883112026599 |
# |Full Multinomial Logistic Regression|seat_group=LOCAL:SCHOOL-BOARD        |0.04050051055373972 |
# |Full Multinomial Logistic Regression|seat_group=LOCAL:MAYOR               |0.03678187922124491 |
# |Full Multinomial Logistic Regression|seat_group=STATE:OTHER               |0.026841783035727217|
# |Full Multinomial Logistic Regression|state_group=AL                       |0.023458576708282317|
# |Full Multinomial Logistic Regression|district_group=TX-5                  |0.021753129773257402|
# |Full Multinomial Logistic Regression|district_group=TX-13                 |0.017817815602118696|
# |Full Multinomial Logistic Regression|district_group=TX-14                 |0.017422581797386528|
# |Full Multinomial Logistic Regression|state_group=WI                       |0.017099011960439222|
# |Full Multinomial Logistic Regression|state_group=IL                       |0.015940089925332294|
# |Full Multinomial Logistic Regression|seat_group=STATE:LOCAL               |0.015811819869624228|
# |Full Multinomial Logistic Regression|district_group=TX-1                  |0.015614070006118962|
# |Full Multinomial Logistic Regression|state_group=CA                       |0.015350772033078013|
# |Full Multinomial Logistic Regression|state_group=VT                       |0.013900872205837494|
# |Full Multinomial Logistic Regression|state_group=UT                       |0.013406609956582426|
# |Full Multinomial Logistic Regression|state_group=OK                       |0.012703995548167068|
# |Full Multinomial Logistic Regression|district_group=TX-2                  |0.011996260974614209|
# |Full Multinomial Logistic Regression|state_group=LA                       |0.01180198380498434 |
# |Full Multinomial Logistic Regression|log_total_indiv_contribs             |0.01126531239898781 |
# |Full Multinomial Logistic Regression|state_group=MD                       |0.01115436956626012 |
# |Full Multinomial Logistic Regression|seat_group=STATE:OFFICE              |0.011145267785289764|
# |Full Multinomial Logistic Regression|state_group=KY                       |0.011124181864282476|
# |Full Multinomial Logistic Regression|district_group=TX-3                  |0.010956678564935221|
# |Full Multinomial Logistic Regression|state_group=MN                       |0.010611317556139817|
# |Full Multinomial Logistic Regression|seat_group=LOCAL:SUPERVISOR          |0.010284526255407576|
# |Full Multinomial Logistic Regression|district_group=TX-4                  |0.010252368824460375|
# |Full Multinomial Logistic Regression|state_group=VA                       |0.010100923316959795|
# |Full Multinomial Logistic Regression|seat_group=STATE:ATTORNEYG           |0.007346325333745781|
# |Full Multinomial Logistic Regression|state_group=MA                       |0.007293266350488684|
# |Full Multinomial Logistic Regression|state_group=WY                       |0.006977599801231686|
# +------------------------------------+-------------------------------------+--------------------+
# only showing top 50 rows
# Grouped Logistic Regression coefficient importances:
# +------------------------------------+-------------------------------------+-----------------------+
# |model                               |feature_group                        |grouped_coef_importance|
# +------------------------------------+-------------------------------------+-----------------------+
# |Full Multinomial Logistic Regression|recipient_cfscore                    |1.0965931624236356     |
# |Full Multinomial Logistic Regression|seat_group                           |0.8767561102331848     |
# |Full Multinomial Logistic Regression|state_group                          |0.630094018646067      |
# |Full Multinomial Logistic Regression|district_group                       |0.44103156006669525    |
# |Full Multinomial Logistic Regression|recipient_type_group                 |0.31840104515023204    |
# |Full Multinomial Logistic Regression|log_num_givers                       |0.15986267122441725    |
# |Full Multinomial Logistic Regression|fec_ctx_candidate_count              |0.10266980799236751    |
# |Full Multinomial Logistic Regression|log_total_pac_contribs               |0.09131003137365573    |
# |Full Multinomial Logistic Regression|log_total_indiv_contribs             |0.01126531239898781    |
# |Full Multinomial Logistic Regression|fec_ctx_avg_num_authorized_committees|0.0                    |
# |Full Multinomial Logistic Regression|gender_group                         |0.0                    |
# |Full Multinomial Logistic Regression|year                                 |0.0                    |
# |Full Multinomial Logistic Regression|log_total_receipts                   |0.0                    |
# |Full Multinomial Logistic Regression|fec_ctx_avg_num_principal_committees |0.0                    |
# |Full Multinomial Logistic Regression|fec_ctx_avg_num_linked_committees    |0.0                    |
# |Full Multinomial Logistic Regression|fec_ctx_avg_sum_linked_cmte_receipts |0.0                    |
# +------------------------------------+-------------------------------------+-----------------------+

# %%
# 18. Model comparison and champion selection

metrics_rows = [benchmark_metrics, full_lr_metrics, rf_metrics]
metrics_pdf = pd.DataFrame(metrics_rows)

model_comparison = spark.createDataFrame(metrics_pdf).orderBy(F.desc("weighted_f1"))

show_df(model_comparison, 20)

champion_row = model_comparison.first().asDict()
champion_model_name = champion_row["model"]

print("Champion model:", champion_model_name)
print("Champion weighted F1:", champion_row["weighted_f1"])
print("Champion weighted AUROC:", champion_row.get("weighted_ovr_auc"))
# Out:
# +------------------------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |model                               |accuracy          |weighted_f1       |weighted_precision|weighted_recall   |macro_ovr_auc     |weighted_ovr_auc  |
# +------------------------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |Full Multinomial Logistic Regression|0.880504240734286 |0.8805030042719104|0.8805078448097026|0.880504240734286 |0.962232626500823 |0.9629713498166326|
# |Random Forest                       |0.851458115487394 |0.8512043350262226|0.8512806898680692|0.851458115487394 |0.9119972483394411|0.9115306348213126|
# |Benchmark Logistic Regression       |0.6256535378180551|0.623062544283796 |0.6210817166698894|0.6256535378180551|0.7996620342593278|0.7955161535340893|
# +------------------------------------+------------------+------------------+------------------+------------------+------------------+------------------+
#
# Champion model: Full Multinomial Logistic Regression
# Champion weighted F1: 0.8805030042719104
# Champion weighted AUROC: 0.9629713498166326

# %% [markdown]
# # Save final outputs

# %%
MODEL_OUTPUT_DIR = PROCESSED_DIR / f"final_project_outputs_{YEAR_LABEL}"
MODEL_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

model_comparison.write.mode("overwrite").parquet(str(MODEL_OUTPUT_DIR / "model_comparison_parquet"))
benchmark_cv_table.write.mode("overwrite").parquet(str(MODEL_OUTPUT_DIR / "benchmark_cv_results_parquet"))
full_lr_cv_table.write.mode("overwrite").parquet(str(MODEL_OUTPUT_DIR / "full_lr_cv_results_parquet"))
rf_cv_table.write.mode("overwrite").parquet(str(MODEL_OUTPUT_DIR / "rf_cv_results_parquet"))

# Save model importance outputs
rf_importance_df.write.mode("overwrite").parquet(str(MODEL_OUTPUT_DIR / "rf_feature_importance_parquet"))
rf_grouped_importance_df.write.mode("overwrite").parquet(str(MODEL_OUTPUT_DIR / "rf_grouped_feature_importance_parquet"))
full_lr_coef_importance_df.write.mode("overwrite").parquet(str(MODEL_OUTPUT_DIR / "full_lr_coefficient_importance_parquet"))
full_lr_grouped_coef_importance_df.write.mode("overwrite").parquet(str(MODEL_OUTPUT_DIR / "full_lr_grouped_coefficient_importance_parquet"))

class_balance.write.mode("overwrite").parquet(str(MODEL_OUTPUT_DIR / "class_balance_parquet"))
eda_year_party.write.mode("overwrite").parquet(str(MODEL_OUTPUT_DIR / "eda_year_party_parquet"))
eda_state_party.write.mode("overwrite").parquet(str(MODEL_OUTPUT_DIR / "eda_state_party_parquet"))
eda_seat_party.write.mode("overwrite").parquet(str(MODEL_OUTPUT_DIR / "eda_seat_party_parquet"))

print("Saved outputs to:", MODEL_OUTPUT_DIR)
# Out:
# Saved outputs to: data/dime_fec_final_project/processed/final_project_outputs_2018_2024
